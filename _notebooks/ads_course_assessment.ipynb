# %% [markdown]
# # Assessment for Advanced Data Science
# # *Data Pipelines*

# %% [markdown]
# ## Radzim Sendyka, Christian Cabrera, Carl Henrik Ek and Neil D. Lawrence
#
# ### 19 November 2024

# %% [markdown]
# Welcome to the course assessment for the Advanced Data Science unit. In this assessment, you will build two data pipelines and prediction systems.
#
# The maximum total mark for this assessment is 20. That mark is split into two miniprojects below.
# - The first miniproject is worth 7 marks.
# - The second miniproject is worth 13 marks.
#
# *The check Session for this Assessment is 03 December 2024.*

# %% [markdown]
# # Task 1 (7 marks)

# %% [markdown]
# This example project builds on your experience from the practicals, using Open Street Maps, and connecting them to real-world datasets.
#
# Your prediction system will be based on data from the 2021 UK Census, and Open Street Maps.

# %% [markdown]
# ### Build a data pipeline and prediction system.
#
# Structure your system around the [Access-Assess-Address](https://inverseprobability.com/talks/notes/access-assess-address-a-pipeline-for-automated-data-science.html) framework for automated data science.
# Use the framework of [Data Readiness Levels](https://inverseprobability.com/publications/data-readiness-levels.html) to track the state of your datasets throughout the process.
# Visualise your data and predictions using appropriate charts and graphics.
# Remember, your notebook should tell a story.
#
# 1.1. Download the data from online sources. In this task you will need:
#   - UK Census Data
#     - The UK Census data file for and Socio-economic Classification (NS SEC) [here](https://www.ons.gov.uk/datasets/TS062/editions/2021/versions/5) or [here](https://www.nomisweb.co.uk/sources/census_2021_bulk). Use the most detailed area type (Output Areas).
#     - One other UK Census data file of your choosing [here](https://www.ons.gov.uk/search?topics=9731,6646,3845,9497,4262,4128,7755,4994,6885,9724,7367&filter=datasets) or [here](https://www.nomisweb.co.uk/sources/census_2021_bulk). Use the most detailed area type available.
#     - Geographic coordinates of Census Output Areas [here](https://www.data.gov.uk/dataset/4d4e021d-fe98-4a0e-88e2-3ead84538537/output-areas-december-2021-boundaries-ew-bgc-v2).
#   - Spatial data
#     - Set up an API connection to Open Street Maps [here](https://osmnx.readthedocs.io/en/stable/). Optionally, to be able to use more data in training, you might want to also download the entire map for England (or more) [here](https://download.openstreetmap.fr/extracts/) or [here](https://wiki.openstreetmap.org/wiki/Planet.osm).
#
# 1.2. Structure the data, and upload it to your AWS database.
#
# - Census datasets can be huge and unwieldy to manipulate directly in python frameworks such as pandas. As a result we will host the data in a relational database.
#
# - Using a cloud hosted database (such as MariaDB hosted on the AWS RDS service),  you will construct a database containing tables that contain per-output-area data, latitudes and longitudes of the output areas, and potentially, extracted selected open street maps features from the country-wide data file.
#
# - Make sure you set the correct indices on your data, which will allow your code to run much faster. Hint: create an index on any columns you will be looking up, and joint indices if your lookup involves multiple columns (like coordinates).
#
# You will likely find the following resources helpful.
#
# - Lecture 1, 2 and 3.
# - Lab class 1 and 2.
#
#
# - *Note, this particular dataset could probably be handled directly in pandas, but you are explicitly tasked with using a database. This is a compromise from previous iterations of this course, where students spent quite a lot of time struggling from the size of the data. This is an opportunity for you to demonstrate your skills, as well as prepare for the second part of the assessment where databases might be necessary. Approach that do not use databases where needed will be penalised during marking.*
#
#
# 2.0. Explore the data.
#
#   - To make predictions you will augment your data with information obtained from Open Street Map: an open license source of mapping information. You will need to use the techniques you have learnt in the course to indentify and incorporate useful features for your prediction tasks.
#   - Look at the percentage of students (NS SEC code L15) in the individual output areas, and explore how it's related to various types of open street map features in those locations. Use the relationships you found to suggest the features to be used in a system that predicts percentage of students in a given area.
#   - Do the same for an additional census variable (e.g., the average age in a given area).
#
# 3.0. Make a prediction system.
# - Use Open Street Maps to predict Socio-Economic Status - in particular, the percent of full time students, from OSM features. Your function should take as input a coordinate pair (you can assume it will be in England), and return an estimate for the share of students in that area.
#
# - Do the same for the additional census variable you selected in the previous step.
#
# Hints:
#
#   - *Some of the census data sheets are very detailed. You might want to try "boiling them down" to some aggregate value or selecting just the most important columns.*
#
#   - *This assignment is focused on data pipelines, rather than machine learning, so we do not expect any advanced architectures here - a linear model or similar is perfectly fine.*
#
#   - *For data exploration, or picking your second dataset, you may find useful the [interactive map](https://www.ons.gov.uk/census/maps/) of the census data.*

# %% [markdown]
# ### Story.
#
# - Remember the notebook you create should tell a story, any code that is not critical to that story can safely be placed into the associated analysis library and imported for use (structured as given in the Fynesse template). Make sure your decisions are well substanciated and flow nicely throughout the notebook, with clear explanations.
#
# - Explain everything you do. Why is your question important, why you selected the datasets you did, why did you join them how you did, why did you look at the things you looked at.
#
# Make sure in your notebook you discuss the design decisions you made in your pipeline and prediction system. How did you structure your notebook? How did you track data readiness? Which aspects of your system could be improved further?
#
# Make sure you compare how you predict student population and your second chosen property. What differences are there, in the underlying data, process, and results?
#
# Make sure you discuss the reusability of your data pipeline and prediction system. What changes to the underlying data/system is it resilient to, and what isn't it? What work would need to be done to adjust it to answer questions about other statistics, or a different country, instead?

# %% [markdown]
# ### Fynesse library.
#
# - Alongside your implementation you will provide a short repository overview describing how you have implemented the different parts of the project and where you have placed those parts in your code repository. You will submit your code alongside a version of this notebook that will allow your examiner to understand and reconstruct the thinking behind your analysis. This notebook is structured to help you in creating that description and allow you to understand how we will allocate the marks. You should make use of the Fynesse framework (https://github.com/lawrennd/fynesse_template) for structuring your code.
#
# - One artefact to be included in your submission is a python library structured according to the "Access, Assess, Address" standard for data science solutions. You will submit this library alongside your code. Use the cell below to perform the necessary installation instructions for your library.
# You should base your module on the template repository given by the Fynesse template repository. That should make it pip-installable as below.
# `%pip install git+https://github.com/lawrennd/fynesse_template.git`. You can either replace fynesse with the name you've given your analysis module or you can leave the name as fynesse if you prefer.
#
# - Remember the notebook you create should tell a story, any code that is not critical to that story can safely be placed into the associated analysis library and imported for use (structured as given in the Fynesse template). Remember to include you fynesse library in your submission.

# %% [markdown]
# ## Access

# %%
# install your library here
# %pip install git+https://github.com/lawrennd/fynesse_template.git # TODO: change to your library
# %pip install pandas osmnx shapely numpy geopandas matplotlib seaborn scikit-learn mysqlclient pymysql
# Out:
# Requirement already satisfied: pandas in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (2.2.3)
# Requirement already satisfied: osmnx in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (1.9.4)
# Requirement already satisfied: shapely in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (2.0.6)
# Requirement already satisfied: numpy in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (1.26.4)
# Requirement already satisfied: geopandas in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (0.14.4)
# Requirement already satisfied: matplotlib in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (3.9.2)
# Requirement already satisfied: seaborn in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (1.5.2)
# Requirement already satisfied: mysqlclient in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (2.2.5)
# Requirement already satisfied: pymysql in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (1.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: networkx<3.4,>=2.5 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from osmnx) (3.3)
# Requirement already satisfied: requests<2.33,>=2.27 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from osmnx) (2.32.3)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from geopandas) (1.10.1)
# Requirement already satisfied: packaging in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from geopandas) (24.1)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from geopandas) (3.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pillow>=8 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from fiona>=1.8.21->geopandas) (24.2.0)
# Requirement already satisfied: certifi in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from fiona>=1.8.21->geopandas) (2024.7.4)
# Requirement already satisfied: click~=8.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from fiona>=1.8.21->geopandas) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: six>=1.5 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from requests<2.33,>=2.27->osmnx) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from requests<2.33,>=2.27->osmnx) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from requests<2.33,>=2.27->osmnx) (2.2.2)
# Requirement already satisfied: colorama in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from click~=8.0->fiona>=1.8.21->geopandas) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import osmnx as ox
import shapely as shp
import numpy as np
import os
import requests
import fynesse
import geopandas as gpd
import yaml
import matplotlib.pyplot as plt
import seaborn as sns
from zipfile import ZipFile
import MySQLdb
import sklearn

# %load_ext sql

# %%
# download data

for url in [
    # 2021 Census data

    # NS-SEC
    "https://static.ons.gov.uk/datasets/TS062-2021-5.csv",
    "https://www.nomisweb.co.uk/output/census/2021/census2021-ts062.zip",
    "https://www.nomisweb.co.uk/output/census/2021/census2021-ts062-extra.zip",

    # Industry by age categories
    # ("./RM062-2021-3-filtered-2024-11-26T15_05_33Z.csv", "https://static.ons.gov.uk/datasets/3195f3da-ba62-4f47-b03a-51f26092371f/RM062-2021-3-filtered-2024-11-26T15:05:33Z.csv#get-data"),
    "https://www.nomisweb.co.uk/output/census/2021/census2021-ts059.zip",

    # OSM data
    "https://download.openstreetmap.fr/extracts/europe/united_kingdom-latest.osm.pbf",
    
    # Geographic data of census output areas
    ("./output_areas.csv", "https://open-geography-portalx-ons.hub.arcgis.com/api/download/v1/items/6beafcfd9b9c4c9993a06b6b199d7e6d/csv?layers=0"),
    ("./output_areas.geojson", "https://open-geography-portalx-ons.hub.arcgis.com/api/download/v1/items/6beafcfd9b9c4c9993a06b6b199d7e6d/geojson?layers=0"),
    ("./counties.geojson", "https://open-geography-portalx-ons.hub.arcgis.com/api/download/v1/items/5e0277da82884fd184ff3e1aa55bd414/geojson?layers=0"),
    "https://pages.mysociety.org/2025-constituencies/data/parliament_con_2025/latest/parl_constituencies_2025.gpkg",
]:

    if isinstance(url, tuple):
        filename, url = url
    else:
        filename = f"./{url.split('/')[-1]}"

    if not os.path.exists(filename):
        print(f"Downloading {url}")
        r = requests.get(url)
        with open(filename, 'wb') as f:
            f.write(r.content)
        print(f"Downloaded {filename}")
    else:
        print(f"Already downloaded {filename}")


    if filename.endswith('.zip') and not os.path.exists(filename.replace('.zip', '')):
        with ZipFile(filename, 'r') as zip_ref:
            zip_ref.extractall()
# Out:
# Already downloaded ./TS062-2021-5.csv
# Already downloaded ./census2021-ts062.zip
# Already downloaded ./census2021-ts062-extra.zip
# Already downloaded ./census2021-ts059.zip
# Already downloaded ./united_kingdom-latest.osm.pbf
# Downloading https://open-geography-portalx-ons.hub.arcgis.com/api/download/v1/items/6beafcfd9b9c4c9993a06b6b199d7e6d/csv?layers=0
# Downloaded ./output_areas.csv
# Already downloaded ./output_areas.geojson
# Already downloaded ./counties.geojson
# Already downloaded ./parl_constituencies_2025.gpkg

# %%
with open("./credentials1.yaml") as file:
  credentials = yaml.safe_load(file)
username = credentials["username"]
password = credentials["password"]
url = credentials["url"]
port = credentials["port"]

# %config SqlMagic.style = '_DEPRECATED_DEFAULT'


connection_string = f"mysql+pymysql://{username}:{password}@{url}:{port}/ads_2024?local_infile=1"
# %sql $connection_string
# %sql use ads_2024;

conn = MySQLdb.connect(host=url, user=username, password=password, database="ads_2024", local_infile=True)

# conn = pymysql.connect(host=url, user=username, password=password, database="ads_2024", local_infile=True)

# conn = fynesse.access.create_connection(username, password, url, "ads_2024")
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 0 rows affected.

# %%
df = pd.read_csv("census2021-ts062-oa.csv")

# the values in "geography" and "geography code" columns are equal
assert (df['geography'] == df['geography code']).all()

# the values in "geography" column are less than 10 characters
assert (df["geography"].str.len() < 10).all()

# %%
# %%sql
# DROP TABLE IF EXISTS census_nssec;
# CREATE TABLE IF NOT EXISTS census_nssec (
#     -- Year of the census
#     year INT NOT NULL,
#
#     -- Geography identifiers
#     output_area VARCHAR(10) NOT NULL,
#
#     -- Population counts by NS-SEC classification
#     total_residents_16_and_over INT NOT NULL,
#     higher_managerial_admin_professional INT NOT NULL,
#     lower_managerial_admin_professional INT NOT NULL,
#     intermediate_occupations INT NOT NULL,
#     small_employers_own_account INT NOT NULL,
#     lower_supervisory_technical INT NOT NULL,
#     semi_routine_occupations INT NOT NULL,
#     routine_occupations INT NOT NULL,
#     never_worked_longterm_unemployed INT NOT NULL,
#     full_time_students INT NOT NULL,
#
#     -- Constraints
#     PRIMARY KEY (year, output_area),
#     CHECK (total_residents_16_and_over >= 0),
#     CHECK (higher_managerial_admin_professional >= 0),
#     CHECK (lower_managerial_admin_professional >= 0),
#     CHECK (intermediate_occupations >= 0),
#     CHECK (small_employers_own_account >= 0),
#     CHECK (lower_supervisory_technical >= 0),
#     CHECK (semi_routine_occupations >= 0),
#     CHECK (routine_occupations >= 0),
#     CHECK (never_worked_longterm_unemployed >= 0),
#     CHECK (full_time_students >= 0)
# ) DEFAULT CHARSET=utf8 COLLATE=utf8_bin AUTO_INCREMENT=1;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 0 rows affected.
# 0 rows affected.
# []

# %%
command = """
LOAD DATA LOCAL INFILE 'census2021-ts062-oa.csv' \
INTO TABLE census_nssec \
FIELDS TERMINATED BY ',' \
ENCLOSED BY '"' \
LINES TERMINATED BY '\n' \
IGNORE 1 LINES \
(year, output_area, @geocode, total_residents_16_and_over, higher_managerial_admin_professional, lower_managerial_admin_professional, intermediate_occupations, small_employers_own_account, lower_supervisory_technical, semi_routine_occupations, routine_occupations, never_worked_longterm_unemployed, full_time_students);"""

# %sql $command
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 188880 rows affected.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS output_area_geometry;
# CREATE TABLE IF NOT EXISTS output_area_geometry (
#     year INT NOT NULL,                    -- Year of the census
#
#     -- Area codes and names
#     code VARCHAR(10) NOT NULL,              -- Output Area code
#     lsoa_code VARCHAR(9) NOT NULL,         -- LSOA code
#     lsoa_name VARCHAR(100) NOT NULL,       -- LSOA name in English
#
#     -- Geographic coordinates
#     bng_easting INT NOT NULL,              -- British National Grid Easting
#     bng_northing INT NOT NULL,             -- British National Grid Northing
#     latitude DECIMAL(10,8) NOT NULL,       -- Latitude coordinate
#     longitude DECIMAL(11,8) NOT NULL,      -- Longitude coordinate
#
#     -- Unique identifier
#     global_id VARCHAR(36) NOT NULL,
#
#     -- Geometry
#     geometry GEOMETRY NOT NULL,            -- Geometry of the output area in WG84
#
#     -- Constraints
#     PRIMARY KEY (year, code)
# ) DEFAULT CHARSET=utf8 COLLATE=utf8_bin AUTO_INCREMENT=1;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 0 rows affected.
# 0 rows affected.
# []

# %%
output_areas_gdf = gpd.read_file("output_areas.geojson")

# set the default geometry column
output_areas_gdf.set_geometry("geometry", inplace=True)

output_areas_gdf.geometry.set_crs(epsg=27700, inplace=True)
output_areas_gdf.geometry = output_areas_gdf.geometry.to_crs(epsg=4326)

# %%
output_areas_gdf.to_csv("output_areas.csv", index=False, sep="|")

# %%
command = """
LOAD DATA LOCAL INFILE 'output_areas.csv' \
INTO TABLE output_area_geometry \
FIELDS TERMINATED BY '|' \
OPTIONALLY ENCLOSED BY '"' \
LINES TERMINATED BY '\n' \
IGNORE 1 LINES \
(@fid, code, lsoa_code, lsoa_name, @welsh, bng_easting, bng_northing, latitude, longitude, global_id, @geometry) \
SET geometry = ST_GeomFromText(@geometry, 4326), year = 2021;"""

# %sql $command
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 188880 rows affected.
# []

# %%
output_areas_gdf = pd.read_sql("SELECT *, ST_AsText(geometry) as geo_text FROM output_area_geometry", conn)
output_areas_gdf["geometry"] = output_areas_gdf["geo_text"].apply(shp.wkt.loads)
output_areas_gdf.drop(columns=["geo_text"], inplace=True)
output_areas_gdf = gpd.GeoDataFrame(output_areas_gdf, geometry="geometry", crs="EPSG:4326")

lsoas = output_areas_gdf.dissolve(by="lsoa_code")
# Out:
# C:\Users\varun\AppData\Local\Temp\ipykernel_30948\1192006307.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   output_areas_gdf = pd.read_sql("SELECT *, ST_AsText(geometry) as geo_text FROM output_area_geometry", conn)

# %%
# %%sql
# DROP TABLE IF EXISTS lsoa_geometry;
# CREATE TABLE IF NOT EXISTS lsoa_geometry (
#     year INT NOT NULL,                    -- Year of the census
#
#     -- Area codes and names
#     code VARCHAR(9) NOT NULL,              -- LSOA code
#     name VARCHAR(100) NOT NULL,            -- LSOA name in English
#
#     -- Geometry
#     geometry GEOMETRY NOT NULL,            -- Geometry of the output area in WG84
#
#     -- Constraints
#     PRIMARY KEY (year, code)
# ) DEFAULT CHARSET=utf8 COLLATE=utf8_bin AUTO_INCREMENT=1;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 0 rows affected.
# 0 rows affected.
# []

# %%
lsoas[["lsoa_name", "geometry"]].to_csv("lsoas.csv", index=True, sep="|")

# %%
command = """
LOAD DATA LOCAL INFILE 'lsoas.csv' \
INTO TABLE lsoa_geometry \
FIELDS TERMINATED BY '|' \
OPTIONALLY ENCLOSED BY '"' \
LINES TERMINATED BY '\n' \
IGNORE 1 LINES \
(code, name, @geo) \
SET geometry = ST_GeomFromText(@geo, 4326), year = 2021;"""

# %sql $command
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 35672 rows affected.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS hours_worked;
# CREATE TABLE IF NOT EXISTS hours_worked (
#     -- Year of the census
#     year INT NOT NULL,
#
#     -- Geography identifiers
#     output_area VARCHAR(10) NOT NULL,
#
#     -- Population counts by hours worked
#     total_employed_over_16 INT NOT NULL,
#     part_time INT NOT NULL,
#     worked_15_hours_or_less INT NOT NULL,
#     worked_16_to_30_hours INT NOT NULL,
#     full_time INT NOT NULL,
#     worked_31_to_48_hours INT NOT NULL,
#     worked_49_hours_or_more INT NOT NULL,
#
#     -- Constraints
#     PRIMARY KEY (year, output_area),
#     CHECK (total_employed_over_16 >= 0),
#     CHECK (part_time >= 0),
#     CHECK (worked_15_hours_or_less >= 0),
#     CHECK (worked_16_to_30_hours >= 0),
#     CHECK (full_time >= 0),
#     CHECK (worked_31_to_48_hours >= 0),
#     CHECK (worked_49_hours_or_more >= 0)
# ) DEFAULT CHARSET=utf8 COLLATE=utf8_bin AUTO_INCREMENT=1;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 0 rows affected.
# 0 rows affected.
# []

# %%
command = """LOAD DATA LOCAL INFILE './census2021-ts059-oa.csv' INTO TABLE `hours_worked` \
FIELDS TERMINATED BY ',' \
OPTIONALLY ENCLOSED by '"' \
LINES STARTING BY '' \
TERMINATED BY '\\n' \
IGNORE 1 LINES \
(year, output_area, @geography_code, \
total_employed_over_16, part_time, \
worked_15_hours_or_less, worked_16_to_30_hours, \
full_time, worked_31_to_48_hours, \
worked_49_hours_or_more);"""

# %sql $command
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 188880 rows affected.
# []

# %%
tags_to_keep = ["amenity", "building", "landuse", "highway", "railway", "public_transport", "amenity_bike", "shop", "leisure", "office", "healthcare", "entertainment", "osmid", "geometry", "building:levels", "height"]
custom_filter = {t: True for t in tags_to_keep}

# %%
# make the buildings directory
if not os.path.exists("buildings"):
    os.makedirs("buildings")

# %%
constituencies = gpd.read_file("parl_constituencies_2025.gpkg")

constituencies.set_geometry("geometry", inplace=True)
constituencies.geometry.set_crs(epsg=4326, inplace=True)

# Ensure polygons are valid
constituencies.geometry = constituencies.geometry.buffer(0)

# %%
broken = []

columns = "amenity|building|id|building:levels|healthcare|height|highway|landuse|leisure|office|osm_id|osmid|public_transport|railway|shop|geometry".split("|")

for index, row in constituencies.iterrows():
    name = row["short_code"]

    # skip if the file already exists
    if os.path.exists(f"buildings/{name}_pois.geojson"):
        print(f"Already fetched features for {name}")
        continue

    # skip if broken
    if name in broken:
        print(f"Skipping {name}")
        continue

    print(f"Fetching features for {name}")

    try:
        pois = ox.features_from_polygon(row["geometry"], custom_filter)

        pois.columns = columns

        # parse height and levels
        pois["height"] = pois["height"].apply(lambda x: float(x) if pd.notnull(x) and x.replace('.', '', 1).isdigit() else None)
        pois["building:levels"] = pois["building:levels"].apply(lambda x: int(x) if pd.notnull(x) and x.isdigit() else None)

        available_tags = pois.columns.intersection(tags_to_keep)
        pois = pois.dropna(subset=["geometry"])
        
        print(f"Found {len(pois)} POIs in {name}")
        pois[available_tags].to_csv(f"buildings/{name}_pois.csv", index=False)
        print(f"Saved {name}_pois.csv: {index}/{len(constituencies)}")
    except Exception as e:
        print(f"Failed to fetch features for {name}: {e}")
        broken.append(name)
# Out:
# Already fetched features for UKPARL.2025.BAF
# Already fetched features for UKPARL.2025.GYM
# Already fetched features for UKPARL.2025.NNF
# Already fetched features for UKPARL.2025.MNF
# Already fetched features for UKPARL.2025.SWN
# Already fetched features for UKPARL.2025.NWN
# Already fetched features for UKPARL.2025.NEC
# Already fetched features for UKPARL.2025.EEC
# Already fetched features for UKPARL.2025.SCB
# Already fetched features for UKPARL.2025.CBG
# Already fetched features for UKPARL.2025.SNC
# Already fetched features for UKPARL.2025.HTD
# Already fetched features for UKPARL.2025.NWC
# Already fetched features for UKPARL.2025.PBO
# Already fetched features for UKPARL.2025.NBD
# Already fetched features for UKPARL.2025.BED
# Already fetched features for UKPARL.2025.MBD
# Already fetched features for UKPARL.2025.DLB
# Already fetched features for UKPARL.2025.LUS
# Already fetched features for UKPARL.2025.CLT
# Already fetched features for UKPARL.2025.HWC
# Already fetched features for UKPARL.2025.COL
# Already fetched features for UKPARL.2025.WTM
# Already fetched features for UKPARL.2025.MAL
# Already fetched features for UKPARL.2025.RAW
# Already fetched features for UKPARL.2025.CPT
# Already fetched features for UKPARL.2025.SBT
# Already fetched features for UKPARL.2025.THK
# Already fetched features for UKPARL.2025.BAB
# Already fetched features for UKPARL.2025.BAO
# Already fetched features for UKPARL.2025.EPF
# Already fetched features for UKPARL.2025.HLW
# Already fetched features for UKPARL.2025.CHM
# Already fetched features for UKPARL.2025.NWE
# Already fetched features for UKPARL.2025.BTR
# Already fetched features for UKPARL.2025.SSF
# Already fetched features for UKPARL.2025.IPS
# Already fetched features for UKPARL.2025.WSF
# Already fetched features for UKPARL.2025.BES
# Already fetched features for UKPARL.2025.CSI
# Already fetched features for UKPARL.2025.SFC
# Already fetched features for UKPARL.2025.WAV
# Already fetched features for UKPARL.2025.LWT
# Already fetched features for UKPARL.2025.SNF
# Already fetched features for UKPARL.2025.NRS
# Already fetched features for UKPARL.2025.NRN
# Already fetched features for UKPARL.2025.LUN
# Already fetched features for UKPARL.2025.HIT
# Already fetched features for UKPARL.2025.HNE
# Already fetched features for UKPARL.2025.SVG
# Already fetched features for UKPARL.2025.HAS
# Already fetched features for UKPARL.2025.WHT
# Already fetched features for UKPARL.2025.BXB
# Already fetched features for UKPARL.2025.HMR
# Already fetched features for UKPARL.2025.SWH
# Already fetched features for UKPARL.2025.WAT
# Already fetched features for UKPARL.2025.HML
# Already fetched features for UKPARL.2025.HAB
# Already fetched features for UKPARL.2025.STA
# Already fetched features for UKPARL.2025.SER
# Already fetched features for UKPARL.2025.SWL
# Already fetched features for UKPARL.2025.HPK
# Already fetched features for UKPARL.2025.DED
# Already fetched features for UKPARL.2025.SDE
# Already fetched features for UKPARL.2025.DES
# Already fetched features for UKPARL.2025.DEN
# Already fetched features for UKPARL.2025.ERW
# Already fetched features for UKPARL.2025.MDE
# Already fetched features for UKPARL.2025.ABV
# Fetching features for UKPARL.2025.NED
# Failed to fetch features for UKPARL.2025.NED: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=180)
# Already fetched features for UKPARL.2025.CHD
# Already fetched features for UKPARL.2025.BOL
# Already fetched features for UKPARL.2025.RUT
# Already fetched features for UKPARL.2025.GAB
# Already fetched features for UKPARL.2025.SLR
# Already fetched features for UKPARL.2025.LNC
# Already fetched features for UKPARL.2025.GNB
# Already fetched features for UKPARL.2025.LAH
# Already fetched features for UKPARL.2025.BAS
# Already fetched features for UKPARL.2025.SHD
# Already fetched features for UKPARL.2025.RCF
# Already fetched features for UKPARL.2025.NGS
# Already fetched features for UKPARL.2025.NGE
# Already fetched features for UKPARL.2025.NGN
# Already fetched features for UKPARL.2025.BXT
# Already fetched features for UKPARL.2025.ASF
# Already fetched features for UKPARL.2025.MAN
# Already fetched features for UKPARL.2025.GED
# Already fetched features for UKPARL.2025.SWF
# Already fetched features for UKPARL.2025.NWK
# Already fetched features for UKPARL.2025.BSL
# Already fetched features for UKPARL.2025.NHS
# Already fetched features for UKPARL.2025.SNH
# Already fetched features for UKPARL.2025.DAV
# Already fetched features for UKPARL.2025.NHN
# Already fetched features for UKPARL.2025.WBR
# Already fetched features for UKPARL.2025.COR
# Already fetched features for UKPARL.2025.KET
# Already fetched features for UKPARL.2025.HOW
# Already fetched features for UKPARL.2025.MLE
# Already fetched features for UKPARL.2025.SLE
# Already fetched features for UKPARL.2025.LEW
# Already fetched features for UKPARL.2025.LES
# Already fetched features for UKPARL.2025.LEE
# Already fetched features for UKPARL.2025.HKB
# Already fetched features for UKPARL.2025.NWL
# Already fetched features for UKPARL.2025.LBO
# Already fetched features for UKPARL.2025.MAS
# Already fetched features for UKPARL.2025.EWH
# Already fetched features for UKPARL.2025.ENF
# Already fetched features for UKPARL.2025.HSP
# Already fetched features for UKPARL.2025.HAY
# Already fetched features for UKPARL.2025.ELN
# Already fetched features for UKPARL.2025.ELS
# Already fetched features for UKPARL.2025.ECA
# Already fetched features for UKPARL.2025.CRW
# Already fetched features for UKPARL.2025.SCN
# Already fetched features for UKPARL.2025.CRE
# Already fetched features for UKPARL.2025.CBH
# Already fetched features for UKPARL.2025.DWN
# Already fetched features for UKPARL.2025.LWW
# Already fetched features for UKPARL.2025.VCG
# Already fetched features for UKPARL.2025.BOS
# Already fetched features for UKPARL.2025.LWN
# Already fetched features for UKPARL.2025.PKM
# Already fetched features for UKPARL.2025.LWE
# Already fetched features for UKPARL.2025.GAW
# Already fetched features for UKPARL.2025.EAC
# Already fetched features for UKPARL.2025.EAT
# Already fetched features for UKPARL.2025.BXC
# Already fetched features for UKPARL.2025.CWG
# Already fetched features for UKPARL.2025.WHW
# Already fetched features for UKPARL.2025.LAW
# Already fetched features for UKPARL.2025.ILN
# Already fetched features for UKPARL.2025.ILS
# Already fetched features for UKPARL.2025.BKG
# Already fetched features for UKPARL.2025.WHB
# Already fetched features for UKPARL.2025.EHM
# Already fetched features for UKPARL.2025.SAB
# Already fetched features for UKPARL.2025.PAL
# Already fetched features for UKPARL.2025.BGS
# Already fetched features for UKPARL.2025.HAW
# Already fetched features for UKPARL.2025.FEL
# Already fetched features for UKPARL.2025.TWI
# Already fetched features for UKPARL.2025.HAC
# Already fetched features for UKPARL.2025.BAI
# Already fetched features for UKPARL.2025.KAB
# Already fetched features for UKPARL.2025.OBS
# Already fetched features for UKPARL.2025.BAP
# Already fetched features for UKPARL.2025.QPK
# Already fetched features for UKPARL.2025.BEA
# Already fetched features for UKPARL.2025.BWE
# Already fetched features for UKPARL.2025.SWG
# Already fetched features for UKPARL.2025.FGG
# Already fetched features for UKPARL.2025.HEN
# Already fetched features for UKPARL.2025.CPB
# Already fetched features for UKPARL.2025.HFB
# Already fetched features for UKPARL.2025.TOT
# Already fetched features for UKPARL.2025.HSN
# Already fetched features for UKPARL.2025.PUT
# Already fetched features for UKPARL.2025.BAT
# Already fetched features for UKPARL.2025.TOO
# Already fetched features for UKPARL.2025.CAW
# Already fetched features for UKPARL.2025.SAC
# Already fetched features for UKPARL.2025.CRS
# Already fetched features for UKPARL.2025.ISN
# Already fetched features for UKPARL.2025.ISS
# Already fetched features for UKPARL.2025.HSD
# Already fetched features for UKPARL.2025.HAE
# Already fetched features for UKPARL.2025.CAF
# Already fetched features for UKPARL.2025.ORP
# Already fetched features for UKPARL.2025.BBH
# Already fetched features for UKPARL.2025.DAR
# Already fetched features for UKPARL.2025.HAU
# Already fetched features for UKPARL.2025.RMF
# Already fetched features for UKPARL.2025.MAM
# Already fetched features for UKPARL.2025.KAS
# Already fetched features for UKPARL.2025.WIM
# Already fetched features for UKPARL.2025.RPK
# Already fetched features for UKPARL.2025.UXB
# Already fetched features for UKPARL.2025.RNP
# Already fetched features for UKPARL.2025.CRK
# Already fetched features for UKPARL.2025.BAC
# Already fetched features for UKPARL.2025.HEX
# Already fetched features for UKPARL.2025.BAA
# Already fetched features for UKPARL.2025.GCW
# Already fetched features for UKPARL.2025.TYN
# Already fetched features for UKPARL.2025.NCN
# Already fetched features for UKPARL.2025.NCL
# Already fetched features for UKPARL.2025.NCE
# Already fetched features for UKPARL.2025.SUN
# Already fetched features for UKPARL.2025.SSH
# Already fetched features for UKPARL.2025.JGE
# Already fetched features for UKPARL.2025.DHM
# Already fetched features for UKPARL.2025.EAS
# Already fetched features for UKPARL.2025.HPL
# Already fetched features for UKPARL.2025.NDH
# Already fetched features for UKPARL.2025.WGS
# Already fetched features for UKPARL.2025.HSS
# Already fetched features for UKPARL.2025.BIA
# Already fetched features for UKPARL.2025.NAS
# Already fetched features for UKPARL.2025.SKN
# Already fetched features for UKPARL.2025.MTE
# Already fetched features for UKPARL.2025.MCL
# Already fetched features for UKPARL.2025.RED
# Already fetched features for UKPARL.2025.DRL
# Already fetched features for UKPARL.2025.SKW
# Already fetched features for UKPARL.2025.NNU
# Already fetched features for UKPARL.2025.LAA
# Already fetched features for UKPARL.2025.MKF
# Already fetched features for UKPARL.2025.CAR
# Already fetched features for UKPARL.2025.MOR
# Already fetched features for UKPARL.2025.LAN
# Already fetched features for UKPARL.2025.RIV
# Already fetched features for UKPARL.2025.BPS
# Already fetched features for UKPARL.2025.FYL
# Already fetched features for UKPARL.2025.PRE
# Already fetched features for UKPARL.2025.BUR
# Already fetched features for UKPARL.2025.PDL
# Already fetched features for UKPARL.2025.BPN
# Already fetched features for UKPARL.2025.BBN
# Already fetched features for UKPARL.2025.HYB
# Already fetched features for UKPARL.2025.RAD
# Already fetched features for UKPARL.2025.SOP
# Already fetched features for UKPARL.2025.SRI
# Already fetched features for UKPARL.2025.WLA
# Already fetched features for UKPARL.2025.SEF
# Already fetched features for UKPARL.2025.BTL
# Already fetched features for UKPARL.2025.RCD
# Already fetched features for UKPARL.2025.CRL
# Already fetched features for UKPARL.2025.BUN
# Already fetched features for UKPARL.2025.HMN
# Already fetched features for UKPARL.2025.BUS
# Already fetched features for UKPARL.2025.BLW
# Already fetched features for UKPARL.2025.BLN
# Already fetched features for UKPARL.2025.BLS
# Already fetched features for UKPARL.2025.LRV
# Already fetched features for UKPARL.2025.LWV
# Already fetched features for UKPARL.2025.LGT
# Already fetched features for UKPARL.2025.KNW
# Already fetched features for UKPARL.2025.OLE
# Already fetched features for UKPARL.2025.OLW
# Already fetched features for UKPARL.2025.LWL
# Already fetched features for UKPARL.2025.WGN
# Already fetched features for UKPARL.2025.WAH
# Already fetched features for UKPARL.2025.SHN
# Already fetched features for UKPARL.2025.BMS
# Already fetched features for UKPARL.2025.SAH
# Already fetched features for UKPARL.2025.AUL
# Already fetched features for UKPARL.2025.LWD
# Already fetched features for UKPARL.2025.SFD
# Already fetched features for UKPARL.2025.WSL
# Already fetched features for UKPARL.2025.SHS
# Already fetched features for UKPARL.2025.SAU
# Already fetched features for UKPARL.2025.WAS
# Already fetched features for UKPARL.2025.WAN
# Already fetched features for UKPARL.2025.ASW
# Already fetched features for UKPARL.2025.WYT
# Already fetched features for UKPARL.2025.MCT
# Already fetched features for UKPARL.2025.TAT
# Already fetched features for UKPARL.2025.GAD
# Already fetched features for UKPARL.2025.WIR
# Already fetched features for UKPARL.2025.MCH
# Already fetched features for UKPARL.2025.MRH
# Already fetched features for UKPARL.2025.MWI
# Already fetched features for UKPARL.2025.CHS
# Already fetched features for UKPARL.2025.CWN
# Already fetched features for UKPARL.2025.SPT
# Already fetched features for UKPARL.2025.WLL
# Already fetched features for UKPARL.2025.CNG
# Already fetched features for UKPARL.2025.MAC
# Already fetched features for UKPARL.2025.CHN
# Already fetched features for UKPARL.2025.CDL
# Already fetched features for UKPARL.2025.ELP
# Already fetched features for UKPARL.2025.BKH
# Already fetched features for UKPARL.2025.RAH
# Already fetched features for UKPARL.2025.WAL
# Already fetched features for UKPARL.2025.BRW
# Already fetched features for UKPARL.2025.HAZ
# Already fetched features for UKPARL.2025.PEN
# Already fetched features for UKPARL.2025.WAW
# Already fetched features for UKPARL.2025.BRL
# Already fetched features for UKPARL.2025.ASD
# Already fetched features for UKPARL.2025.AYS
# Already fetched features for UKPARL.2025.MKN
# Already fetched features for UKPARL.2025.MKC
# Already fetched features for UKPARL.2025.BUC
# Already fetched features for UKPARL.2025.MBU
# Already fetched features for UKPARL.2025.WYC
# Already fetched features for UKPARL.2025.BAN
# Already fetched features for UKPARL.2025.BWS
# Already fetched features for UKPARL.2025.HAT
# Already fetched features for UKPARL.2025.DAW
# Already fetched features for UKPARL.2025.WIT
# Already fetched features for UKPARL.2025.OXW
# Already fetched features for UKPARL.2025.OXE
# Already fetched features for UKPARL.2025.NBY
# Already fetched features for UKPARL.2025.RDW
# Already fetched features for UKPARL.2025.RDG
# Already fetched features for UKPARL.2025.EAR
# Already fetched features for UKPARL.2025.WKM
# Already fetched features for UKPARL.2025.BRK
# Already fetched features for UKPARL.2025.MAI
# Already fetched features for UKPARL.2025.SLO
# Already fetched features for UKPARL.2025.WND
# Already fetched features for UKPARL.2025.SPL
# Already fetched features for UKPARL.2025.RUN
# Already fetched features for UKPARL.2025.EAW
# Already fetched features for UKPARL.2025.EAE
# Already fetched features for UKPARL.2025.REI
# Already fetched features for UKPARL.2025.ESU
# Already fetched features for UKPARL.2025.DAH
# Already fetched features for UKPARL.2025.GUI
# Already fetched features for UKPARL.2025.GAA
# Already fetched features for UKPARL.2025.WOK
# Already fetched features for UKPARL.2025.SRH
# Already fetched features for UKPARL.2025.FAB
# Already fetched features for UKPARL.2025.EHA
# Already fetched features for UKPARL.2025.NEH
# Already fetched features for UKPARL.2025.BSK
# Already fetched features for UKPARL.2025.NWH
# Already fetched features for UKPARL.2025.RSO
# Already fetched features for UKPARL.2025.SOT
# Already fetched features for UKPARL.2025.SOI
# Already fetched features for UKPARL.2025.NFE
# Already fetched features for UKPARL.2025.NFW
# Already fetched features for UKPARL.2025.ESL
# Already fetched features for UKPARL.2025.HBV
# Already fetched features for UKPARL.2025.WIN
# Already fetched features for UKPARL.2025.FAW
# Already fetched features for UKPARL.2025.GOS
# Already fetched features for UKPARL.2025.PON
# Already fetched features for UKPARL.2025.POS
# Already fetched features for UKPARL.2025.HAV
# Already fetched features for UKPARL.2025.CCH
# Already fetched features for UKPARL.2025.WRH
# Already fetched features for UKPARL.2025.EWS
# Already fetched features for UKPARL.2025.AHT
# Already fetched features for UKPARL.2025.HAP
# Already fetched features for UKPARL.2025.MSU
# Already fetched features for UKPARL.2025.HRH
# Already fetched features for UKPARL.2025.CRA
# Already fetched features for UKPARL.2025.EBN
# Already fetched features for UKPARL.2025.BEX
# Already fetched features for UKPARL.2025.HAR
# Already fetched features for UKPARL.2025.TNW
# Already fetched features for UKPARL.2025.GRV
# Already fetched features for UKPARL.2025.RAS
# Already fetched features for UKPARL.2025.CTM
# Already fetched features for UKPARL.2025.GAR
# Already fetched features for UKPARL.2025.SAS
# Already fetched features for UKPARL.2025.ASH
# Already fetched features for UKPARL.2025.FAH
# Already fetched features for UKPARL.2025.DAD
# Already fetched features for UKPARL.2025.CTB
# Already fetched features for UKPARL.2025.HBS
# Already fetched features for UKPARL.2025.ETH
# Already fetched features for UKPARL.2025.IWW
# Already fetched features for UKPARL.2025.IWE
# Already fetched features for UKPARL.2025.BCF
# Already fetched features for UKPARL.2025.BPV
# Already fetched features for UKPARL.2025.BKP
# Already fetched features for UKPARL.2025.CAA
# Already fetched features for UKPARL.2025.DFD
# Already fetched features for UKPARL.2025.EGU
# Already fetched features for UKPARL.2025.FAV
# Already fetched features for UKPARL.2025.LWS
# Already fetched features for UKPARL.2025.MDS
# Already fetched features for UKPARL.2025.SEV
# Already fetched features for UKPARL.2025.SXW
# Already fetched features for UKPARL.2025.TON
# Already fetched features for UKPARL.2025.WKT
# Already fetched features for UKPARL.2025.FES
# Already fetched features for UKPARL.2025.GAS
# Already fetched features for UKPARL.2025.MDP
# Already fetched features for UKPARL.2025.SDS
# Already fetched features for UKPARL.2025.NDS
# Already fetched features for UKPARL.2025.WDS
# Already fetched features for UKPARL.2025.BSC
# Already fetched features for UKPARL.2025.BSS
# Already fetched features for UKPARL.2025.BSE
# Already fetched features for UKPARL.2025.BNW
# Already fetched features for UKPARL.2025.BNE
# Already fetched features for UKPARL.2025.FBS
# Already fetched features for UKPARL.2025.TAY
# Already fetched features for UKPARL.2025.NES
# Already fetched features for UKPARL.2025.BTH
# Already fetched features for UKPARL.2025.WSM
# Already fetched features for UKPARL.2025.WEL
# Already fetched features for UKPARL.2025.NSS
# Already fetched features for UKPARL.2025.BWT
# Already fetched features for UKPARL.2025.PLE
# Already fetched features for UKPARL.2025.BHW
# Already fetched features for UKPARL.2025.BHE
# Already fetched features for UKPARL.2025.CHR
# Already fetched features for UKPARL.2025.TEW
# Already fetched features for UKPARL.2025.NCT
# Already fetched features for UKPARL.2025.CNM
# Already fetched features for UKPARL.2025.GLO
# Already fetched features for UKPARL.2025.FOD
# Already fetched features for UKPARL.2025.STR
# Already fetched features for UKPARL.2025.SCT
# Already fetched features for UKPARL.2025.SNN
# Already fetched features for UKPARL.2025.SNS
# Already fetched features for UKPARL.2025.CPM
# Already fetched features for UKPARL.2025.MKM
# Already fetched features for UKPARL.2025.EWT
# Already fetched features for UKPARL.2025.SAL
# Already fetched features for UKPARL.2025.SWW
# Already fetched features for UKPARL.2025.YEO
# Already fetched features for UKPARL.2025.TAW
# Already fetched features for UKPARL.2025.TIV
# Already fetched features for UKPARL.2025.HNS
# Already fetched features for UKPARL.2025.EXM
# Already fetched features for UKPARL.2025.EXT
# Already fetched features for UKPARL.2025.NTA
# Already fetched features for UKPARL.2025.TRB
# Already fetched features for UKPARL.2025.SDV
# Already fetched features for UKPARL.2025.PMV
# Already fetched features for UKPARL.2025.PSD
# Already fetched features for UKPARL.2025.NDV
# Already fetched features for UKPARL.2025.TAV
# Already fetched features for UKPARL.2025.SWD
# Already fetched features for UKPARL.2025.CDV
# Already fetched features for UKPARL.2025.NCR
# Already fetched features for UKPARL.2025.SEC
# Already fetched features for UKPARL.2025.SNQ
# Already fetched features for UKPARL.2025.TRF
# Already fetched features for UKPARL.2025.STV
# Already fetched features for UKPARL.2025.CRR
# Already fetched features for UKPARL.2025.BPB
# Already fetched features for UKPARL.2025.BER
# Already fetched features for UKPARL.2025.KLW
# Already fetched features for UKPARL.2025.WKL
# Already fetched features for UKPARL.2025.DAE
# Already fetched features for UKPARL.2025.RUG
# Already fetched features for UKPARL.2025.NUN
# Already fetched features for UKPARL.2025.NWB
# Already fetched features for UKPARL.2025.SUT
# Already fetched features for UKPARL.2025.BSN
# Already fetched features for UKPARL.2025.BLA
# Already fetched features for UKPARL.2025.BEB
# Already fetched features for UKPARL.2025.BNF
# Already fetched features for UKPARL.2025.BSO
# Already fetched features for UKPARL.2025.BHG
# Already fetched features for UKPARL.2025.BYA
# Already fetched features for UKPARL.2025.SWS
# Already fetched features for UKPARL.2025.HRS
# Already fetched features for UKPARL.2025.WWR
# Already fetched features for UKPARL.2025.WOR
# Already fetched features for UKPARL.2025.WYF
# Already fetched features for UKPARL.2025.RDC
# Already fetched features for UKPARL.2025.CEA
# Already fetched features for UKPARL.2025.CNW
# Already fetched features for UKPARL.2025.SSO
# Already fetched features for UKPARL.2025.SHR
# Already fetched features for UKPARL.2025.TFD
# Already fetched features for UKPARL.2025.WRK
# Already fetched features for UKPARL.2025.NSO
# Already fetched features for UKPARL.2025.WWE
# Already fetched features for UKPARL.2025.ABH
# Already fetched features for UKPARL.2025.WAB
# Already fetched features for UKPARL.2025.DUD
# Already fetched features for UKPARL.2025.HAL
# Already fetched features for UKPARL.2025.SBR
# Already fetched features for UKPARL.2025.SMK
# Already fetched features for UKPARL.2025.KSS
# Already fetched features for UKPARL.2025.TMW
# Already fetched features for UKPARL.2025.LIC
# Already fetched features for UKPARL.2025.BAU
# Already fetched features for UKPARL.2025.NUL
# Already fetched features for UKPARL.2025.STM
# Already fetched features for UKPARL.2025.STN
# Already fetched features for UKPARL.2025.STC
# Already fetched features for UKPARL.2025.STS
# Already fetched features for UKPARL.2025.CKC
# Already fetched features for UKPARL.2025.SGW
# Already fetched features for UKPARL.2025.STF
# Already fetched features for UKPARL.2025.WNE
# Already fetched features for UKPARL.2025.WSE
# Already fetched features for UKPARL.2025.TIP
# Already fetched features for UKPARL.2025.SOA
# Already fetched features for UKPARL.2025.NHR
# Already fetched features for UKPARL.2025.MSE
# Already fetched features for UKPARL.2025.CSO
# Already fetched features for UKPARL.2025.BRG
# Already fetched features for UKPARL.2025.WBW
# Already fetched features for UKPARL.2025.GAP
# Already fetched features for UKPARL.2025.BRD
# Already fetched features for UKPARL.2025.SHA
# Already fetched features for UKPARL.2025.SCE
# Already fetched features for UKPARL.2025.SBH
# Already fetched features for UKPARL.2025.SHE
# Already fetched features for UKPARL.2025.SSE
# Already fetched features for UKPARL.2025.PAS
# Already fetched features for UKPARL.2025.BNN
# Already fetched features for UKPARL.2025.BNS
# Already fetched features for UKPARL.2025.RAC
# Already fetched features for UKPARL.2025.RHM
# Already fetched features for UKPARL.2025.RHV
# Already fetched features for UKPARL.2025.DNC
# Already fetched features for UKPARL.2025.DNN
# Already fetched features for UKPARL.2025.DNE
# Already fetched features for UKPARL.2025.SCU
# Already fetched features for UKPARL.2025.BIM
# Already fetched features for UKPARL.2025.GGC
# Already fetched features for UKPARL.2025.HUW
# Already fetched features for UKPARL.2025.HUN
# Already fetched features for UKPARL.2025.HUE
# Already fetched features for UKPARL.2025.BEV
# Already fetched features for UKPARL.2025.SBY
# Already fetched features for UKPARL.2025.WAE
# Already fetched features for UKPARL.2025.HGK
# Already fetched features for UKPARL.2025.SAR
# Already fetched features for UKPARL.2025.RAN
# Already fetched features for UKPARL.2025.TAM
# Already fetched features for UKPARL.2025.SAW
# Already fetched features for UKPARL.2025.YOO
# Already fetched features for UKPARL.2025.YOC
# Already fetched features for UKPARL.2025.PCK
# Already fetched features for UKPARL.2025.DAB
# Already fetched features for UKPARL.2025.NAH
# Already fetched features for UKPARL.2025.HFX
# Already fetched features for UKPARL.2025.WKF
# Already fetched features for UKPARL.2025.ODB
# Already fetched features for UKPARL.2025.COV
# Already fetched features for UKPARL.2025.HUD
# Already fetched features for UKPARL.2025.SPV
# Already fetched features for UKPARL.2025.CAV
# Already fetched features for UKPARL.2025.KAI
# Already fetched features for UKPARL.2025.BDE
# Already fetched features for UKPARL.2025.SHY
# Already fetched features for UKPARL.2025.LCH
# Already fetched features for UKPARL.2025.BDW
# Already fetched features for UKPARL.2025.BDS
# Already fetched features for UKPARL.2025.LSW
# Already fetched features for UKPARL.2025.LWP
# Already fetched features for UKPARL.2025.LNE
# Already fetched features for UKPARL.2025.LEA
# Already fetched features for UKPARL.2025.LNW
# Already fetched features for UKPARL.2025.LSO
# Already fetched features for UKPARL.2025.CLW
# Already fetched features for UKPARL.2025.HAH
# Already fetched features for UKPARL.2025.BRS
# Already fetched features for UKPARL.2025.ABF
# Already fetched features for UKPARL.2025.DFR
# Already fetched features for UKPARL.2025.AAS
# Already fetched features for UKPARL.2025.EKS
# Already fetched features for UKPARL.2025.ERF
# Already fetched features for UKPARL.2025.EEM
# Already fetched features for UKPARL.2025.ENL
# Already fetched features for UKPARL.2025.ESW
# Already fetched features for UKPARL.2025.AAG
# Already fetched features for UKPARL.2025.GSW
# Already fetched features for UKPARL.2025.IRW
# Already fetched features for UKPARL.2025.KAL
# Already fetched features for UKPARL.2025.LVG
# Already fetched features for UKPARL.2025.MID
# Already fetched features for UKPARL.2025.MWC
# Already fetched features for UKPARL.2025.PRS
# Already fetched features for UKPARL.2025.APG
# Already fetched features for UKPARL.2025.STG
# Already fetched features for UKPARL.2025.WDB
# Already fetched features for UKPARL.2025.MNS
# Already fetched features for UKPARL.2025.ABL
# Already fetched features for UKPARL.2025.WAK
# Already fetched features for UKPARL.2025.GDB
# Already fetched features for UKPARL.2025.CKY
# Already fetched features for UKPARL.2025.ABS
# Already fetched features for UKPARL.2025.EWE
# Already fetched features for UKPARL.2025.LOE
# Already fetched features for UKPARL.2025.ACC
# Already fetched features for UKPARL.2025.CAY
# Already fetched features for UKPARL.2025.OAS
# Already fetched features for UKPARL.2025.NHI
# Already fetched features for UKPARL.2025.NAA
# Already fetched features for UKPARL.2025.PHK
# Already fetched features for UKPARL.2025.DUN
# Already fetched features for UKPARL.2025.FLK
# Already fetched features for UKPARL.2025.BAL
# Already fetched features for UKPARL.2025.ISW
# Already fetched features for UKPARL.2025.ESO
# Already fetched features for UKPARL.2025.DAG
# Already fetched features for UKPARL.2025.PRN
# Already fetched features for UKPARL.2025.ABM
# Already fetched features for UKPARL.2025.CSR
# Already fetched features for UKPARL.2025.GEA
# Already fetched features for UKPARL.2025.MDB
# Already fetched features for UKPARL.2025.GNO
# Already fetched features for UKPARL.2025.GSO
# Already fetched features for UKPARL.2025.GWE
# Already fetched features for UKPARL.2025.CKH
# Already fetched features for UKPARL.2025.CAB
# Already fetched features for UKPARL.2025.HCV
# Already fetched features for UKPARL.2025.RGN
# Already fetched features for UKPARL.2025.GNE
# Already fetched features for UKPARL.2025.ABN
# Already fetched features for UKPARL.2025.DCT
# Already fetched features for UKPARL.2025.NEF
# Already fetched features for UKPARL.2025.GMF
# Already fetched features for UKPARL.2025.AFM
# Already fetched features for UKPARL.2025.AAD
# Already fetched features for UKPARL.2025.BGA
# Already fetched features for UKPARL.2025.BGR
# Already fetched features for UKPARL.2025.BRC
# Already fetched features for UKPARL.2025.BGN
# Already fetched features for UKPARL.2025.CAN
# Already fetched features for UKPARL.2025.CAE
# Already fetched features for UKPARL.2025.CFE
# Already fetched features for UKPARL.2025.CFN
# Already fetched features for UKPARL.2025.CFP
# Already fetched features for UKPARL.2025.CFW
# Already fetched features for UKPARL.2025.CDP
# Already fetched features for UKPARL.2025.CLE
# Already fetched features for UKPARL.2025.CLN
# Already fetched features for UKPARL.2025.DMD
# Already fetched features for UKPARL.2025.GWR
# Already fetched features for UKPARL.2025.LLE
# Already fetched features for UKPARL.2025.MTA
# Already fetched features for UKPARL.2025.MSP
# Already fetched features for UKPARL.2025.MMS
# Already fetched features for UKPARL.2025.MAG
# Already fetched features for UKPARL.2025.NSW
# Already fetched features for UKPARL.2025.NPE
# Already fetched features for UKPARL.2025.NPI
# Already fetched features for UKPARL.2025.PPD
# Already fetched features for UKPARL.2025.RAO
# Already fetched features for UKPARL.2025.SWT
# Already fetched features for UKPARL.2025.TOR
# Already fetched features for UKPARL.2025.VOG
# Already fetched features for UKPARL.2025.WRE
# Already fetched features for UKPARL.2025.YNM
# Already fetched features for UKPARL.2025.EAN
# Already fetched features for UKPARL.2025.SAN
# Already fetched features for UKPARL.2025.LGV
# Already fetched features for UKPARL.2025.UBN
# Already fetched features for UKPARL.2025.BTN
# Already fetched features for UKPARL.2025.ELD
# Already fetched features for UKPARL.2025.WTY
# Already fetched features for UKPARL.2025.FOY
# Already fetched features for UKPARL.2025.NAN
# Already fetched features for UKPARL.2025.MUL
# Already fetched features for UKPARL.2025.FST
# Already fetched features for UKPARL.2025.SDW
# Already fetched features for UKPARL.2025.NDW
# Already fetched features for UKPARL.2025.SGF
# Already fetched features for UKPARL.2025.BTE
# Already fetched features for UKPARL.2025.BTW
# Already fetched features for UKPARL.2025.BTS
# Already fetched features for UKPARL.2025.NAR

# %%
for i, name in enumerate(broken):
    # skip if the file already exists
    if os.path.exists(f"buildings/{name}_pois.geojson"):
        print(f"Already fetched features for {name}")
        continue
    
    row = constituencies[constituencies["short_code"] == name]
    bbox = row.envelope.iloc[0]

    print(f"Fetching features for {name}")
    pois = ox.features_from_polygon(bbox, custom_filter)

    pois.columns = columns

    # parse height and levels
    pois["height"] = pois["height"].apply(lambda x: float(x) if pd.notnull(x) and x.replace('.', '', 1).isdigit() else None)
    pois["building:levels"] = pois["building:levels"].apply(lambda x: int(x) if pd.notnull(x) and x.isdigit() else None)

    available_tags = pois.columns.intersection(tags_to_keep)
    pois = pois.dropna(subset=["geometry"])
    print(f"Found {len(pois)} POIs in {name}")
    pois[available_tags].to_csv(f"buildings/{name}_pois.csv", index=False)
    print(f"Saved {name}_pois.csv: {i}/{len(broken)}")

# %%
# %%sql
# DROP TABLE IF EXISTS osm_features;
# CREATE TABLE IF NOT EXISTS osm_features (
#     osmid BIGINT NOT NULL,
#     geometry GEOMETRY NOT NULL,
#
#     -- Tags
#     building VARCHAR(255),
#     building:levels INT,
#     height FLOAT,
#
#     amenity VARCHAR(255),
#     shop VARCHAR(255),
#     tourism VARCHAR(255),
#     leisure VARCHAR(255),
#     healthcare VARCHAR(255),
#     office VARCHAR(255),
#     craft VARCHAR(255),
#     sport VARCHAR(255),
#     highway VARCHAR(255),
#     landuse VARCHAR(255),
#     public_transport VARCHAR(255),
#     railway VARCHAR(255),
#
#     -- Constraints
#     PRIMARY KEY (osmid),
#     CHECK (osmid >= 0)
# ) DEFAULT CHARSET=utf8 COLLATE=utf8_bin AUTO_INCREMENT=1;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 0 rows affected.
# 0 rows affected.
# []

# %%
for file in os.listdir("buildings"):
    if not file.endswith(".csv"):
        continue

    name = file.split("_")[0]
    print(f"Processing {name}")

    command = f"""
LOAD DATA LOCAL INFILE 'buildings/{file}' \
INTO TABLE osm_features \
FIELDS TERMINATED BY '|' \
ENCLOSED BY '"' \
LINES TERMINATED BY '\n' \
IGNORE 1 LINES \
(amenity, building, @id, levels, healthcare, height, highway, landuse, leisure, office, @osm_id, osmid, public_transport, railway, shop, @geometry) \
SET geometry = ST_GeomFromText(@geometry, 4326);"""
    
    # %sql $command

# %%
# error at buildings/412_pois.csv

pois = pd.read_csv("buildings/412_pois.csv", sep="|")
pois["geometry"] = pois["geometry"].apply(shp.wkt.loads)
pois["geometry"] = pois["geometry"].apply(lambda x: x if x.is_valid else x.buffer(0))

# convert back to wkt
pois["geometry"] = pois["geometry"].apply(shp.wkt.dumps)

chunks = 100

for i in range(0, len(pois), chunks):
    print(f"Processing {i} to {i+chunks}")
    pois.iloc[i:i+chunks].to_csv(f"buildings/412_{i}_pois.csv", index=False, sep="|")

    command = f"""
    LOAD DATA LOCAL INFILE 'buildings/412_{i}_pois.csv' \
    INTO TABLE osm_features \
    FIELDS TERMINATED BY '|' \
    ENCLOSED BY '"' \
    LINES TERMINATED BY '\n' \
    IGNORE 1 LINES \
    (amenity, building, @id, levels, healthcare, height, highway, landuse, leisure, office, @osm_id, osmid, public_transport, railway, shop, @geometry) \
    SET geometry = ST_GeomFromText(@geometry, 4326);"""

    # %sql $command
# Out:
# Processing 0 to 100
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 100 to 200
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 200 to 300
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 300 to 400
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 400 to 500
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 500 to 600
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 600 to 700
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 700 to 800
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 800 to 900
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 900 to 1000
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 1000 to 1100
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 1100 to 1200
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 1200 to 1300
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 1300 to 1400
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 1400 to 1500
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 1500 to 1600
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 1600 to 1700
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 1700 to 1800
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 1800 to 1900
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 1900 to 2000
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 2000 to 2100
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 2100 to 2200
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 2200 to 2300
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 2300 to 2400
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 2400 to 2500
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 2500 to 2600
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 2600 to 2700
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 2700 to 2800
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 2800 to 2900
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 2900 to 3000
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 3000 to 3100
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 3100 to 3200
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 3200 to 3300
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 3300 to 3400
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 3400 to 3500
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 3500 to 3600
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 3600 to 3700
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 3700 to 3800
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 3800 to 3900
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 3900 to 4000
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 4000 to 4100
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 4100 to 4200
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 4200 to 4300
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 4300 to 4400
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 4400 to 4500
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 4500 to 4600
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# (pymysql.err.OperationalError) (3673, "Column 'geometry' cannot be null")
# [SQL: LOAD DATA LOCAL INFILE 'buildings/412_4500_pois.csv' INTO TABLE osm_features FIELDS TERMINATED BY '|' ENCLOSED BY '' LINES TERMINATED BY '
# ' IGNORE 1 LINES (amenity, building, @id, levels, healthcare, height, highway, landuse, leisure, office, @osm_id, osmid, public_transport, railway, shop, @geometry) SET geometry = ST_GeomFromText(@geometry, 4326);]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Processing 4600 to 4700
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 4700 to 4800
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 4800 to 4900
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 4900 to 5000
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 5000 to 5100
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 5100 to 5200
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 5200 to 5300
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 5300 to 5400
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 5400 to 5500
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 5500 to 5600
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 5600 to 5700
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 5700 to 5800
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 5800 to 5900
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 5900 to 6000
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 6000 to 6100
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 6100 to 6200
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 100 rows affected.
# Processing 6200 to 6300
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 79 rows affected.

# %%
# the issue is in 4500 to 4600

pois = pd.read_csv("buildings/412_4500_pois.csv", sep="|")

for idx, row in pois.iterrows():
    command = "INSERT INTO osm_features (amenity, building, levels, healthcare, height, highway, landuse, leisure, office, osmid, public_transport, railway, shop, geometry) VALUES ("

    for col in pois.columns:
        if col == "geometry":
            command += f"ST_GeomFromText('{row[col]}'),"
        elif col in ["id", "osm_id"]:
            continue
        elif isinstance(row[col], float) and np.isnan(row[col]):
            command += f"NULL,"
        else:
            command += f"'{row[col]}',"

    command = command.rstrip(",") + ");"

    # %sql $command
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near '783051370',NULL,NULL,NULL,ST_GeomFromText('POLYGON ((0.2222896000000000 52.18079' at line 1")
# [SQL: INSERT INTO osm_features (amenity, building, levels, healthcare, height, highway, landuse, leisure, office, osmid, public_transport, railway, shop, geometry) VALUES (NULL,'residential','\',NULL,NULL,NULL,NULL,NULL,NULL,'783051370',NULL,NULL,NULL,ST_GeomFromText('POLYGON ((0.2222896000000000 52.1807997000000015, 0.2222574000000000 52.1807574000000045, 0.2221408000000000 52.1807908000000040, 0.2221951000000000 52.1808621000000059, 0.2221649000000000 52.1808708000000010, 0.2221996000000000 52.1809162999999998, 0.2222835000000000 52.1808923000000036, 0.2223303000000000 52.1809538000000046, 0.2224372000000000 52.1809232000000023, 0.2223925000000000 52.1808644000000044, 0.2223576000000000 52.1808661000000029, 0.2223305000000000 52.1808305000000061, 0.2222765000000000 52.1808459000000013, 0.2222500000000000 52.1808111000000068, 0.2222896000000000 52.1807997000000015))'));]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.

# %%
for col in ["building", "amenity", "shop", "tourism", "leisure", "healthcare", "office", "craft", "sport", "highway", "landuse", "public_transport", "railway"]:
    # set empty strings to NULL
    # %sql UPDATE osm_features SET $col = NULL WHERE $col = '';

# %%
# census nssec table
# %sql ALTER TABLE census_nssec ADD INDEX idx_output_area (output_area);
# output area geometry table
# %sql ALTER TABLE oas ADD SPATIAL INDEX idx_geometry (geometry);
# hours worked
# %sql ALTER TABLE hours_worked ADD INDEX idx_output_area (output_area);
# osm features
# %sql ALTER TABLE osm_features ADD SPATIAL INDEX idx_geometry (geometry);
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 0 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# (pymysql.err.OperationalError) (1061, "Duplicate key name 'idx_geometry'")
# [SQL: ALTER TABLE output_area_geometry ADD SPATIAL INDEX idx_geometry (geometry);]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# (pymysql.err.OperationalError) (1061, "Duplicate key name 'idx_geometry'")
# [SQL: ALTER TABLE lsoa_geometry ADD SPATIAL INDEX idx_geometry (geometry);]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 0 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# (pymysql.err.OperationalError) (1061, "Duplicate key name 'idx_geometry'")
# [SQL: ALTER TABLE osm_features ADD SPATIAL INDEX idx_geometry (geometry);]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %%sql
# ALTER TABLE osm_features ADD INDEX idx_building (building),
# ADD INDEX idx_levels (levels),
# ADD INDEX idx_height (height),
# ADD INDEX idx_amenity (amenity),
# ADD INDEX idx_shop (shop),
# ADD INDEX idx_tourism (tourism),
# ADD INDEX idx_leisure (leisure),
# ADD INDEX idx_healthcare (healthcare),
# ADD INDEX idx_office (office),
# ADD INDEX idx_craft (craft),
# ADD INDEX idx_sport (sport),
# ADD INDEX idx_highway (highway),
# ADD INDEX idx_landuse (landuse),
# ADD INDEX idx_public_transport (public_transport),
# ADD INDEX idx_railway (railway);
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 0 rows affected.
# []

# %% [markdown]
# Write a short paragraph summarising what you did in the Access stage.

# %% [markdown]
# ## Assess

# %%
oas = pd.read_sql("SELECT *, ST_AsText(geometry) as geo_text FROM output_area_geometry", conn)
oas["geometry"] = oas["geo_text"].apply(shp.wkt.loads)
oas = gpd.GeoDataFrame(oas, geometry="geometry", crs="EPSG:4326")
# Out:
# C:\Users\varun\AppData\Local\Temp\ipykernel_38248\1280060622.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   oas = pd.read_sql("SELECT *, ST_AsText(geometry) as geo_text FROM output_area_geometry", conn)

# %%
# lsoas for graphing
lsoas = pd.read_sql("SELECT *, ST_AsText(geometry) as geo_text FROM lsoa_geometry", conn)
lsoas["geometry"] = lsoas["geo_text"].apply(shp.wkt.loads)
lsoas = gpd.GeoDataFrame(lsoas, geometry="geometry", crs="EPSG:4326")

lsoas["centroid"] = lsoas["geometry"].to_crs(epsg=27700).centroid.to_crs(epsg=4326)
lsoas["lat"] = lsoas["centroid"].y
lsoas["lon"] = lsoas["centroid"].x

if not os.path.exists("lsoas.psv"):
    lsoas[["year", "code", "lat", "lon"]].to_csv("lsoas.psv", index=False, sep="|")

lsoas.set_index("code", inplace=True)
# Out:
# C:\Users\varun\AppData\Local\Temp\ipykernel_16392\4169001930.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   lsoas = pd.read_sql("SELECT *, ST_AsText(geometry) as geo_text FROM lsoa_geometry", conn)

# %%
# %%sql
# DROP TABLE IF EXISTS lsoa_coords;
# CREATE TABLE IF NOT EXISTS lsoa_coords (
#     year INT NOT NULL,
#     code VARCHAR(9) NOT NULL,
#     latitude DOUBLE NOT NULL,
#     longitude DOUBLE NOT NULL,
#     PRIMARY KEY (year, code)
# ) DEFAULT CHARSET=utf8 COLLATE=utf8_bin AUTO_INCREMENT=1;
# LOAD DATA LOCAL INFILE 'lsoas.psv' INTO TABLE lsoa_coords FIELDS TERMINATED BY '|' OPTIONALLY ENCLOSED BY '"' LINES TERMINATED BY '\n' IGNORE 1 LINES (year, code, latitude, longitude);
# ALTER TABLE lsoa_coords ADD INDEX idx_code (code), ADD INDEX idx_coords (latitude, longitude);
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 0 rows affected.
# []

# %%
# get the lat and long of the osm features
osm_geometries = pd.read_sql("SELECT osmid, ST_AsText(geometry) as geo_text FROM osm_features", conn)
osm_geometries["geometry"] = osm_geometries["geo_text"].apply(shp.wkt.loads)
osm_geometries = gpd.GeoDataFrame(osm_geometries, geometry="geometry", crs="EPSG:4326")
# Out:
# C:\Users\varun\AppData\Local\Temp\ipykernel_43760\1375604788.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   osm_geometries = pd.read_sql("SELECT osmid, ST_AsText(geometry) as geo_text FROM osm_features", conn)

# %%
osm_geometries["centroid"] = osm_geometries["geometry"].to_crs(epsg=27700).centroid.to_crs(epsg=4326)
osm_geometries["lat"] = osm_geometries["centroid"].y
osm_geometries["lon"] = osm_geometries["centroid"].x

osm_geometries[["osmid", "lat", "lon"]].to_csv("osm_geometries.psv", index=False, sep="|")

# %%
# %%sql
# DROP TABLE IF EXISTS osm_coords;
# CREATE TABLE IF NOT EXISTS osm_coords (
#     osmid BIGINT NOT NULL,
#     latitude DECIMAL(10,8) NOT NULL,
#     longitude DECIMAL(11,8) NOT NULL,
#     PRIMARY KEY (osmid)
# ) DEFAULT CHARSET=utf8 COLLATE=utf8_bin AUTO_INCREMENT=1;
# LOAD DATA LOCAL INFILE 'osm_geometries.psv' INTO TABLE osm_coords FIELDS TERMINATED BY '|' OPTIONALLY ENCLOSED BY '"' LINES TERMINATED BY '\n' IGNORE 1 LINES (osmid, latitude, longitude);
# ALTER TABLE osm_coords ADD INDEX idx_coords (latitude, longitude);
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 0 rows affected.
# 0 rows affected.
# 4081533 rows affected.
# 0 rows affected.
# []

# %%
radius = 1000

# %%
all_university_buildings = pd.read_sql(f"""
SELECT osmid, ST_AsText(geometry) as geo_text
FROM osm_features
JOIN osm_coords USING (osmid)
WHERE amenity = 'university'
""", conn)
# Out:
# C:\Users\varun\AppData\Local\Temp\ipykernel_38248\153438529.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   all_university_buildings = pd.read_sql(f"""

# %%
# join oas and all_university_buildings by distance < radius
all_university_buildings["geometry"] = all_university_buildings["geo_text"].apply(shp.wkt.loads)
all_university_buildings.drop(columns=["geo_text"], inplace=True)
all_university_buildings = gpd.GeoDataFrame(all_university_buildings, geometry="geometry", crs="EPSG:4326")
all_university_buildings.head()
# Out:
#      osmid                                           geometry
# 0    70982  MULTIPOINT (-2.08839 51.88776, -2.08816 51.887...
# 1   158500  POLYGON ((-0.29707 51.40534, -0.29726 51.40526...
# 2   377796  MULTIPOLYGON (((-1.18419 52.94914, -1.18337 52...
# 3   536135  MULTIPOLYGON (((-0.47360 51.53215, -0.47360 51...
# 4  1411412  POLYGON ((-1.32656 51.06160, -1.32647 51.06075...

# %%
oas_to_join = oas.drop(columns=["year", "lsoa_name", "bng_easting", "bng_northing", "global_id", "geo_text"])
oas_to_join.rename(columns={"geometry": "oa_geometry", "latitude": "oa_lat", "longitude": "oa_lon"}, inplace=True)
oas_to_join["radius"] = oas_to_join["oa_geometry"].to_crs(epsg=27700).buffer(radius).to_crs(epsg=4326)
oas_to_join.set_geometry("radius", inplace=True)
oas_to_join.head()
# Out:
#         code  lsoa_code    oa_lat   oa_lon  \
# 0  E00000001  E01000001  51.52022 -0.09523
# 1  E00000003  E01000001  51.51983 -0.09638
# 2  E00000005  E01000001  51.51896 -0.09649
# 3  E00000007  E01000001  51.51674 -0.09771
# 4  E00000010  E01000003  51.52250 -0.09741
#
#                                          oa_geometry  \
# 0  POLYGON ((-0.09450 51.51976, -0.09579 51.52007...
# 1  POLYGON ((-0.09579 51.52007, -0.09614 51.51962...
# 2  POLYGON ((-0.09630 51.51933, -0.09576 51.51879...
# 3  POLYGON ((-0.09603 51.51847, -0.09508 51.51824...
# 4  POLYGON ((-0.09691 51.52267, -0.09749 51.52217...
#
#                                               radius
# 0  POLYGON ((-0.10136 51.51179, -0.10209 51.51195...
# 1  POLYGON ((-0.10537 51.51235, -0.10561 51.51245...
# 2  POLYGON ((-0.08382 51.52383, -0.08353 51.52355...
# 3  POLYGON ((-0.10949 51.51014, -0.11050 51.51078...
# 4  POLYGON ((-0.09049 51.53071, -0.08928 51.53029...

# %%
oa_university_in_radius = gpd.sjoin(all_university_buildings, oas_to_join, predicate="intersects")
oa_university_in_radius["distance"] = oa_university_in_radius["oa_geometry"].to_crs(epsg=27700).distance(oa_university_in_radius["geometry"].to_crs(epsg=27700))
oa_university_in_radius.head()
# Out:
#    osmid                                           geometry  index_right  \
# 0  70982  MULTIPOINT (-2.08839 51.88776, -2.08816 51.887...       106521
# 0  70982  MULTIPOINT (-2.08839 51.88776, -2.08816 51.887...       106516
# 0  70982  MULTIPOINT (-2.08839 51.88776, -2.08816 51.887...       106506
# 0  70982  MULTIPOINT (-2.08839 51.88776, -2.08816 51.887...       106514
# 0  70982  MULTIPOINT (-2.08839 51.88776, -2.08816 51.887...       106732
#
#         code  lsoa_code    oa_lat   oa_lon  \
# 0  E00112461  E01022128  51.87758 -2.08847
# 0  E00112456  E01022128  51.87813 -2.08279
# 0  E00112446  E01022128  51.88037 -2.08034
# 0  E00112454  E01022129  51.88095 -2.07903
# 0  E00112677  E01022172  51.88165 -2.09459
#
#                                          oa_geometry    distance
# 0  POLYGON ((-2.08830 51.88269, -2.08686 51.88150...  544.076146
# 0  POLYGON ((-2.07921 51.87962, -2.07874 51.87949...  671.444494
# 0  POLYGON ((-2.08032 51.88233, -2.07975 51.88181...  665.941150
# 0  POLYGON ((-2.07798 51.88258, -2.07739 51.88069...  787.497047
# 0  POLYGON ((-2.09207 51.88189, -2.09566 51.88002...  682.631725

# %%
libraries = pd.read_sql(f"""
SELECT osmid, ST_AsText(geometry) as geo_text
FROM osm_features
JOIN osm_coords USING (osmid)
WHERE amenity = 'library'
""", conn)

# join oas and libraries by distance < radius
libraries["geometry"] = libraries["geo_text"].apply(shp.wkt.loads)
libraries.drop(columns=["geo_text"], inplace=True)
libraries = gpd.GeoDataFrame(libraries, geometry="geometry", crs="EPSG:4326")

libraries_in_radius = gpd.sjoin(libraries, oas_to_join, predicate="intersects")
libraries_in_radius["distance"] = libraries_in_radius["oa_geometry"].to_crs(epsg=27700).distance(libraries_in_radius["geometry"].to_crs(epsg=27700))
libraries_in_radius.head()
# Out:
# C:\Users\varun\AppData\Local\Temp\ipykernel_38248\312733288.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   libraries = pd.read_sql(f"""
#    osmid                                           geometry  index_right  \
# 0  62123  MULTIPOLYGON (((-1.25473 51.75395, -1.25476 51...       137768
# 0  62123  MULTIPOLYGON (((-1.25473 51.75395, -1.25476 51...       137767
# 0  62123  MULTIPOLYGON (((-1.25473 51.75395, -1.25476 51...       137758
# 0  62123  MULTIPOLYGON (((-1.25473 51.75395, -1.25476 51...       137769
# 0  62123  MULTIPOLYGON (((-1.25473 51.75395, -1.25476 51...       137765
#
#         code  lsoa_code    oa_lat   oa_lon  \
# 0  E00145407  E01028544  51.74380 -1.25354
# 0  E00145406  E01028543  51.74415 -1.26255
# 0  E00145397  E01028543  51.74551 -1.25896
# 0  E00145408  E01028543  51.74604 -1.26068
# 0  E00145404  E01028544  51.74610 -1.25800
#
#                                          oa_geometry    distance
# 0  POLYGON ((-1.25166 51.74407, -1.24930 51.74258...  831.004682
# 0  POLYGON ((-1.26359 51.74612, -1.26273 51.74594...  976.443931
# 0  POLYGON ((-1.25749 51.74526, -1.25623 51.74538...  821.271743
# 0  POLYGON ((-1.25967 51.74713, -1.25944 51.74633...  821.271743
# 0  POLYGON ((-1.25647 51.74709, -1.25635 51.74641...  752.312660

# %%
def get_features_in_radius(feature, conn):
    features = pd.read_sql(f"""
    SELECT osmid, ST_AsText(geometry) as geo_text
    FROM osm_features
    JOIN osm_coords USING (osmid)
    WHERE {feature}
    """, conn)

    # join oas and libraries by distance < radius
    features["geometry"] = features["geo_text"].apply(shp.wkt.loads)
    features.drop(columns=["geo_text"], inplace=True)
    features = gpd.GeoDataFrame(features, geometry="geometry", crs="EPSG:4326")

    features_in_radius = gpd.sjoin(features, oas_to_join, predicate="intersects")
    features_in_radius["distance"] = features_in_radius["oa_geometry"].to_crs(epsg=27700).distance(features_in_radius["geometry"].to_crs(epsg=27700))

    print(f"Found {len(features_in_radius)} relationships in radius for {feature}")

    features_in_radius["feature"] = feature

    # drop radius to save memory
    features_in_radius.drop(columns=["geometry", "oa_geometry"], inplace=True)

    return features_in_radius

def get_features_in_radius_db(feature, conn):
    features = pd.read_sql(f"""
    SELECT osmid, latitude, longitude
        FROM osm_features as osm
        JOIN osm_coords as oc USING (osmid)
        JOIN output_area_geometry as oag
        ON ST_Distance_Sphere(Point(oc.longitude, oc.latitude), Point(oag.longitude, oag.latitude)) <= {radius}
        WHERE {feature}
    """, conn)

    print("fetched")

    features["geometry"] = features.apply(lambda x: shp.geometry.Point(x["longitude"], x["latitude"]), axis=1)
    features = gpd.GeoDataFrame(features, geometry="geometry", crs="EPSG:4326")

    print("spatial join")

    features_in_radius = gpd.sjoin(features, oas_to_join, predicate="intersects")
    features_in_radius["distance"] = features_in_radius["oa_geometry"].to_crs(epsg=27700).distance(features_in_radius["geometry"].to_crs(epsg=27700))

    print(f"Found {len(features_in_radius)} relationships in radius for {feature}")
    return features

coworking_spaces_in_radius = get_features_in_radius("amenity = 'coworking_space'", conn)
# Out:
# Found 112 relationships in radius for amenity = 'coworking_space'
# C:\Users\varun\AppData\Local\Temp\ipykernel_38248\2515138808.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   features = pd.read_sql(f"""

# %%
# education: higher
universities_in_radius = get_features_in_radius("amenity = 'university'", conn)

# education: secondary and below
schools_in_radius = get_features_in_radius("amenity = 'school'", conn)
colleges_in_radius = get_features_in_radius("amenity = 'college'", conn)
kindergartens_in_radius = get_features_in_radius("amenity = 'kindergarten'", conn)

secondary_and_below_education_in_radius = pd.concat([schools_in_radius, colleges_in_radius, kindergartens_in_radius])

all_education = pd.concat([universities_in_radius, secondary_and_below_education_in_radius])
# Out:
# C:\Users\varun\AppData\Local\Temp\ipykernel_38248\2515138808.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   features = pd.read_sql(f"""
# Found 63051 relationships in radius for amenity = 'university'
# Found 150 relationships in radius for amenity = 'school'
# C:\Users\varun\AppData\Local\Temp\ipykernel_38248\2515138808.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   features = pd.read_sql(f"""
# C:\Users\varun\AppData\Local\Temp\ipykernel_38248\2515138808.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   features = pd.read_sql(f"""
# Found 64329 relationships in radius for amenity = 'college'
# Found 1662 relationships in radius for amenity = 'kindergarten'
# C:\Users\varun\AppData\Local\Temp\ipykernel_38248\2515138808.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   features = pd.read_sql(f"""

# %%
# accomodation
student_accommodations_in_radius = get_features_in_radius("amenity = 'student_accommodation'", conn)
# too many to do by geometries
residentials_or_appartments_count = get_approx_features_in_radius("building = 'residential' OR building = 'apartments'", conn)

all_accom_in_radius = get_approx_features_in_radius("amenity = 'student_accommodation' or building = 'residential' or building = 'apartments'", conn)
# Out:
# C:\Users\varun\AppData\Local\Temp\ipykernel_38248\2515138808.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   features = pd.read_sql(f"""
# C:\Users\varun\AppData\Local\Temp\ipykernel_38248\2515138808.py:27: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   features = pd.read_sql(f"""
# Found 5705 relationships in radius for amenity = 'student_accommodation'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 4
#       2 student_accommodations_in_radius = get_features_in_radius("amenity = 'student_accommodation'", conn)
#       3 # too many to do by geometries
# ----> 4 residentials_or_appartments_count = get_approx_features_in_radius("building = 'residential' OR building = 'apartments'", conn)
#       6 all_accom_in_radius = get_approx_features_in_radius("amenity = 'student_accommodation' or building = 'residential' or building = 'apartments'", conn)
#
# Cell In[14], line 38, in get_approx_features_in_radius(feature, conn)
#      35 features = gpd.GeoDataFrame(features, geometry="geometry", crs="EPSG:4326")
#      37 features_in_radius = gpd.sjoin(features, oas_to_join, predicate="intersects")
# ---> 38 features_in_radius["distance"] = features_in_radius["oa_geometry"].to_crs(epsg=27700).distance(features_in_radius["geometry"].to_crs(epsg=27700))
#      40 print(f"Found {len(features_in_radius)} relationships in radius for {feature}")
#      41 return features
#
# File c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\geopandas\geoseries.py:1175, in GeoSeries.to_crs(self, crs, epsg)
#    1096 def to_crs(
#    1097     self, crs: Optional[Any] = None, epsg: Optional[int] = None
#    1098 ) -> GeoSeries:
#    1099     """Returns a ``GeoSeries`` with all geometries transformed to a new
#    1100     coordinate reference system.
#    1101
#    (...)
#    1172
#    1173     """
#    1174     return GeoSeries(
# -> 1175         self.values.to_crs(crs=crs, epsg=epsg), index=self.index, name=self.name
#    1176     )
#
# File c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\geopandas\array.py:872, in GeometryArray.to_crs(self, crs, epsg)
#     868     return self
#     870 transformer = TransformerFromCRS(self.crs, crs, always_xy=True)
# --> 872 new_data = vectorized.transform(self._data, transformer.transform)
#     873 return GeometryArray(new_data, crs=crs)
#
# File c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\geopandas\_vectorized.py:1290, in transform(data, func)
#    1288 coords = get_coordinates(data[~has_z], include_z=False)
#    1289 new_coords_z = func(coords[:, 0], coords[:, 1])
# -> 1290 result[~has_z] = set_coordinates(data[~has_z].copy(), np.array(new_coords_z).T)
#    1292 coords_z = get_coordinates(data[has_z], include_z=True)
#    1293 new_coords_z = func(coords_z[:, 0], coords_z[:, 1], coords_z[:, 2])
#
# File c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\shapely\coordinates.py:184, in set_coordinates(geometry, coordinates)
#     142 """Adapts the coordinates of a geometry array in-place.
#     143
#     144 If the coordinates array has shape (N, 2), all returned geometries
#    (...)
#     181 <POINT Z (1 1 1)>
#     182 """
#     183 geometry_arr = np.asarray(geometry, dtype=np.object_)
# --> 184 coordinates = np.atleast_2d(np.asarray(coordinates)).astype(np.float64)
#     185 if coordinates.ndim != 2:
#     186     raise ValueError(
#     187         "The coordinate array should have dimension of 2 "
#     188         f"(has {coordinates.ndim})"
#     189     )
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# transport infrastructure: public
train_stations_in_radius = get_features_in_radius("railway = 'station'", conn)
bus_stops_in_radius = get_features_in_radius("highway = 'bus_stop'", conn)
cycle_hire_in_radius = get_features_in_radius("amenity = 'bicycle_rental'", conn)
cycle_lanes_in_radius = get_features_in_radius("highway = 'cycleway'", conn)
pedestrian_areas_in_radius = get_features_in_radius("highway = 'pedestrian'", conn)
footpaths_in_radius = get_features_in_radius("highway = 'footway'", conn)
bicycle_parking_in_radius = get_features_in_radius("amenity = 'bicycle_parking'", conn)

# transport infrastructure: private
roads_in_radius = get_features_in_radius("highway = 'road'", conn)
car_parks_in_radius = get_features_in_radius("amenity = 'parking'", conn)
charging_stations_in_radius = get_features_in_radius("amenity = 'charging_station'", conn)

public_transport_in_radius = pd.concat([train_stations_in_radius, bus_stops_in_radius, cycle_hire_in_radius, cycle_lanes_in_radius, pedestrian_areas_in_radius, footpaths_in_radius, bicycle_parking_in_radius])
private_transport_in_radius = pd.concat([roads_in_radius, car_parks_in_radius])

all_transport = get_features_in_radius("railway IS NOT NULL OR highway IS NOT NULL OR public_transport IS NOT NULL", conn)

# %%
# food and drink
fast_food_in_radius = get_features_in_radius("amenity = 'fast_food'", conn)
restaurants_in_radius = get_features_in_radius("amenity = 'restaurant'", conn)
pubs_bars_and_beer_gardens_in_radius = get_features_in_radius("amenity = 'pub' OR amenity = 'bar' OR amenity = 'beer_garden'", conn)
cafes_in_radius = get_features_in_radius("amenity = 'cafe'", conn)
dessert_shops_in_radius = get_features_in_radius("amenity = 'ice_cream' OR amenity = 'sweet_shop'", conn)

all_food_and_drink_in_radius = pd.concat([fast_food_in_radius, restaurants_in_radius, pubs_bars_and_beer_gardens_in_radius, cafes_in_radius, dessert_shops_in_radius])

# %%
# shopping
# bookstores
bookstores_in_radius = get_features_in_radius("shop = 'books'", conn)
copy_shop_in_radius = get_features_in_radius("shop = 'copyshop'", conn)

all_shops = get_features_in_radius("shop IS NOT NULL", conn)

# %%
# leisure
leisure_centers_in_radius = get_features_in_radius("leisure = 'sports_centre'", conn)
gyms_in_radius = get_features_in_radius("leisure = 'fitness_centre'", conn)
parks_in_radius = get_features_in_radius("leisure = 'park'", conn)
playgrounds_in_radius = get_features_in_radius("leisure = 'playground'", conn)
swimming_pools_in_radius = get_features_in_radius("leisure = 'swimming_pool'", conn)

all_leisure_in_radius = get_features_in_radius("leisure IS NOT NULL", conn)

# %%
# healthcare
hospitals_in_radius = get_features_in_radius("amenity = 'hospital'", conn)
pharmacies_in_radius = get_features_in_radius("amenity = 'pharmacy'", conn)
doctors_in_radius = get_features_in_radius("amenity = 'doctors'", conn)
dentists_in_radius = get_features_in_radius("amenity = 'dentist'", conn)
clinics_in_radius = get_features_in_radius("amenity = 'clinic'", conn)
nursing_homes_in_radius = get_features_in_radius("amenity = 'nursing_home'", conn)
vets_in_radius = get_features_in_radius("amenity = 'veterinary'", conn)

all_healthcare_in_radius = get_features_in_radius("healthcare IS NOT NULL", conn)
# Out:
# C:\Users\varun\AppData\Local\Temp\ipykernel_31276\2174163700.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   features = pd.read_sql(f"""
# Found 63051 relationships in radius for amenity = 'university'
# Found 0 relationships in radius for amenity = 'research_institute'
# Found 150 relationships in radius for amenity = 'school'
# C:\Users\varun\AppData\Local\Temp\ipykernel_31276\2174163700.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   features = pd.read_sql(f"""
# C:\Users\varun\AppData\Local\Temp\ipykernel_31276\2174163700.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   features = pd.read_sql(f"""
# C:\Users\varun\AppData\Local\Temp\ipykernel_31276\2174163700.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   features = pd.read_sql(f"""
# Found 64329 relationships in radius for amenity = 'college'
# Found 1662 relationships in radius for amenity = 'kindergarten'
# C:\Users\varun\AppData\Local\Temp\ipykernel_31276\2174163700.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   features = pd.read_sql(f"""
# C:\Users\varun\AppData\Local\Temp\ipykernel_31276\2174163700.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   features = pd.read_sql(f"""
# Found 5705 relationships in radius for amenity = 'student_accommodation'
# C:\Users\varun\AppData\Local\Temp\ipykernel_31276\2174163700.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   features = pd.read_sql(f"""

# %% [markdown]
# # Plan
#
# For each of:
# - Educational Infrastructure
#     - University Buildings
#     - Libraries
#     - Coworking spaces
# - Accomodation
#     - Student Accomodation
#     - Residential or apartment buildings
# - Transportation Infrastructure
#     - Train and Bus Stops
#     - Cycling Infrastructure
#     - Pedestrian Areas
# - Amenities
#     - Fast food, cafes, bars, ...
#     - Bookstores and copy shops
#     - Leisure facilities
#
# Produce a:
# - Distance to nearest
# - Naive density
# - Distance-aware density (higher density if POIs are closer)
# for each OA.
#
# Cluster and visualise
#
# Then add the same for aggregates:
# - All POIs
# - All amenities
# - All education
# - All accomodation
# - All transport
#
# Then add interaction terms:
# - Housing x education
# - Housing x amenities
# - Transport x accomodation
#
# Cluster and visualise to see if these actually helped
#
# Then run PCA for dimensionality reduction.
# Then train a linear model.
#
# All with relevant visualisations along the way

# %% [markdown]
# Write a short paragraph summarising what you did in the Assess stage.

# %%
# TODO: your answer here

# %% [markdown]
# ## Address

# %%
def estimate_students(latitude: float, longitude: float) -> float:
    """
    Args:
    latitude (float): The latitude coordinate.
    longitude (float): The longitude coordinate.

    Returns:
    float: Estimated share of students in that area (value between 0 and 1).
    """
    # TODO: implement
    return NotImplementedError


def estimate_something(latitude: float, longitude: float) -> float:
    #TODO: rename function
    """
    Args:
    latitude (float): The latitude coordinate.
    longitude (float): The longitude coordinate.

    Returns:
    float: Estimated value, percentage, probability, etc
    """
    # TODO: implement
    return NotImplementedError

# %% [markdown]
# Write a short paragraph summarising what you did in the Address stage.

# %%
# TODO: your answer here

# %% [markdown]
# ## Discussion

# %% [markdown]
# #### Story and structure

# %%
# Marks awarded for inline explanation and structure, no need for answers here. Go over your notebook to make sure you explain what you did and why.

# %% [markdown]
# #### Design decisions

# %%
# TODO: your answer here

# %% [markdown]
# #### Comparison

# %%
# TODO: your answer here

# %% [markdown]
# #### Reusability

# %%
# TODO: your answer here

# %% [markdown]
# # Task 2: miniproject (13 marks)

# %% [markdown]
# We expect your miniproject to be more advanced than the example project, and that's why we allocated more marks to it. The first 7 marks will be allocated similarly to Task 1.
#
# 6 remaining points are *bonus* - they will be allocated for going far beyond what you did in Task 1, either in data access, assess, address or story.

# %% [markdown]
# #### Choosing your topic
#
# You are given a lot of flexibility in choosing a miniproject topic.
#
# Some hints:
# - Your project should be based on the Census, Price Paid, OSM and Election datasets.
# - It's a good idea to pick something that you are interested in.
# - Bear in mind there are no marks dedicated to your overall prediction accuracy, so there is no advantage to picking 'easy' topics. It is perfectly ok to not reach significant predictive power, as long as you followed the proper process.
#
# Some guidelines:
# - Do not make a miniproject that furthers discriminatory rhetoric. In general, avoid topics that could be insensitive. If in doubt, message Radzim Sendyka (and *cc* Christian Cabrera) to discuss if this applies to your idea.
# - Please avoid any projects that would require approval from the ethics comittee.
# - Pick the scope of your projects that will allow you to show your skills. Some projects might not be challenging enough while others might be hard to make any progress in. Don't be scared to report negative results.
#
# Please email Radzim Sendyka (and *cc* Christian Cabrera) with your project idea when you begin working on it, so we can let you know about any potential concerns (eg. potentially insensive, too off-topic, too simple, too complex) as soon as we can. You can change the topic up to the submission deadline, but let us know again in cases of major changes.

# %% [markdown]
# Most of the advice from Task 1 still applies, particularly around using an online relational database, structuring your notebook, fynesse, access-assess-address, data readiness levels, hints.

# %% [markdown]
# Sources you may want to include in your data include:
#
#   - UK Census Data
#     - UK Census 2021 data [here](https://www.ons.gov.uk/search?topics=9731,6646,3845,9497,4262,4128,7755,4994,6885,9724,7367&filter=datasets) or [here](https://www.nomisweb.co.uk/sources/census_2021_bulk).
#     - Historical Census data [here](https://www.ons.gov.uk/census/historiccensusdata).
#     - Geographic coordinates of Census Output Areas [here](https://www.data.gov.uk/dataset/4d4e021d-fe98-4a0e-88e2-3ead84538537/output-areas-december-2021-boundaries-ew-bgc-v2).
#   - Spatial data
#     - You should already have a connection to OpenStreetMaps.
#     - You might want to also download the entire map for England (or more) [here](https://download.openstreetmap.fr/extracts/) or [here](https://wiki.openstreetmap.org/wiki/Planet.osm).
#   - Election data
#     - Recent Election Results data [here](https://commonslibrary.parliament.uk/research-briefings/cbp-10009/)
#     - Historical Election Results data [here](https://commonslibrary.parliament.uk/research-briefings/cbp-8647/#fullreport).
#     - Lookup reference between Output Areas and Parliamentary Constituencies [here](https://geoportal.statistics.gov.uk/datasets/5968b5b2c0f14dd29ba277beaae6dec3_0/explore).
#   - Price Paid Data
#     - You should have this data already in your database.
#   - OSM
#     - You should know how to access this data from previous practicals.

# %% [markdown]
# Example ideas:
#
# - Are areas correlated in terms of census results? If so, find the areas that are leading change, and the ones that are following.
# - Which historical census variables used to predict election results in the past, but don't seem related anymore?
# - Census results are only updated once a decade, but new roads and houses are built every year. Can census results, for example those relating to travel, be predicted from basic map information, such as street networks?
# - Building new houses is our best way of tackling the housing crisis. Use the information on new builds in the house prices dataset to explore what factors drive new developments, and make predictions for where the next houses will be built.
# - House styles differ a lot between regions and inhabitants. Can you make any predictions about the house or area simply from looking at it's geometric shape and orientation?
#
# Note that the ideas are just a starting point question. You should include more in-depth investigations into the data, validate your findings where applicable, and prepare visualisations.

# %% [markdown]
# ## Title and description

# %%
# TODO: title your miniproject

# %%
# TODO: provide a very brief description of the goals of your miniproject

# %% [markdown]
# ## Access

# %%
import pandas as pd
import osmnx as ox
import shapely as shp
import numpy as np
import os
import requests
import fynesse
import geopandas as gpd
import yaml
import matplotlib.pyplot as plt
import seaborn as sns
from zipfile import ZipFile
import MySQLdb
import sklearn
import multiprocessing as mp
import re

# set up database connection

# %load_ext sql

with open("./credentials1.yaml") as file:
  credentials = yaml.safe_load(file)

username = credentials["username"]
password = credentials["password"]
url = credentials["url"]
port = credentials["port"]

# %config SqlMagic.style = '_DEPRECATED_DEFAULT'


connection_string = f"mysql+pymysql://{username}:{password}@{url}:{port}/ads_2024?local_infile=1"
# %sql $connection_string
# %sql use ads_2024;

conn = MySQLdb.connect(host=url, user=username, password=password, database="ads_2024", local_infile=True)

# download data

for url in [
    
]:

    if isinstance(url, tuple):
        filename, url = url
    else:
        filename = f"./{url.split('/')[-1]}"

    if not os.path.exists(filename):
        print(f"Downloading {url}")
        r = requests.get(url)
        with open(filename, 'wb') as f:
            f.write(r.content)
        print(f"Downloaded {filename}")
    else:
        print(f"Already downloaded {filename}")


    if filename.endswith('.zip') and not os.path.exists(filename.replace('.zip', '')):
        with ZipFile(filename, 'r') as zip_ref:
            zip_ref.extractall()
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 0 rows affected.

# %%
def parse_height_to_meters(height_series):
    """
    Parses a pandas Series containing height information from OpenStreetMap and converts it to float values in metres.
    
    Parameters:
    height_series (pd.Series): Series containing height information as strings.
    
    Returns:
    pd.Series: Series with heights converted to metres as float.
    """
    
    def convert_to_meters(height):
        if pd.isnull(height):
            return None
        
        height_str = str(height).strip().lower()
        
        # Regular expression to extract number and unit
        # This regex handles:
        # 1. Pure numerical values with optional unit (e.g., "4 m", "1.35")
        # 2. Feet and inches format (e.g., "7'4\"")
        # 3. Mixed units with possible spacing issues
        pure_number_pattern = r'^([\d,.]+)\s*(m|meter|meters|metre|metres|ft|foot|feet)?$'
        feet_inches_pattern = r"^(\d+)'\s*(\d+)?\"?$"
        
        # Try pure number with optional unit
        match = re.match(pure_number_pattern, height_str)
        
        if match:
            value, unit = match.groups()
            # Replace comma with dot for decimal conversion if necessary
            value = value.replace(',', '.')
            
            try:
                value = float(value)
            except ValueError:
                return np.nan  # Unable to convert to float
            
            # Define conversion factors
            unit = unit.lower() if unit else 'm'  # Assume meters if no unit provided
            
            if unit in ['m', 'meter', 'meters', 'metre', 'metres']:
                return value
            elif unit in ['ft', 'foot', 'feet']:
                return value * 0.3048  # 1 foot = 0.3048 meters
            else:
                # Handle other units if necessary
                return np.nan  # Unknown unit
        
        # Try feet and inches pattern
        match = re.match(feet_inches_pattern, height_str)
        if match:
            feet, inches = match.groups()
            try:
                feet = int(feet)
                inches = int(inches) if inches else 0
            except ValueError:
                return np.nan  # Unable to convert to integers
            
            total_meters = feet * 0.3048 + inches * 0.0254
            return round(total_meters, 4)  # Rounded to 4 decimal places
        
        # If no pattern matches, return NaN
        return None
    
    # Apply the conversion to each element in the Series
    return height_series.apply(convert_to_meters)

# %%
headers = "osmid|area|amenity|building|building:use|building:levels|height|shop|leisure|sport|landuse|office|railway|public_transport|highway|aeroway|waterway|man_made|geometry".split("|")

# for every geojson file in the osm_features directory, save it to a csv

def process_file(file):
    if not file.endswith(".geojson"):
        return

    name = file.split(".")[0]
        
    print(f"Processing {name}")

    pois = gpd.read_file(f"osm_features/{file}")

    pois["height"] = parse_height_to_meters(pois["height"])
    pois["building:levels"] = pois["building:levels"].apply(lambda x: int(x) if pd.notnull(x) and x.isdigit() else None)
    pois["area"] = pois["geometry"].set_crs(epsg=4326).to_crs(epsg=27700).area

    pois = pois.dropna(subset=["geometry"])

    to_save = pd.DataFrame(columns=headers)

    for col in headers:
        if col in pois.columns:
            to_save[col] = pois[col]

    to_save.to_csv(f"osm_features/{name}.csv", sep="|", index=False)

files = os.listdir("osm_features")

for file in files:
    process_file(file)
# Out:
# Processing chunk_0
# Processing chunk_1
# Processing chunk_10
# Processing chunk_11
# Processing chunk_12
# Processing chunk_13
# Processing chunk_14
# Processing chunk_15
# Processing chunk_16
# Processing chunk_17
# Processing chunk_18
# Processing chunk_19
# Processing chunk_2
# Processing chunk_20
# Processing chunk_21
# Processing chunk_22
# Processing chunk_23
# Processing chunk_24
# Processing chunk_25
# Processing chunk_26
# Processing chunk_27
# Processing chunk_28
# Processing chunk_29
# Processing chunk_3
# Processing chunk_30
# Processing chunk_31
# Processing chunk_32
# Processing chunk_33
# Processing chunk_34
# Processing chunk_35
# Processing chunk_36
# Processing chunk_37
# Processing chunk_38
# Processing chunk_39
# Processing chunk_4
# Processing chunk_40
# Processing chunk_41
# Processing chunk_42
# Processing chunk_43
# Processing chunk_44
# Processing chunk_45
# Processing chunk_46
# Processing chunk_47
# Processing chunk_48
# Processing chunk_49
# Processing chunk_5
# Processing chunk_50
# Processing chunk_51
# Processing chunk_52
# Processing chunk_53
# Processing chunk_54
# Processing chunk_55
# Processing chunk_56
# Processing chunk_57
# Processing chunk_58
# Processing chunk_59
# Processing chunk_6
# Processing chunk_60
# Processing chunk_61
# Processing chunk_62
# Processing chunk_63
# Processing chunk_64
# Processing chunk_65
# Processing chunk_66
# Processing chunk_67
# Processing chunk_68
# Processing chunk_69
# Processing chunk_7
# Processing chunk_70
# Processing chunk_71
# Processing chunk_72
# Processing chunk_8
# Processing chunk_9

# %%
# %%sql
# DROP TABLE IF EXISTS osm_features;
# CREATE TABLE IF NOT EXISTS osm_features (
#     -- Unique identifier
#     osmid INT NOT NULL,
#
#     -- Area of the feature
#     area DOUBLE,
#
#     -- Tags
#     amenity VARCHAR(255),
#     building VARCHAR(255),
#     building_use VARCHAR(255),
#     building_levels INT,
#     height FLOAT,
#     shop VARCHAR(255),
#     leisure VARCHAR(255),
#     sport VARCHAR(255),
#     landuse VARCHAR(255),
#     office VARCHAR(255),
#     railway VARCHAR(255),
#     public_transport VARCHAR(255),
#     highway VARCHAR(255),
#     aeroway VARCHAR(255),
#     waterway VARCHAR(255),
#     man_made VARCHAR(255),
#
#     -- Geometry
#     geometry GEOMETRY NOT NULL,
#
#     -- Constraints
#     PRIMARY KEY (osmid),
#     CHECK (osmid >= 0)
# ) DEFAULT CHARSET=utf8 COLLATE=utf8_bin AUTO_INCREMENT=1;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 0 rows affected.
# 0 rows affected.
# []

# %%
# for each csv file in the osm_features directory, load it into the database

for file in os.listdir("osm_features"):
    if not file.endswith(".csv"):
        continue

    name = file.split(".")[0]
    print(f"Processing {name}")

    command = f"""
LOAD DATA LOCAL INFILE 'osm_features/{file}' \
INTO TABLE osm_features \
FIELDS TERMINATED BY '|' \
ENCLOSED BY '"' \
LINES TERMINATED BY '\\n' \
IGNORE 1 LINES \
(osmid, @area, amenity, building, building_use, building_levels, height, shop, leisure, sport, landuse, office, railway, public_transport, highway, aeroway, waterway, man_made, @geo) \
SET geometry = ST_GeomFromText(@geo, 4326), area = IF(@area = 0.0, NULL, @area);"""

    # %sql $command
# Out:
# Processing chunk_0
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_1
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_10
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_11
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_12
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_13
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_14
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_15
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_16
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_17
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_18
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_19
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_2
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_20
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_21
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_22
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_23
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_24
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_25
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_26
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_27
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_28
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_29
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_3
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_30
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_31
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_32
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_33
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_34
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_35
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_36
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_37
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_38
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_39
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_4
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_40
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_41
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_42
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_43
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_44
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_45
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_46
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_47
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_48
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_49
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_5
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_50
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_51
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_52
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_53
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_54
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_55
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_56
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_57
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_58
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_59
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_6
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_60
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_61
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_62
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_63
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_64
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_65
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_66
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_67
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 199995 rows affected.
# Processing chunk_68
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_69
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_7
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_70
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_71
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_72
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 146309 rows affected.
# Processing chunk_8
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.
# Processing chunk_9
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 200000 rows affected.

# %%
# %%sql
# ALTER TABLE osm_features ADD INDEX idx_amenity (amenity),
# ADD INDEX idx_building (building),
# ADD INDEX idx_building_use (building_use),
# ADD INDEX idx_shop (shop),
# ADD INDEX idx_leisure (leisure),
# ADD INDEX idx_sport (sport),
# ADD INDEX idx_landuse (landuse),
# ADD INDEX idx_office (office),
# ADD INDEX idx_railway (railway),
# ADD INDEX idx_public_transport (public_transport),
# ADD INDEX idx_highway (highway),
# ADD INDEX idx_aeroway (aeroway),
# ADD INDEX idx_waterway (waterway),
# ADD INDEX idx_man_made (man_made),
# ADD SPATIAL INDEX idx_geometry (geometry);
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 0 rows affected.
# []

# %% [markdown]
# ## Conclusions
#
# The below code is for marking purpuses only, and not part of your project. It helps us gather the data we need without asking you for database credentials, and scouring github pages. This is mandatory. If the code does not work for you, let us know immediately.

# %% [markdown]
# 1) Please re-run the code from Practical 1 to help us see the contents of your database. We recommend you include all data sources there, but some smaller inputs are fine to use as files.

# %%
tables = %sql SHOW TABLES;

for row in tables:
    table_name = row[0]
    print(f"\nTable: {table_name}")

    table_status = %sql SHOW TABLE STATUS LIKE '{table_name}';
    approx_row_count = table_status[0][4] if table_status else 'Unable to fetch row count'
    print("\nApprox Row Count:", approx_row_count//100000/10, "M")

    first_5_rows = %sql SELECT * FROM `{table_name}` LIMIT 5;
    print(first_5_rows)

    indices = %sql SHOW INDEX FROM `{table_name}`;
    if indices:
        print("\nIndices:")
        for index in indices:
            print(f" - {index[2]} ({index[10]}): Column {index[4]}")
    else:
        print("\nNo indices set on this table.")
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 6 rows affected.
#
# Table: census_nssec
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#
# Approx Row Count: 0.1 M
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 5 rows affected.
# +------+-------------+-----------------------------+--------------------------------------+-------------------------------------+--------------------------+-----------------------------+-----------------------------+--------------------------+---------------------+----------------------------------+--------------------+
# | year | output_area | total_residents_16_and_over | higher_managerial_admin_professional | lower_managerial_admin_professional | intermediate_occupations | small_employers_own_account | lower_supervisory_technical | semi_routine_occupations | routine_occupations | never_worked_longterm_unemployed | full_time_students |
# +------+-------------+-----------------------------+--------------------------------------+-------------------------------------+--------------------------+-----------------------------+-----------------------------+--------------------------+---------------------+----------------------------------+--------------------+
# | 2021 |  E00000001  |             159             |                  80                  |                  38                 |            13            |              9              |              3              |            5             |          5          |                4                 |         2          |
# | 2021 |  E00000003  |             222             |                  96                  |                  58                 |            8             |              26             |              2              |            5             |          2          |                5                 |         20         |
# | 2021 |  E00000005  |             103             |                  37                  |                  28                 |            8             |              21             |              0              |            3             |          1          |                1                 |         4          |
# | 2021 |  E00000007  |             140             |                  62                  |                  39                 |            5             |              11             |              3              |            3             |          1          |                6                 |         10         |
# | 2021 |  E00000010  |             170             |                  34                  |                  45                 |            17            |              27             |              7              |            10            |          14         |                11                |         5          |
# +------+-------------+-----------------------------+--------------------------------------+-------------------------------------+--------------------------+-----------------------------+-----------------------------+--------------------------+---------------------+----------------------------------+--------------------+
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 3 rows affected.
#
# Indices:
#  - PRIMARY (BTREE): Column year
#  - PRIMARY (BTREE): Column output_area
#  - idx_output_area (BTREE): Column output_area
#
# Table: hours_worked
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#
# Approx Row Count: 0.1 M
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 5 rows affected.
# +------+-------------+------------------------+-----------+-------------------------+-----------------------+-----------+-----------------------+-------------------------+
# | year | output_area | total_employed_over_16 | part_time | worked_15_hours_or_less | worked_16_to_30_hours | full_time | worked_31_to_48_hours | worked_49_hours_or_more |
# +------+-------------+------------------------+-----------+-------------------------+-----------------------+-----------+-----------------------+-------------------------+
# | 2021 |  E00000001  |           88           |     28    |            14           |           14          |     60    |           43          |            17           |
# | 2021 |  E00000003  |          134           |     37    |            17           |           20          |     97    |           59          |            38           |
# | 2021 |  E00000005  |           66           |     12    |            5            |           7           |     54    |           33          |            21           |
# | 2021 |  E00000007  |          106           |     12    |            10           |           2           |     94    |           58          |            36           |
# | 2021 |  E00000010  |          113           |     26    |            10           |           16          |     87    |           66          |            21           |
# +------+-------------+------------------------+-----------+-------------------------+-----------------------+-----------+-----------------------+-------------------------+
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 3 rows affected.
#
# Indices:
#  - PRIMARY (BTREE): Column year
#  - PRIMARY (BTREE): Column output_area
#  - idx_output_area (BTREE): Column output_area
#
# Table: lsoa_coords
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#
# Approx Row Count: 0.0 M
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 5 rows affected.
# +------+-----------+--------------------+--------------------+
# | year |    code   |      latitude      |     longitude      |
# +------+-----------+--------------------+--------------------+
# | 2021 | E01019077 | 49.93554586306154  | -6.314362745794287 |
# | 2021 | E01018881 | 50.002141253873944 | -5.194059326857887 |
# | 2021 | E01018904 | 50.01249648937134  | -5.237279625396924 |
# | 2021 | E01018920 | 50.04085079714364  | -5.117039298107807 |
# | 2021 | E01018903 | 50.05971532971494  | -5.236437166777518 |
# +------+-----------+--------------------+--------------------+
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 5 rows affected.
#
# Indices:
#  - PRIMARY (BTREE): Column year
#  - PRIMARY (BTREE): Column code
#  - idx_code (BTREE): Column code
#  - idx_coords (BTREE): Column latitude
#  - idx_coords (BTREE): Column longitude
#
# Table: lsoa_geometry
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#
# Approx Row Count: 0.0 M
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 5 rows affected.
# +------+-----------+---------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | year |    code   |            name           |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         geometry                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# +------+-----------+---------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 2021 | E01000001 |    City of London 001A    |                                                          b'\xe6\x10\x00\x00\x01\x03\x00\x00\x00\x01\x00\x00\x00\x1c\x00\x00\x00\xa0\xe9\xad\x81\x1f\xc2I@\xbb\xdb\x91b3N\xb8\xbf\xf0\xb5E\xf0\xf9\xc1I@\x1e\xb9x\x9esq\xb8\xbf\xc3\xaa\x1eq\xea\xc1I@t\x13\x8aO*\x86\xb8\xbf4\xc3\x8dQ\xe6\xc1I@ZQV\xe3\x0b\xba\xb8\xbfU\x7f&\x1d\xfd\xc1I@\xa3\xd3\xc2\xd0k\x15\xb9\xbfT\x86\x1b\xf3\x1f\xc2I@\x81I\xac$\xf8\x0c\xb9\xbf\x9e\x1f\xc7p%\xc2I@s\xf7d4#\x89\xb9\xbf\xd9\xedU\xcd;\xc2I@\x93\xce\xb3R\xe9\x83\xb9\xbf@\x1b\\\xf0E\xc2I@\xa2bG\x08,c\xb9\xbf\xff8\xb8uJ\xc2I@t\x07b\xd4\xa3#\xb9\xbf\x07S\xc7\xf1>\xc2I@~D\xcd\xd6a\x19\xb9\xbfTB\x1dUC\xc2I@\xa6C\xa4\xa9\x8c\xfb\xb8\xbf\x8a\xfb\xc8`\x84\xc2I@v\xc8\x1f=\x03\x07\xb9\xbf\xcc\x05\x07\xbc\x8c\xc2I@\xe1\x82Gn\xc3\r\xb9\xbfR\xb5\xb6\x9f\x86\xc2I@\xca\x9f$\xc04<\xb9\xbf\x8eZ$\xfe\xa0\xc2I@\xa9\xca\x18\x9a\xe38\xb9\xbf\x1c\x83\x07\xec\xa5\xc2I@Z\xdeL\x00S\xff\xb8\xbfNJN;\xc3\xc2I@\xb4\xb2\x07 \x1a\xe8\xb8\xbf\xf0\xd4v\xd7\xc2\xc2I@\xc1O\xf8\t\xb8\xe7\xb8\xbf\xd0\xaa\xb3Y\x98\xc2I@J\x97j\x13?\xb5\xb8\xbf\xb4\x16\xd3\xd0\x9f\xc2I@\xeb\xf1\x1b]yc\xb8\xbf:\xbf\xd9\xd5\xa2\xc2I@\x9270\x84\xe1B\xb8\xbf\xf8\x12\x18\x14\xa5\xc2I@8\x7f\x94\xa2\xe6)\xb8\xbf*\x99|x\x87\xc2I@\x17\x9fj1u1\xb8\xbf\xa3\xefV\xfcw\xc2I@\xd5pr\xec|W\xb8\xbf47\x9e\x96U\xc2I@PV\xd8\xafgW\xb8\xbfO\xf5\x8e\xf4$\xc2I@\xb7\x01\x96\x1c\x19\x8f\xb8\xbf\xa0\xe9\xad\x81\x1f\xc2I@\xbb\xdb\x91b3N\xb8\xbf'                                                          |
# | 2021 | E01000002 |    City of London 001B    | b'\xe6\x10\x00\x00\x01\x03\x00\x00\x00\x01\x00\x00\x00\x1e\x00\x00\x00\xc8;U\xb3<\xc2I@\xc0\xb3\x87\xf3\x18\x12\xb7\xbf\xcc\xb6G\xa9/\xc2I@\xda\t4\x04\x86\x1e\xb7\xbf>\xad\x05\xa55\xc2I@\x90\x99\xdau\x15?\xb7\xbf~/+\xb7>\xc2I@Zf@\xda=7\xb7\xbf\x004\xbfIB\xc2I@Cm\xaaTKg\xb7\xbf\x08\xcf\xf7\xbb\x06\xc2I@\xad\xf04D\x8c\xa8\xb7\xbf\x11\xb2\xb8\xcd\xcd\xc1I@\x90\x89\xaf\xd4|\x12\xb8\xbf\xc2Ns\x87\xd2\xc1I@\xb6g]\xeaqC\xb8\xbf\xa6\x1b\x08\x07\xdc\xc1I@]s\x80\xc4\xc0=\xb8\xbf\x87\x8d\x19\x18\xde\xc1I@\x01\xd5~\xbe\xd2`\xb8\xbf\x17\x85\n\x9f\xf4\xc1I@s\x1d\xee\t3T\xb8\xbf\xf0\xb5E\xf0\xf9\xc1I@\x1e\xb9x\x9esq\xb8\xbf\xa0\xe9\xad\x81\x1f\xc2I@\xbb\xdb\x91b3N\xb8\xbfO\xf5\x8e\xf4$\xc2I@\xb7\x01\x96\x1c\x19\x8f\xb8\xbf47\x9e\x96U\xc2I@PV\xd8\xafgW\xb8\xbf\xa3\xefV\xfcw\xc2I@\xd5pr\xec|W\xb8\xbf*\x99|x\x87\xc2I@\x17\x9fj1u1\xb8\xbf\xf8\x12\x18\x14\xa5\xc2I@8\x7f\x94\xa2\xe6)\xb8\xbf:\xbf\xd9\xd5\xa2\xc2I@\x9270\x84\xe1B\xb8\xbf\xad\x80\xa3\xc6\xa8\xc2I@\xdf\x9a\x91\xf8L\x0b\xb8\xbf\x13\xa4\x902\xb1\xc2I@\xe9Zn:\x01\x13\xb8\xbf\xca\xdb\xcb\xd1\xbc\xc2I@R\x87\x15\x95S\xbf\xb7\xbf!g\x03,\xbe\xc2I@\xa4"r\xdd\xe8\xaf\xb7\xbf\xd9\x80m.\xb0\xc2I@\xd4\xc1\xdcHQ\xa7\xb7\xbf\x94^\x05%\xaa\xc2I@\xf0w\xa2\xcd\x9a0\xb7\xbf\xe2\xf6\xc9\xe1\xa5\xc2I@\x0e\x84\xce\xbb:\xf6\xb6\xbf\xef#\xaa\xc9\x8e\xc2I@ 0\r\x17\xab\x06\xb7\xbf\xc3\xbe\xea\x0c|\xc2I@\xfcIn\xcc\xa1\x8f\xb6\xbf\x1b\x04\x8e\xf8=\xc2I@U\xce/n\xcb\xdb\xb6\xbf\xc8;U\xb3<\xc2I@\xc0\xb3\x87\xf3\x18\x12\xb7\xbf' |
# | 2021 | E01000003 |    City of London 001C    |                                                                                                                                                                                                                                                                                                                         b"\xe6\x10\x00\x00\x01\x03\x00\x00\x00\x01\x00\x00\x00\x10\x00\x00\x00\xf0\xd4v\xd7\xc2\xc2I@\xc1O\xf8\t\xb8\xe7\xb8\xbfNJN;\xc3\xc2I@\xb4\xb2\x07 \x1a\xe8\xb8\xbf\xbd\x98>\x85\xd6\xc2I@\xe5\xe0#'=\xf5\xb8\xbf\\A=\xfb\xee\xc2I@\xe4\xc2\xfe5+\x04\xb9\xbfn\xe2\xc6\xd7\xf9\xc2I@\xb4\x1d\xc8\xc8\xf4\xc6\xb8\xbf@\xfe5\xce\xeb\xc2I@\x9fbM\xf4J\xb2\xb8\xbf\xb2\xdd\x06f\xf3\xc2I@|m\x1b\xc4DX\xb8\xbf\xe2\xc6\xd0j\xd2\xc2I@\xd0;\xe9\xb4\x015\xb8\xbf\x1f\xbb\xce:\xbf\xc2I@\xa7\xc5\x89\x9e\x91&\xb8\xbf\xca\xdb\xcb\xd1\xbc\xc2I@R\x87\x15\x95S\xbf\xb7\xbf\x13\xa4\x902\xb1\xc2I@\xe9Zn:\x01\x13\xb8\xbf\xad\x80\xa3\xc6\xa8\xc2I@\xdf\x9a\x91\xf8L\x0b\xb8\xbf:\xbf\xd9\xd5\xa2\xc2I@\x9270\x84\xe1B\xb8\xbf\xb4\x16\xd3\xd0\x9f\xc2I@\xeb\xf1\x1b]yc\xb8\xbf\xd0\xaa\xb3Y\x98\xc2I@J\x97j\x13?\xb5\xb8\xbf\xf0\xd4v\xd7\xc2\xc2I@\xc1O\xf8\t\xb8\xe7\xb8\xbf"                                                                                                                                                                                                                                                                                                                         |
# | 2021 | E01000005 |    City of London 001E    |                                                                                                                                                                                                                                                                                                                           b"\xe6\x10\x00\x00\x01\x03\x00\x00\x00\x01\x00\x00\x00\x11\x00\x00\x00\xad\r^\x98\xd9\xc1I@\xbd\xc3$D\xa2\xef\xb2\xbf?|b\xee\xbb\xc1I@p\x89\xc7\x9ck\xcd\xb2\xbf\x12\x0c\xbe\xe9\x9b\xc1I@B\x00\xbe\x10\xab\xbc\xb2\xbf0\xef\x96\xd2\x8a\xc1I@ 1\xa8o\xb2\xb6\xb2\xbf\xb3\x00 \x0eb\xc1I@\xff\xea\x8ee\xb0\xa0\xb2\xbf\xf9p\xf6\xd5M\xc1I@\xb3'z\xc1J\x9e\xb2\xbfq%d\xc2G\xc1I@\xf4\xffF\xf41\xbf\xb2\xbfp\xdd\xc5\x02?\xc1I@\x95\x11{\xd7\x14V\xb3\xbf4>$OW\xc1I@kbyT\x0b\x80\xb3\xbfV=J$\xb8\xc1I@\x11KS\xb8\xae\x91\xb3\xbf\xcbL\xc2\x96\x01\xc2I@\xb8@\x9b<>}\xb4\xbf)'>\xd5\x16\xc2I@\xa2\xaf\r\x17\x1dC\xb4\xbf0\xe9\xcf\x11=\xc2I@\x92o\xa9\xab\x88\x06\xb4\xbf\x9c\xd0c\x08:\xc2I@g\xce\xd2\xf5\x95\xce\xb3\xbf\xf9\xc4\x14\xd9\x08\xc2I@\xdan\xb7y[o\xb3\xbfw\xf6\x1e\xaf\x06\xc2I@.\xb7\xbc\xe93i\xb3\xbf\xad\r^\x98\xd9\xc1I@\xbd\xc3$D\xa2\xef\xb2\xbf"                                                                                                                                                                                                                                                                                                                            |
# | 2021 | E01000006 | Barking and Dagenham 016A |                                                                                                                                                                                                                               b"\xe6\x10\x00\x00\x01\x03\x00\x00\x00\x01\x00\x00\x00\x16\x00\x00\x00\xdf\x98w\x93\xcf\xc4I@\x84\xa9\x16\x03l&\xb6?k\xa7\n\xca\xd9\xc4I@\x85p\x8f\xc3\xb3\xc0\xb5?\x88k\xd4>\xe2\xc4I@\x1c|(gb\xca\xb5?Aw\x9d\x07\xe9\xc4I@\xc7T\xf1\x10%\xd7\xb5?\xeeo\x1f>\xee\xc4I@\xbeU\xcf\xc8/\xbd\xb5?\x98\xc6\xfe\xcf\x03\xc5I@[\xfe\x96cD\xf5\xb5?i\xfd\x12k\xfe\xc4I@\xfe9\xe0\xc5\x90\x10\xb6?\xc1\x021\x86\x0c\xc5I@Z\x9c \x12a7\xb6?\xa1\x95\nn*\xc5I@U\x8a\x91\xc0\x1b\xc7\xb5?\xf9:\xf0\xbdG\xc5I@1\x01\x11\xa8\xca$\xb6?\xccu\x02&Q\xc5I@G^\x13\xc8\x0b\x0c\xb6?f{\xf5\xecX\xc5I@\xa7\x11\xc1\x0e\xf0!\xb6?Q\xc8g\xc51\xc5I@!9\x19\x94\x8a\xa9\xb6?\x84\xba\xadp\x1d\xc5I@\x03\xdc`\x15\x1a\xf1\xb6?\xa9\x8e\xa6\xa0\x01\xc5I@\x0erV\x8d\xb3R\xb7?\xff\xe0F\xbf\x00\xc5I@\x04\xf5i\x0f\xbeU\xb7?r}h\xf3\xd8\xc4I@\xea'm\x88\xa9\xdf\xb7?\xb7\xfcVd\xd2\xc4I@\xf3;+#\x1c\xf6\xb7?Bu\xe5\xc5\xcf\xc4I@T_\xd4\xe8y\xb3\xb7?kK\xa0y\xce\xc4I@S\xe3\xa2\xed-\x92\xb7?\xcb,\x95E\xc9\xc4I@\x92[\x90\x7fn\xf1\xb6?\xdf\x98w\x93\xcf\xc4I@\x84\xa9\x16\x03l&\xb6?"                                                                                                                                                                                                                                |
# +------+-----------+---------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 3 rows affected.
#
# Indices:
#  - PRIMARY (BTREE): Column year
#  - PRIMARY (BTREE): Column code
#  - idx_geometry (SPATIAL): Column geometry
#
# Table: osm_coords
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#
# Approx Row Count: 3.9 M
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 5 rows affected.
# +-----------+-------------+-------------+
# |   osmid   |   latitude  |  longitude  |
# +-----------+-------------+-------------+
# |  11624001 | 35.07306930 |  6.60139501 |
# | 233988359 | 49.88422196 | -6.34221202 |
# | 233988373 | 49.88430604 | -6.34257657 |
# | 233988123 | 49.88464154 | -6.34160119 |
# | 957849707 | 49.88544286 | -6.34155754 |
# +-----------+-------------+-------------+
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 3 rows affected.
#
# Indices:
#  - PRIMARY (BTREE): Column osmid
#  - idx_coords (BTREE): Column latitude
#  - idx_coords (BTREE): Column longitude
#
# Table: osm_features
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 1 rows affected.
#
# Approx Row Count: 3.9 M
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 5 rows affected.
# +-------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------+--------+--------+---------+------+---------+---------+------------+--------+-------+-------+---------+---------+------------------+---------+
# | osmid |                                                                                                                                                                                                                                                                                            geometry                                                                                                                                                                                                                                                                                            |  building  | levels | height | amenity | shop | tourism | leisure | healthcare | office | craft | sport | highway | landuse | public_transport | railway |
# +-------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------+--------+--------+---------+------+---------+---------+------------+--------+-------+-------+---------+---------+------------------+---------+
# |   38  |               b'\xe6\x10\x00\x00\x01\x02\x00\x00\x00\x0b\x00\x00\x00\x14D\xdd\x07 FJ@\xa3\xdd\xd77\xe6\x0b\xfd\xbf\x1f\xbeL\x14!FJ@\xea\xea\x8e\xc56\t\xfd\xbf"2Q)\x1bFJ@dM\x1b\xc4\xbd\x08\xfd\xbf\xa3\x85\xba\xfe\x13FJ@\xf6\xcbq\xb8\xa0\x08\xfd\xbf\x8fuq\x1b\rFJ@\xb4\xbb\xf6\xbbf\x08\xfd\xbf7d\xf2\xbc\nFJ@\x94\x8db\x14_\x08\xfd\xbf\x19Q\x7fb\tFJ@\xda\xbe\x91\x8a\x10\x08\xfd\xbfnU\x12\xd9\x07FJ@\xde\x01C\xfb\xfd\x07\xfd\xbf3\x9f\xbdD\x06FJ@\xcc\xc7\xa4u\n\x08\xfd\xbf^\xe2#\xbd\x03FJ@\xdcr\xe47;\x08\xfd\xbf\x07\x1f\x94A\xffEJ@\xc0 \x8e\x1a\xb8\x08\xfd\xbf'                |    None    |   0    |  0.0   |   None  | None |   None  |   None  |    None    |  None  |  None |  None | footway |   None  |       None       |   None  |
# |   56  |                                                                                                                                                                             b"\xe6\x10\x00\x00\x01\x02\x00\x00\x00\x04\x00\x00\x00\x9f\x80\x81{\xf9EJ@\x1b\x91\xde&\x92\xfe\xfc\xbf\xb13*\x15\xf9EJ@\xeb}>%B\xfe\xfc\xbf\x9a\x9boD\xf7EJ@\xfe\xba\xd3\x9d'\xfe\xfc\xbf:\xc1Hy\xf7EJ@\x89\xe0n\xff\x80\xfd\xfc\xbf"                                                                                                                                                                             |    None    |   0    |  0.0   |   None  | None |   None  |   None  |    None    |  None  |  None |  None | footway |   None  |       None       |   None  |
# |  114  | b'\xe6\x10\x00\x00\x01\x06\x00\x00\x00\x01\x00\x00\x00\x01\x03\x00\x00\x00\x02\x00\x00\x00\x05\x00\x00\x00#\xc71\xed\xf6\xc1I@\x97\xa1;\xd2*D\xe0\xbf\x19\xac\xdd\x1b\xe8\xc1I@\x873\xbf\x9a\x03D\xe0\xbfl\x06]g\xe8\xc1I@dq\xa4\xd8v?\xe0\xbf\xe1a\xda7\xf7\xc1I@\xa9\xc4\xd0E\x9e?\xe0\xbf#\xc71\xed\xf6\xc1I@\x97\xa1;\xd2*D\xe0\xbf\x05\x00\x00\x00lW\x8d\xca\xf2\xc1I@\x80\x1c\x83\x04{B\xe0\xbf\xff\xcd0Z\xec\xc1I@\x94\x96\xdb\x07jB\xe0\xbf^\x04|m\xec\xc1I@\x94d\xc2\xd4;A\xe0\xbf\xcc\x8d\xd8\xdd\xf2\xc1I@\xb5\xcf\x19\x07MA\xe0\xbflW\x8d\xca\xf2\xc1I@\x80\x1c\x83\x04{B\xe0\xbf' | apartments |   0    |  0.0   |   None  | None |   None  |   None  |    None    |  None  |  None |  None |   None  |   None  |       None       |   None  |
# |  133  |                                  b'\xe6\x10\x00\x00\x01\x02\x00\x00\x00\n\x00\x00\x00\xb4\xc6EZ\xcf\x7fI@D\xc7i\xe3\xe3\xae\xf4\xbf\x13\xa1l%\xcf\x7fI@\x11\x96\x0c[\x0e\xaf\xf4\xbfs{\x93\xf0\xce\x7fI@\x90\xfc\xc1\xc0s\xaf\xf4\xbfaA\xf5j\xdb\x7fI@g\xd3\xb6\x06[\xb1\xf4\xbf\n\xb5\xf0\x06\xe2\x7fI@\x06\xbf\r1^\xb3\xf4\xbf\x05\xbf\xb2w\xeb\x7fI@\xa2=\x03\x8f\x14\xb6\xf4\xbff\x80\xb0\xf8\xf2\x7fI@\x0e\xf8\xfc0B\xb8\xf4\xbfU\xc5T\xfa\t\x80I@\xba\x8f\x92\rZ\xbe\xf4\xbf\xe9b\xd3J!\x80I@S?o*R\xc1\xf4\xbfN"\x0cM#\x80I@\x1d\x1d\xfciH\xc1\xf4\xbf'                                  |    None    |   0    |  0.0   |   None  | None |   None  |   None  |    None    |  None  |  None |  None | footway |   None  |       None       |   None  |
# |  134  |                               b'\xe6\x10\x00\x00\x01\x02\x00\x00\x00\t\x00\x00\x00N\x9bq\x1a\xa2\x81I@\x82\xfa\xe0\xc6w\x13\xf5\xbfA\xe7\x7f\x03\xa4\x81I@\xf6\x82\xaa,e\x14\xf5\xbf\x1c\x00\xbb\xe4\xc9\x81I@\xb9z\x04\xed\xc4\x1b\xf5\xbf\x11a\xb2\xa7\xd3\x81I@\x1f\x19\x06\x87r\x1d\xf5\xbf\x87C%d\xd6\x81I@\x15;\x1a\x87\xfa\x1d\xf5\xbf\xd3\xee\xa1\x8e\xd8\x81I@\x9a\xb0\xa2\xab\x19\x1e\xf5\xbf$)\x8e\xa8\xf5\x81I@\xfc\xbf\x8f\x0f\x1f\x1d\xf5\xbf\xba\xb8\xd7\x93\n\x82I@2\xad\xf2\xa9\x08\x1c\xf5\xbf\x169\x9f\x95\x0f\x82I@\xaf=Xk\xcd\x1b\xf5\xbf'                                |    None    |   0    |  0.0   |   None  | None |   None  |   None  |    None    |  None  |  None |  None | footway |   None  |       None       |   None  |
# +-------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------+--------+--------+---------+------+---------+---------+------------+--------+-------+-------+---------+---------+------------------+---------+
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 17 rows affected.
#
# Indices:
#  - PRIMARY (BTREE): Column osmid
#  - idx_geometry (SPATIAL): Column geometry
#  - idx_building (BTREE): Column building
#  - idx_levels (BTREE): Column levels
#  - idx_height (BTREE): Column height
#  - idx_amenity (BTREE): Column amenity
#  - idx_shop (BTREE): Column shop
#  - idx_tourism (BTREE): Column tourism
#  - idx_leisure (BTREE): Column leisure
#  - idx_healthcare (BTREE): Column healthcare
#  - idx_office (BTREE): Column office
#  - idx_craft (BTREE): Column craft
#  - idx_sport (BTREE): Column sport
#  - idx_highway (BTREE): Column highway
#  - idx_landuse (BTREE): Column landuse
#  - idx_public_transport (BTREE): Column public_transport
#  - idx_railway (BTREE): Column railway

# %% [markdown]
# 2) Please paste a link to your fynesse library below, and make sure it's publically accessible. Also run the code below, and make sure it worked, printing out the contents of your library.

# %%
fynesse_url = '<your-url-library-here>'

# %%
import fynesse
import os

print('FYNESSE STRUCTURE:')
package_path = os.path.dirname(fynesse.__file__)
for root, dirs, files in os.walk(package_path):
    level = root.replace(package_path, '').count(os.sep)
    indent = ' ' * 4 * level
    print(f"{indent}{os.path.basename(root)}/")
    sub_indent = ' ' * 4 * (level + 1)
    for f in files:
        print(f"{sub_indent}{f}")

print('FILE CONTENTS')
for root, dirs, files in os.walk(package_path):
    for file in files:
        file_path = os.path.join(root, file)
        print(f"--- Contents of {file_path} ---\n")
        try:
            with open(file_path, "r", encoding="utf-8") as f:
                print(f.read())
        except Exception as e:
            print(f"Could not read {file_path}: {e}")
        print("\n" + "-" * 50 + "\n")
