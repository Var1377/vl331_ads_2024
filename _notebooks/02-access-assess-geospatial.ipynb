# %% [markdown]
# <a href="https://colab.research.google.com/github/Var1377/vl331_ads_2024/blob/main/_notebooks/02-access-assess-geospatial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practical 2
#
# ### [Radzim Sendyka](https://www.cst.cam.ac.uk/people/rs2071), University
#
# of Cambridge
#
# ### [Christian Cabrera](https://www.cst.cam.ac.uk/people/chc79), University
#
# of Cambridge
#
# ### [Carl Henrik Ek](http://carlhenrik.com), University of Cambridge
#
# ### [Neil D. Lawrence](http://inverseprobability.com), University of
#
# Cambridge
#
# ### 2024-11-07

# %% [markdown]
# **Abstract**: In this lab session we look at working with geospatial
# data, in conjunction with the house prices dataset you created in the
# previous practicals.

# %% [markdown]
# $$
# $$

# %% [markdown]
# ::: {.cell .markdown}
#
# <!-- Do not edit this file locally. -->
# <!-- Do not edit this file locally. -->
# <!---->
# <!-- Do not edit this file locally. -->
# <!-- Do not edit this file locally. -->
# <!-- The last names to be defined. Should be defined entirely in terms of macros from above-->
# <!--
#
# -->
#
# **The check Session for this Practical is 12th November 2024.**
# Prerequisite: practical 1, and a working database with tables price paid
# data (i.e., `pp_data`) and postcodes(i.e., `postcode_data`)
#
# In this lab session we look at working with geospacial data, in
# conjunction with the house prices dataset you created in the previous
# practicals. The goal is to enrich the data from the first practical with
# geographic data enabling better informed data analysis. Access to the
# price paid database is needed to complete some of the below exercises.
# You are asked to write reusable code that will help you in the
# assessment.

# %% [markdown]
# ## Accessing Open Street Maps
#
# <span class="editsection-bracket"
# style="">\[</span><span class="editsection"
# style=""><a href="https://github.com/lawrennd/snippets/edit/main/_datasets/includes/accessing-osm.md" target="_blank" onclick="ga('send', 'event', 'Edit Page', 'Edit', 'https://github.com/lawrennd/snippets/edit/main/_datasets/includes/accessing-osm.md', 13);">edit</a></span><span class="editsection-bracket" style="">\]</span>
#
# [Open Street Maps
# (OSM)](https://www.openstreetmap.org/#map=6/54.91/-3.43) is an open
# geographic database that can provide useful information about different
# locations and places in the planet. In this example, we will download
# data about the city of Kampala, Uganda. As always, we should start by
# installing some Python packages.

# %%
# %pip install osmnx
# Out:
# Collecting osmnx
#   Downloading osmnx-1.9.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting geopandas<0.15,>=0.12 (from osmnx)
#   Downloading geopandas-0.14.4-py3-none-any.whl.metadata (1.5 kB)
# Collecting networkx<3.4,>=2.5 (from osmnx)
#   Downloading networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Collecting numpy<1.27,>=1.20 (from osmnx)
#   Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Requirement already satisfied: pandas<2.3,>=1.1 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from osmnx) (2.2.3)
# Requirement already satisfied: requests<2.33,>=2.27 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from osmnx) (2.32.3)
# Collecting shapely<2.1,>=2.0 (from osmnx)
#   Downloading shapely-2.0.6-cp312-cp312-win_amd64.whl.metadata (7.2 kB)
# Collecting fiona>=1.8.21 (from geopandas<0.15,>=0.12->osmnx)
#   Downloading fiona-1.10.1-cp312-cp312-win_amd64.whl.metadata (58 kB)
# Requirement already satisfied: packaging in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from geopandas<0.15,>=0.12->osmnx) (24.1)
# Collecting pyproj>=3.3.0 (from geopandas<0.15,>=0.12->osmnx)
#   Downloading pyproj-3.7.0-cp312-cp312-win_amd64.whl.metadata (31 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from pandas<2.3,>=1.1->osmnx) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from pandas<2.3,>=1.1->osmnx) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from pandas<2.3,>=1.1->osmnx) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from requests<2.33,>=2.27->osmnx) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from requests<2.33,>=2.27->osmnx) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from requests<2.33,>=2.27->osmnx) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from requests<2.33,>=2.27->osmnx) (2024.7.4)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from fiona>=1.8.21->geopandas<0.15,>=0.12->osmnx) (24.2.0)
# Collecting click~=8.0 (from fiona>=1.8.21->geopandas<0.15,>=0.12->osmnx)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting click-plugins>=1.0 (from fiona>=1.8.21->geopandas<0.15,>=0.12->osmnx)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl.metadata (6.4 kB)
# Collecting cligj>=0.5 (from fiona>=1.8.21->geopandas<0.15,>=0.12->osmnx)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: six>=1.5 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas<2.3,>=1.1->osmnx) (1.16.0)
# Requirement already satisfied: colorama in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from click~=8.0->fiona>=1.8.21->geopandas<0.15,>=0.12->osmnx) (0.4.6)
# Downloading osmnx-1.9.4-py3-none-any.whl (107 kB)
# Downloading geopandas-0.14.4-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 10.9 MB/s eta 0:00:00
# Downloading networkx-3.3-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 18.5 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    --------------- ------------------------ 6.0/15.5 MB 28.4 MB/s eta 0:00:01
#    ------------------------------ --------- 11.8/15.5 MB 30.8 MB/s eta 0:00:01
#    ---------------------------------------- 15.5/15.5 MB 25.1 MB/s eta 0:00:00
# Downloading shapely-2.0.6-cp312-cp312-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 25.7 MB/s eta 0:00:00
# Downloading fiona-1.10.1-cp312-cp312-win_amd64.whl (24.5 MB)
#    ---------------------------------------- 0.0/24.5 MB ? eta -:--:--
#    --------- ------------------------------ 6.0/24.5 MB 28.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 13.9/24.5 MB 33.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 18.1/24.5 MB 28.5 MB/s eta 0:00:01
#    ---------------------------------------  24.1/24.5 MB 28.3 MB/s eta 0:00:01
#    ---------------------------------------- 24.5/24.5 MB 24.6 MB/s eta 0:00:00
# Downloading pyproj-3.7.0-cp312-cp312-win_amd64.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    -------------------------------------- - 6.0/6.2 MB 30.7 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 27.2 MB/s eta 0:00:00
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
# Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Installing collected packages: pyproj, numpy, networkx, click, shapely, cligj, click-plugins, fiona, geopandas, osmnx
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.3
#     Uninstalling numpy-2.1.3:
#       Successfully uninstalled numpy-2.1.3
# Successfully installed click-8.1.7 click-plugins-1.1.1 cligj-0.7.2 fiona-1.10.1 geopandas-0.14.4 networkx-3.3 numpy-1.26.4 osmnx-1.9.4 pyproj-3.7.0 shapely-2.0.6
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\~umpy'.
#   You can safely remove it manually.

# %%
# %pip uninstall --yes matplotlib
# Out:
# Found existing installation: matplotlib 3.9.2
# Uninstalling matplotlib-3.9.2:
#   Successfully uninstalled matplotlib-3.9.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install matplotlib==3.7.1
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Collecting matplotlib==3.7.1
#   Downloading matplotlib-3.7.1.tar.gz (38.0 MB)
#      ---------------------------------------- 0.0/38.0 MB ? eta -:--:--
#      ------ --------------------------------- 6.6/38.0 MB 33.6 MB/s eta 0:00:01
#      ------------ -------------------------- 12.6/38.0 MB 30.3 MB/s eta 0:00:01
#      ------------------- ------------------- 19.1/38.0 MB 30.2 MB/s eta 0:00:01
#      --------------------------- ----------- 26.5/38.0 MB 31.1 MB/s eta 0:00:01
#      ---------------------------------- ---- 33.6/38.0 MB 31.3 MB/s eta 0:00:01
#      --------------------------------------  37.7/38.0 MB 31.2 MB/s eta 0:00:01
#      --------------------------------------- 38.0/38.0 MB 28.8 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from matplotlib==3.7.1) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from matplotlib==3.7.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from matplotlib==3.7.1) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from matplotlib==3.7.1) (1.4.7)
# Requirement already satisfied: numpy>=1.20 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from matplotlib==3.7.1) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from matplotlib==3.7.1) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from matplotlib==3.7.1) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from matplotlib==3.7.1) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from matplotlib==3.7.1) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib==3.7.1) (1.16.0)
# Building wheels for collected packages: matplotlib
#   Building wheel for matplotlib (pyproject.toml): started
#   Building wheel for matplotlib (pyproject.toml): still running...
#   Building wheel for matplotlib (pyproject.toml): finished with status 'done'
#   Created wheel for matplotlib: filename=matplotlib-3.7.1-cp312-cp312-win_amd64.whl size=7291977 sha256=6f2b1d0a1dd0c4a64b625263d4aa84f51020c882fd5639c86e5d9ea9e004b440
#   Stored in directory: c:\users\varun\appdata\local\pip\cache\wheels\1c\06\fa\3453aac11411fac092c1bdfe52815f2f6969a42700d977e62f
# Successfully built matplotlib
# Installing collected packages: matplotlib
# Successfully installed matplotlib-3.7.1

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# load the fynesse library from github
# %pip uninstall --yes fynesse
# %pip install git+https://github.com/Var1377/vl331_ads_2024.git
# Out:
# Found existing installation: fynesse 0.1.0
# Uninstalling fynesse-0.1.0:
#   Successfully uninstalled fynesse-0.1.0
# Note: you may need to restart the kernel to use updated packages.
# C:\Users\varun\AppData\Roaming\Python\Python312\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedWriter name=4>
#   return process_handler(cmd, _system_body)
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\varun\AppData\Roaming\Python\Python312\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedReader name=5>
#   return process_handler(cmd, _system_body)
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\varun\AppData\Roaming\Python\Python312\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedReader name=6>
#   return process_handler(cmd, _system_body)
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# Collecting git+https://github.com/Var1377/vl331_ads_2024.git
#   Cloning https://github.com/Var1377/vl331_ads_2024.git to c:\users\varun\appdata\local\temp\pip-req-build-ecjtioyh
#   Resolved https://github.com/Var1377/vl331_ads_2024.git to commit 7402776bcece91d8c12246e70f32c659ade3244d
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: pandas in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from fynesse==0.1.0) (2.2.3)
# Requirement already satisfied: numpy in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from fynesse==0.1.0) (1.26.3)
# Requirement already satisfied: jupyter in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from fynesse==0.1.0) (1.1.1)
# Requirement already satisfied: matplotlib in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from fynesse==0.1.0) (3.9.2)
# Requirement already satisfied: pymysql in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from fynesse==0.1.0) (1.1.1)
# Requirement already satisfied: scikit-learn in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from fynesse==0.1.0) (1.5.2)
# Requirement already satisfied: seaborn in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from fynesse==0.1.0) (0.13.2)
# Requirement already satisfied: geopandas in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from fynesse==0.1.0) (0.14.4)
# Requirement already satisfied: osmnx in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from fynesse==0.1.0) (1.9.4)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from geopandas->fynesse==0.1.0) (1.10.1)
# Requirement already satisfied: packaging in c:\users\varun\appdata\roaming\python\python312\site-packages (from geopandas->fynesse==0.1.0) (23.2)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from geopandas->fynesse==0.1.0) (3.7.0)
# Requirement already satisfied: shapely>=1.8.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from geopandas->fynesse==0.1.0) (2.0.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\varun\appdata\roaming\python\python312\site-packages (from pandas->fynesse==0.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from pandas->fynesse==0.1.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from pandas->fynesse==0.1.0) (2024.2)
# Requirement already satisfied: notebook in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jupyter->fynesse==0.1.0) (7.2.2)
# Requirement already satisfied: jupyter-console in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jupyter->fynesse==0.1.0) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jupyter->fynesse==0.1.0) (7.16.4)
# Requirement already satisfied: ipykernel in c:\users\varun\appdata\roaming\python\python312\site-packages (from jupyter->fynesse==0.1.0) (6.25.2)
# Requirement already satisfied: ipywidgets in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jupyter->fynesse==0.1.0) (8.1.5)
# Requirement already satisfied: jupyterlab in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jupyter->fynesse==0.1.0) (4.2.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->fynesse==0.1.0) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->fynesse==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->fynesse==0.1.0) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->fynesse==0.1.0) (1.4.7)
# Requirement already satisfied: pillow>=8 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->fynesse==0.1.0) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->fynesse==0.1.0) (3.2.0)
# Requirement already satisfied: networkx<3.4,>=2.5 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from osmnx->fynesse==0.1.0) (3.2.1)
# Requirement already satisfied: requests<2.33,>=2.27 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from osmnx->fynesse==0.1.0) (2.32.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->fynesse==0.1.0) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->fynesse==0.1.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->fynesse==0.1.0) (3.5.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from fiona>=1.8.21->geopandas->fynesse==0.1.0) (24.2.0)
# Requirement already satisfied: certifi in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from fiona>=1.8.21->geopandas->fynesse==0.1.0) (2024.8.30)
# Requirement already satisfied: click~=8.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from fiona>=1.8.21->geopandas->fynesse==0.1.0) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from fiona>=1.8.21->geopandas->fynesse==0.1.0) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from fiona>=1.8.21->geopandas->fynesse==0.1.0) (0.7.2)
# Requirement already satisfied: six>=1.5 in c:\users\varun\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas->fynesse==0.1.0) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from requests<2.33,>=2.27->osmnx->fynesse==0.1.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from requests<2.33,>=2.27->osmnx->fynesse==0.1.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from requests<2.33,>=2.27->osmnx->fynesse==0.1.0) (2.2.3)
# Requirement already satisfied: comm>=0.1.1 in c:\users\varun\appdata\roaming\python\python312\site-packages (from ipykernel->jupyter->fynesse==0.1.0) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\varun\appdata\roaming\python\python312\site-packages (from ipykernel->jupyter->fynesse==0.1.0) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\varun\appdata\roaming\python\python312\site-packages (from ipykernel->jupyter->fynesse==0.1.0) (8.16.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\varun\appdata\roaming\python\python312\site-packages (from ipykernel->jupyter->fynesse==0.1.0) (8.4.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\varun\appdata\roaming\python\python312\site-packages (from ipykernel->jupyter->fynesse==0.1.0) (5.4.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\varun\appdata\roaming\python\python312\site-packages (from ipykernel->jupyter->fynesse==0.1.0) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\varun\appdata\roaming\python\python312\site-packages (from ipykernel->jupyter->fynesse==0.1.0) (1.5.8)
# Requirement already satisfied: psutil in c:\users\varun\appdata\roaming\python\python312\site-packages (from ipykernel->jupyter->fynesse==0.1.0) (5.9.6)
# Requirement already satisfied: pyzmq>=20 in c:\users\varun\appdata\roaming\python\python312\site-packages (from ipykernel->jupyter->fynesse==0.1.0) (25.1.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\varun\appdata\roaming\python\python312\site-packages (from ipykernel->jupyter->fynesse==0.1.0) (6.3.3)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\varun\appdata\roaming\python\python312\site-packages (from ipykernel->jupyter->fynesse==0.1.0) (5.11.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets->jupyter->fynesse==0.1.0) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets->jupyter->fynesse==0.1.0) (3.0.13)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\varun\appdata\roaming\python\python312\site-packages (from jupyter-console->jupyter->fynesse==0.1.0) (3.0.39)
# Requirement already satisfied: pygments in c:\users\varun\appdata\roaming\python\python312\site-packages (from jupyter-console->jupyter->fynesse==0.1.0) (2.16.1)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab->jupyter->fynesse==0.1.0) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab->jupyter->fynesse==0.1.0) (0.27.2)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab->jupyter->fynesse==0.1.0) (3.1.3)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab->jupyter->fynesse==0.1.0) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab->jupyter->fynesse==0.1.0) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab->jupyter->fynesse==0.1.0) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab->jupyter->fynesse==0.1.0) (0.2.4)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab->jupyter->fynesse==0.1.0) (70.0.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->fynesse==0.1.0) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->fynesse==0.1.0) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->fynesse==0.1.0) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->fynesse==0.1.0) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->fynesse==0.1.0) (2.1.5)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->fynesse==0.1.0) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->fynesse==0.1.0) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->fynesse==0.1.0) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->fynesse==0.1.0) (1.5.1)
# Requirement already satisfied: tinycss2 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->fynesse==0.1.0) (1.4.0)
# Requirement already satisfied: webencodings in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter->fynesse==0.1.0) (0.5.1)
# Requirement already satisfied: colorama in c:\users\varun\appdata\roaming\python\python312\site-packages (from click~=8.0->fiona>=1.8.21->geopandas->fynesse==0.1.0) (0.4.6)
# Requirement already satisfied: anyio in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter->fynesse==0.1.0) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter->fynesse==0.1.0) (1.0.6)
# Requirement already satisfied: sniffio in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter->fynesse==0.1.0) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter->fynesse==0.1.0) (0.14.0)
# Requirement already satisfied: backcall in c:\users\varun\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel->jupyter->fynesse==0.1.0) (0.2.0)
# Requirement already satisfied: decorator in c:\users\varun\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel->jupyter->fynesse==0.1.0) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\varun\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel->jupyter->fynesse==0.1.0) (0.19.1)
# Requirement already satisfied: pickleshare in c:\users\varun\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel->jupyter->fynesse==0.1.0) (0.7.5)
# Requirement already satisfied: stack-data in c:\users\varun\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel->jupyter->fynesse==0.1.0) (0.6.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\varun\appdata\roaming\python\python312\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->fynesse==0.1.0) (3.11.0)
# Requirement already satisfied: pywin32>=300 in c:\users\varun\appdata\roaming\python\python312\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->fynesse==0.1.0) (306)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->fynesse==0.1.0) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->fynesse==0.1.0) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->fynesse==0.1.0) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->fynesse==0.1.0) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->fynesse==0.1.0) (0.21.0)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->fynesse==0.1.0) (2.0.14)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->fynesse==0.1.0) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->fynesse==0.1.0) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->fynesse==0.1.0) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->fynesse==0.1.0) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->fynesse==0.1.0) (0.9.27)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->fynesse==0.1.0) (4.23.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter->fynesse==0.1.0) (2.20.0)
# Requirement already satisfied: wcwidth in c:\users\varun\appdata\roaming\python\python312\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->fynesse==0.1.0) (0.2.8)
# Requirement already satisfied: soupsieve>1.2 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->fynesse==0.1.0) (2.6)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->fynesse==0.1.0) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\varun\appdata\roaming\python\python312\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->fynesse==0.1.0) (0.8.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->fynesse==0.1.0) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->fynesse==0.1.0) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->fynesse==0.1.0) (0.21.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->fynesse==0.1.0) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->fynesse==0.1.0) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->fynesse==0.1.0) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->fynesse==0.1.0) (0.1.1)
# Requirement already satisfied: executing>=1.2.0 in c:\users\varun\appdata\roaming\python\python312\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->fynesse==0.1.0) (2.0.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\varun\appdata\roaming\python\python312\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->fynesse==0.1.0) (2.4.0)
# Requirement already satisfied: pure-eval in c:\users\varun\appdata\roaming\python\python312\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->fynesse==0.1.0) (0.2.2)
# Requirement already satisfied: fqdn in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->fynesse==0.1.0) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->fynesse==0.1.0) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->fynesse==0.1.0) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->fynesse==0.1.0) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->fynesse==0.1.0) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->fynesse==0.1.0) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->fynesse==0.1.0) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->fynesse==0.1.0) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->fynesse==0.1.0) (2.9.0.20241003)
# Building wheels for collected packages: fynesse
#   Building wheel for fynesse (pyproject.toml): started
#   Building wheel for fynesse (pyproject.toml): finished with status 'done'
#   Created wheel for fynesse: filename=fynesse-0.1.0-py3-none-any.whl size=9049 sha256=ac5cc31f4a0a0cd8b68e94e03078eaeeaa6b0de341dbca571be9db11f962cb60
#   Stored in directory: C:\Users\varun\AppData\Local\Temp\pip-ephem-wheel-cache-ko0kgwl7\wheels\bf\cc\90\4c751d573d7d0fd1ffb8d6712daf54060f43f3e95f6f0368ff
# Successfully built fynesse
# Installing collected packages: fynesse
# Successfully installed fynesse-0.1.0
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/Var1377/vl331_ads_2024.git 'C:\Users\varun\AppData\Local\Temp\pip-req-build-ecjtioyh'

# %%
import osmnx as ox
import matplotlib.pyplot as plt
import warnings
import fynesse
import pandas as pd
warnings.filterwarnings("ignore", category=FutureWarning, module='osmnx')

# %% [markdown]
# We will download data of Kamplala, Uganda, which has the following
# latitude and longitude.

# %%
place_name = "Kampala, Uganda"

latitude = 0.347596 # Kampala latitude
longitude = 32.582520 # Kampala longitude

# %%
placestub = place_name.lower().replace(' ', '-').replace(',','')

# %% [markdown]
# We’ll create a bounding box which is 0.02 degrees wide, 1 degree is
# around 111km ([circumference of the Earth is around 40,000
# km](https://en.wikipedia.org/wiki/Metre) and 40,000/360=111km). Note:
# will this approximation work well in all countries?

# %%
box_width = 0.02 # About 2.2 km
box_height = 0.02
north = latitude + box_height/2
south = latitude - box_width/2
west = longitude - box_width/2
east = longitude + box_width/2

# %% [markdown]
# Now we’ll download a set of points of interest from OpenStreetMap. We
# can specify the points of interest we’re interested in by building a
# small dictionary containing their labels as follows. A Point of Interest
# is a location with certain importance in the geographic area. They can
# vary from amenities to touristic places as you can see in the following.

# %%
# Retrieve POIs
tags = {
    "amenity": True,
    "buildings": True,
    "historic": True,
    "leisure": True,
    "shop": True,
    "tourism": True,
    "religion": True,
    "memorial": True
}

# %% [markdown]
# We can use `osmnx` to download all such points of interest within a
# given bounding box.

# %%
pois = ox.geometries_from_bbox(north, south, east, west, tags)
# Out:
# C:\Users\varun\AppData\Local\Temp\ipykernel_169208\1281167846.py:1: FutureWarning: The `geometries` module and `geometries_from_X` functions have been renamed the `features` module and `features_from_X` functions. Use these instead. The `geometries` module and function names are deprecated and will be removed in the v2.0.0 release. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   pois = ox.geometries_from_bbox(north, south, east, west, tags)

# %% [markdown]
# That operation can take some time, particularly as the bounding box
# grows larger. Once it is complete we can check how many points of
# interest we have found.

# %%
print("There are {number} points of interest surrounding {placename} latitude: {latitude}, longitude: {longitude}".format(number=len(pois), placename=place_name, latitude=latitude, longitude=longitude))
# Out:
# There are 880 points of interest surrounding Kampala, Uganda latitude: 0.347596, longitude: 32.58252

# %% [markdown]
# And then we can examine their contents in more detail.

# %%
pois
# Out:
#                         addr:housenumber  addr:street      amenity  cuisine  \
# element_type osmid
# node         599171967           Plot 21  Cooper Road   restaurant  mexican
#              599171968               NaN          NaN          NaN      NaN
#              599171969               NaN          NaN          NaN      NaN
#              599171971               NaN          NaN     pharmacy      NaN
#              601370312               NaN          NaN         fuel      NaN
# ...                                  ...          ...          ...      ...
# way          1156972448              NaN          NaN  marketplace      NaN
#              1156972449              NaN          NaN  marketplace      NaN
#              1156972454              NaN          NaN  marketplace      NaN
#              1156972457              NaN          NaN  marketplace      NaN
#              1156972468              NaN          NaN  marketplace      NaN
#
#                                             name            phone  \
# element_type osmid
# node         599171967                  Que Pasa  +256 783 874469
#              599171968    Millennium Supermarket              NaN
#              599171969                  Checkers              NaN
#              599171971   Makro Pharmacy (U) Ltd.              NaN
#              601370312                     Kobil              NaN
# ...                                          ...              ...
# way          1156972448                      NaN              NaN
#              1156972449                      NaN              NaN
#              1156972454                      NaN              NaN
#              1156972457                      NaN              NaN
#              1156972468                      NaN              NaN
#
#                                                                    website  \
# element_type osmid
# node         599171967             https://www.facebook.com/quepasakampala
#              599171968   http://www.millenniumsupermarket.com/profile.html
#              599171969                                                 NaN
#              599171971                                                 NaN
#              601370312                                                 NaN
# ...                                                                    ...
# way          1156972448                                                NaN
#              1156972449                                                NaN
#              1156972454                                                NaN
#              1156972457                                                NaN
#              1156972468                                                NaN
#
#                                                                   geometry  \
# element_type osmid
# node         599171967                            POINT (32.58830 0.33888)
#              599171968                            POINT (32.58734 0.33821)
#              599171969                            POINT (32.58817 0.33865)
#              599171971                            POINT (32.58793 0.33845)
#              601370312                            POINT (32.58904 0.34189)
# ...                                                                    ...
# way          1156972448  POLYGON ((32.59044 0.34826, 32.59079 0.34818, ...
#              1156972449  POLYGON ((32.59025 0.34807, 32.59037 0.34829, ...
#              1156972454  POLYGON ((32.59120 0.34825, 32.59121 0.34818, ...
#              1156972457  POLYGON ((32.59168 0.34846, 32.59168 0.34837, ...
#              1156972468  POLYGON ((32.59155 0.34854, 32.59155 0.34839, ...
#
#                                 shop  brand  ... roof:shape community_centre  \
# element_type osmid                           ...
# node         599171967           NaN    NaN  ...        NaN              NaN
#              599171968   supermarket    NaN  ...        NaN              NaN
#              599171969   supermarket    NaN  ...        NaN              NaN
#              599171971           NaN    NaN  ...        NaN              NaN
#              601370312           NaN  Kobil  ...        NaN              NaN
# ...                              ...    ...  ...        ...              ...
# way          1156972448          NaN    NaN  ...        NaN              NaN
#              1156972449          NaN    NaN  ...        NaN              NaN
#              1156972454          NaN    NaN  ...        NaN              NaN
#              1156972457          NaN    NaN  ...        NaN              NaN
#              1156972468          NaN    NaN  ...        NaN              NaN
#
#                         denomination  bus public_transport multipurpose  \
# element_type osmid
# node         599171967           NaN  NaN              NaN          NaN
#              599171968           NaN  NaN              NaN          NaN
#              599171969           NaN  NaN              NaN          NaN
#              599171971           NaN  NaN              NaN          NaN
#              601370312           NaN  NaN              NaN          NaN
# ...                              ...  ...              ...          ...
# way          1156972448          NaN  NaN              NaN          NaN
#              1156972449          NaN  NaN              NaN          NaN
#              1156972454          NaN  NaN              NaN          NaN
#              1156972457          NaN  NaN              NaN          NaN
#              1156972468          NaN  NaN              NaN          NaN
#
#                         contact:twitter rooms guest_house smoking
# element_type osmid
# node         599171967              NaN   NaN         NaN     NaN
#              599171968              NaN   NaN         NaN     NaN
#              599171969              NaN   NaN         NaN     NaN
#              599171971              NaN   NaN         NaN     NaN
#              601370312              NaN   NaN         NaN     NaN
# ...                                 ...   ...         ...     ...
# way          1156972448             NaN   NaN         NaN     NaN
#              1156972449             NaN   NaN         NaN     NaN
#              1156972454             NaN   NaN         NaN     NaN
#              1156972457             NaN   NaN         NaN     NaN
#              1156972468             NaN   NaN         NaN     NaN
#
# [880 rows x 134 columns]

# %% [markdown]
# ### We notice a few things:
#
# 1.  Points of interest do not have a consistent OpenStreetMap
#     `element_type`, some are `node`, others are `relation` and we also
#     have `way`. You can find out more about elements in OpenStreetMap on
#     [this wiki page](https://wiki.openstreetmap.org/wiki/Elements). This
#     will become important when tidying up the data for next stage
#     processing.
#
# 2.  Many of the values are missing. In SQL we would express a missing
#     value as `NULL`. But in `pandas` a missing value is expressed as
#     not-a-number, `NaN`. This is quite a common standard, but it is not
#     the only standard. Sometimes data is collected and coded with an
#     “unreasonable” value for a missing value. For example, someone might
#     set missing values for heights to -999. The concept is that this is
#     an obviously void “height” and would trigger a human user to check
#     whether it’s a missing value. Of course, this is obvious to humans,
#     but not necessarily to a computer!
#
# Nodes, ways and relations in OpenStreetMap all have different *keys*
# associated with them. The data is not structured in standard database
# columns. Different points of interest might have different keys present
# or absent. We might be interested in the following keys.

# %%
keys = ["name",
        "addr:city",
        "addr:postcode",
        "amenity",
        "building",
        "building:name",
        "building:colour",
        "building:material",
        "historic",
        "memorial",
        "religion",
        "tourism",
        "emergency",
        "leisure",
        "shop"]

# %% [markdown]
# But our downloaded `gdf` may have fewer keys.

# %%
pois.columns.values
# Out:
# array(['addr:housenumber', 'addr:street', 'amenity', 'cuisine', 'name',
#        'phone', 'website', 'geometry', 'shop', 'brand', 'brand:wikidata',
#        'brand:wikipedia', 'compressed_air', 'opening_hours', 'wheelchair',
#        'access', 'capacity', 'parking', 'healthcare', 'addr:city',
#        'addr:country', 'branch', 'note', 'designation', 'fee',
#        'diet:halal', 'diet:kosher', 'payment:credit_cards',
#        'payment:debit_cards', 'diet:vegan', 'diet:vegetarian',
#        'internet_access', 'outdoor_seating', 'operator', 'alt_name',
#        'drive_through', 'level', 'takeaway', 'email', 'tourism',
#        'contact:email', 'contact:facebook', 'contact:instagram',
#        'contact:phone', 'check_date:opening_hours', 'internet_access:fee',
#        'operator:wikidata', 'atm', 'facebook', 'network', 'short_name',
#        'check_date', 'fixme', 'addr:suburb', 'office', 'leisure', 'sport',
#        'lit', 'supervised', 'surface', 'covered', 'addr:flats', 'beauty',
#        'payment:cards', 'payment:cash', 'female', 'male',
#        'contact:website', 'description', 'bed_count', 'wikidata',
#        'name:en', 'cash_in', 'operational_status', 'building', 'function',
#        'religion', 'information', 'name:de', 'addr:place', 'legal',
#        'recycling_type', 'waste', 'operator:type', 'backrest',
#        'healthcare:speciality', 'addr:county', 'addr:district',
#        'addr:parish', 'addr:subcounty', 'isced:level', 'source',
#        'staff_count:teachers', 'start_date', 'type', 'bicycle_parking',
#        'wikipedia', 'place:village', 'beds', 'capacity:inpatient',
#        'capacity:outpatient', 'staff_count:doctors', 'staff_count:nurses',
#        'toilets', 'toilets:access', 'toilets:num_chambers',
#        'generator:source', 'emergency', 'contact', 'grades',
#        'operational', 'addr:village', 'loading_dock', 'product',
#        'addr:postcode', 'certification', 'power', 'craft', 'grade',
#        'nodes', 'source:date', 'building:levels', 'building:material',
#        'roof:levels', 'roof:shape', 'community_centre', 'denomination',
#        'bus', 'public_transport', 'multipurpose', 'contact:twitter',
#        'rooms', 'guest_house', 'smoking'], dtype=object)

# %% [markdown]
# We can write a short piece of code to discover which keys are missing
# drom the data frame’s columns.

# %%
for key in keys:
    if key not in pois.columns:
        print(key)

present_keys = [key for key in keys if key in pois.columns]
pois[present_keys]
# Out:
# building:name
# building:colour
# historic
# memorial
#                                             name addr:city addr:postcode  \
# element_type osmid
# node         599171967                  Que Pasa       NaN           NaN
#              599171968    Millennium Supermarket       NaN           NaN
#              599171969                  Checkers       NaN           NaN
#              599171971   Makro Pharmacy (U) Ltd.       NaN           NaN
#              601370312                     Kobil       NaN           NaN
# ...                                          ...       ...           ...
# way          1156972448                      NaN       NaN           NaN
#              1156972449                      NaN       NaN           NaN
#              1156972454                      NaN       NaN           NaN
#              1156972457                      NaN       NaN           NaN
#              1156972468                      NaN       NaN           NaN
#
#                              amenity building building:material religion  \
# element_type osmid
# node         599171967    restaurant      NaN               NaN      NaN
#              599171968           NaN      NaN               NaN      NaN
#              599171969           NaN      NaN               NaN      NaN
#              599171971      pharmacy      NaN               NaN      NaN
#              601370312          fuel      NaN               NaN      NaN
# ...                              ...      ...               ...      ...
# way          1156972448  marketplace      NaN               NaN      NaN
#              1156972449  marketplace      NaN               NaN      NaN
#              1156972454  marketplace      NaN               NaN      NaN
#              1156972457  marketplace      NaN               NaN      NaN
#              1156972468  marketplace      NaN               NaN      NaN
#
#                         tourism emergency leisure         shop
# element_type osmid
# node         599171967      NaN       NaN     NaN          NaN
#              599171968      NaN       NaN     NaN  supermarket
#              599171969      NaN       NaN     NaN  supermarket
#              599171971      NaN       NaN     NaN          NaN
#              601370312      NaN       NaN     NaN          NaN
# ...                         ...       ...     ...          ...
# way          1156972448     NaN       NaN     NaN          NaN
#              1156972449     NaN       NaN     NaN          NaN
#              1156972454     NaN       NaN     NaN          NaN
#              1156972457     NaN       NaN     NaN          NaN
#              1156972468     NaN       NaN     NaN          NaN
#
# [880 rows x 11 columns]

# %% [markdown]
# This gives us the relevant points of interest (part of the map). If we’d
# like to see the entire street network, we can download the entire graph
# from the location.

# %%
graph = ox.graph_from_bbox(north, south, east, west)

# Retrieve nodes and edges
nodes, edges = ox.graph_to_gdfs(graph)

# Get place boundary related to the place name as a geodataframe
area = ox.geocode_to_gdf(place_name)
# Out:
# C:\Users\varun\AppData\Local\Temp\ipykernel_169208\1038450013.py:1: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(north, south, east, west)
# C:\Users\varun\AppData\Local\Temp\ipykernel_169208\1038450013.py:1: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(north, south, east, west)

# %% [markdown]
# Which we can then render as follows.

# %%
import matplotlib.pyplot as plt

# !pip install --upgrade matplotlib
# Out:
# ^C
# Requirement already satisfied: matplotlib in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\varun\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\threading.py:1014: ResourceWarning: unclosed file <_io.BufferedWriter name=3>
#   del self._target, self._args, self._kwargs
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\threading.py:1014: ResourceWarning: unclosed file <_io.BufferedReader name=4>
#   del self._target, self._args, self._kwargs
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\threading.py:1014: ResourceWarning: unclosed file <_io.BufferedReader name=5>
#   del self._target, self._args, self._kwargs
# ResourceWarning: Enable tracemalloc to get the object allocation traceback

# %%
fig, ax = plt.subplots()

# Plot the footprint
area.plot(ax=ax, facecolor="white")

# Plot street edges
edges.plot(ax=ax, linewidth=1, edgecolor="dimgray")

ax.set_xlim([west, east])
ax.set_ylim([south, north])
ax.set_xlabel("longitude")
ax.set_ylabel("latitude")

# Plot all POIs
pois.plot(ax=ax, color="blue", alpha=0.7, markersize=10)
plt.tight_layout()

# %%
# Plot a subset of the POIs (e.g., tourist places)
# Create figure
fig, ax = plt.subplots()

# Plot the footprint
area.plot(ax=ax, facecolor="white")

# Plot street edges
edges.plot(ax=ax, linewidth=1, edgecolor="dimgray")

ax.set_xlim([west, east])
ax.set_ylim([south, north])
ax.set_xlabel("longitude")
ax.set_ylabel("latitude")

# Plot tourist places
tourist_places = pois[pois.tourism.notnull()]
tourist_places.plot(ax=ax, color="blue", alpha=1, markersize=50)
plt.tight_layout()

# %% [markdown]
# We have the POI information on all tourist places structured in a
# geodataframe. To work with them in a machine learning algorithm, it will
# be easier to convert them to a pandas DataFrame.

# %%
import pandas as pd

# %%
pois_df = pd.DataFrame(pois)
pois_df['latitude'] = pois_df.apply(lambda row: row.geometry.centroid.y, axis=1)
pois_df['longitude'] = pois_df.apply(lambda row: row.geometry.centroid.x, axis=1)

tourist_places_df = pois_df[pois_df.tourism.notnull()]
print(len(tourist_places_df))
tourist_places_df
# Out:
# 16
#                         addr:housenumber           addr:street  \
# element_type osmid
# node         3032234586              NaN                   NaN
#              4119308804              NaN                   NaN
#              4942954054              NaN                   NaN
#              5678162422              NaN                   NaN
#              7743212629              NaN                   NaN
#              8445011017              NaN      Kisingiri Street
#              8456545033              NaN          Mawanda Road
#              8456545129              NaN          Mawanda Road
#              8481722617              NaN                   NaN
#              8498971118              NaN                   NaN
#              8597526517              NaN                   NaN
#              8686698118              NaN          Oketcho Road
#              8686698119              NaN           Kasubi Road
#              8778105111          8HQJ+XW  New Mulago Gate Road
# way          437577068           Plot 72            Kiira Road
#              649469461               NaN                   NaN
#
#                                     amenity cuisine  \
# element_type osmid
# node         3032234586                 NaN     NaN
#              4119308804  mobile_money_agent     NaN
#              4942954054                 NaN     NaN
#              5678162422                 NaN     NaN
#              7743212629                 NaN     NaN
#              8445011017                 NaN     NaN
#              8456545033                 NaN     NaN
#              8456545129                 NaN     NaN
#              8481722617                 NaN     NaN
#              8498971118                 NaN     NaN
#              8597526517                 NaN     NaN
#              8686698118                 NaN     NaN
#              8686698119                 NaN     NaN
#              8778105111                 NaN     NaN
# way          437577068                  NaN     NaN
#              649469461                  NaN     NaN
#
#                                               name            phone  \
# element_type osmid
# node         3032234586                    Fat Cat  +256 771 393892
#              4119308804                Green apple              NaN
#              4942954054                Okrut Close              NaN
#              5678162422          Tagore Apartments              NaN
#              7743212629                        NaN              NaN
#              8445011017               Prisma Hotel       0414371122
#              8456545033          Silverline Condos              NaN
#              8456545129            Kida Guesthouse              NaN
#              8481722617           Koda Guest House              NaN
#              8498971118         Mulago Guest House              NaN
#              8597526517           Papa Guest house              NaN
#              8686698118          Silent Corner inn              NaN
#              8686698119           Kerona Dam Hotel              NaN
#              8778105111                 Nyumba 591    +256792172017
# way          437577068   Hilton Garden Inn Kampala  +256 31 3800800
#              649469461    Ku spot inn accomodation              NaN
#
#                                                                    website  \
# element_type osmid
# node         3032234586                      http://www.fatcatkampala.com/
#              4119308804                                                NaN
#              4942954054                                                NaN
#              5678162422                                                NaN
#              7743212629                                                NaN
#              8445011017                                                NaN
#              8456545033                                                NaN
#              8456545129                                                NaN
#              8481722617                                                NaN
#              8498971118                                                NaN
#              8597526517                                                NaN
#              8686698118                                                NaN
#              8686698119                                                NaN
#              8778105111                         https://www.nyumba591.com/
# way          437577068   https://www.hilton.com/en/hotels/klakrgi-hilto...
#              649469461                                                 NaN
#
#                                                                   geometry  \
# element_type osmid
# node         3032234586                           POINT (32.58834 0.33994)
#              4119308804                           POINT (32.58817 0.34264)
#              4942954054                           POINT (32.59180 0.33868)
#              5678162422                           POINT (32.58474 0.33914)
#              7743212629                           POINT (32.58812 0.34466)
#              8445011017                           POINT (32.57987 0.34816)
#              8456545033                           POINT (32.58329 0.34251)
#              8456545129                           POINT (32.57336 0.34773)
#              8481722617                           POINT (32.57340 0.34824)
#              8498971118                           POINT (32.57883 0.34850)
#              8597526517                           POINT (32.57918 0.35097)
#              8686698118                           POINT (32.58197 0.35119)
#              8686698119                           POINT (32.58485 0.35106)
#              8778105111                           POINT (32.58247 0.34012)
# way          437577068   POLYGON ((32.58394 0.33763, 32.58404 0.33783, ...
#              649469461   POLYGON ((32.57274 0.34776, 32.57274 0.34780, ...
#
#                         shop              brand  ... denomination  bus  \
# element_type osmid                               ...
# node         3032234586  NaN                NaN  ...          NaN  NaN
#              4119308804  NaN                NaN  ...          NaN  NaN
#              4942954054  NaN                NaN  ...          NaN  NaN
#              5678162422  NaN                NaN  ...          NaN  NaN
#              7743212629  NaN                NaN  ...          NaN  NaN
#              8445011017  NaN                NaN  ...          NaN  NaN
#              8456545033  NaN                NaN  ...          NaN  NaN
#              8456545129  NaN                NaN  ...          NaN  NaN
#              8481722617  NaN                NaN  ...          NaN  NaN
#              8498971118  NaN                NaN  ...          NaN  NaN
#              8597526517  NaN                NaN  ...          NaN  NaN
#              8686698118  NaN                NaN  ...          NaN  NaN
#              8686698119  NaN                NaN  ...          NaN  NaN
#              8778105111  NaN                NaN  ...          NaN  NaN
# way          437577068   NaN  Hilton Garden Inn  ...          NaN  NaN
#              649469461   NaN                NaN  ...          NaN  NaN
#
#                         public_transport multipurpose  \
# element_type osmid
# node         3032234586              NaN          NaN
#              4119308804              NaN          NaN
#              4942954054              NaN          NaN
#              5678162422              NaN          NaN
#              7743212629              NaN          NaN
#              8445011017              NaN          NaN
#              8456545033              NaN          NaN
#              8456545129              NaN          NaN
#              8481722617              NaN          NaN
#              8498971118              NaN          NaN
#              8597526517              NaN          NaN
#              8686698118              NaN          NaN
#              8686698119              NaN          NaN
#              8778105111              NaN          NaN
# way          437577068               NaN          NaN
#              649469461               NaN          NaN
#
#                                         contact:twitter rooms guest_house  \
# element_type osmid
# node         3032234586                             NaN   NaN         NaN
#              4119308804                             NaN   NaN         NaN
#              4942954054                             NaN   NaN         NaN
#              5678162422                             NaN   NaN         NaN
#              7743212629                             NaN   NaN         NaN
#              8445011017                             NaN   NaN         NaN
#              8456545033                             NaN   NaN         NaN
#              8456545129                             NaN   NaN         NaN
#              8481722617                             NaN   NaN         NaN
#              8498971118                             NaN   NaN         NaN
#              8597526517                             NaN   NaN         NaN
#              8686698118                             NaN   NaN         NaN
#              8686698119                             NaN   NaN         NaN
#              8778105111                             NaN   NaN         NaN
# way          437577068   https://twitter.com/hgikampala    96         NaN
#              649469461                              NaN   NaN         inn
#
#                         smoking  latitude  longitude
# element_type osmid
# node         3032234586     NaN  0.339942  32.588339
#              4119308804     NaN  0.342644  32.588168
#              4942954054     NaN  0.338675  32.591800
#              5678162422     NaN  0.339140  32.584741
#              7743212629     NaN  0.344656  32.588117
#              8445011017     NaN  0.348161  32.579872
#              8456545033     NaN  0.342511  32.583290
#              8456545129     NaN  0.347735  32.573358
#              8481722617     NaN  0.348238  32.573398
#              8498971118     NaN  0.348499  32.578828
#              8597526517     NaN  0.350970  32.579181
#              8686698118     NaN  0.351190  32.581971
#              8686698119     NaN  0.351062  32.584852
#              8778105111     NaN  0.340115  32.582471
# way          437577068      NaN  0.337646  32.584057
#              649469461       no  0.347782  32.572782
#
# [16 rows x 136 columns]

# %%
poi_counts = {}

poi_types =["amenity", "historic", "leisure", "shop", "tourism", "religion", "memorial"]

for tag in poi_types:
  if tag in pois_df.columns:
    poi_counts[tag] = pois_df[tag].notnull().sum()
  else:
    poi_counts[tag] = 0

poi_counts_df = pd.DataFrame(list(poi_counts.items()), columns=['POI Type', 'Count'])
poi_counts_df
# Out:
#    POI Type  Count
# 0   amenity    729
# 1  historic      0
# 2   leisure     20
# 3      shop    163
# 4   tourism     16
# 5  religion      7
# 6  memorial      0

# %% [markdown]
# ## Assessing the Available OpenStreetMap Features
#
# <span class="editsection-bracket"
# style="">\[</span><span class="editsection"
# style=""><a href="https://github.com/lawrennd/snippets/edit/main/_datasets/includes/assessing-osm.md" target="_blank" onclick="ga('send', 'event', 'Edit Page', 'Edit', 'https://github.com/lawrennd/snippets/edit/main/_datasets/includes/assessing-osm.md', 13);">edit</a></span><span class="editsection-bracket" style="">\]</span>
#
# In the course assessment you will be given the task of constructing a
# prediction system for various indicators at a given location. We expect
# that knowledge of the local region around the property should be helpful
# in making those predictions. To evaluate this we will now look at
# [OpenStreetMap](https://www.openstreetmap.org) as a data source.
#
# In this section, you should follow the methodology used in the above
# example to extract summary OSM information that can be useful in making
# predictions about an area. Use code from the example to construct a
# function that summarises the number of various points of interest in a
# target area. You should write reusable code that allows you to explore
# the characteristics of different points of interest.

# %%
def count_pois_near_coordinates(latitude: float, longitude: float, tags: dict, distance_km: float = 1.0) -> dict:
    """
    Count Points of Interest (POIs) near a given pair of coordinates within a specified distance.
    Args:
        latitude (float): Latitude of the location.
        longitude (float): Longitude of the location.
        tags (dict): A dictionary of OSM tags to filter the POIs (e.g., {'amenity': True, 'tourism': True}).
        distance_km (float): The distance around the location in kilometers. Default is 1 km.
    Returns:
        dict: A dictionary where keys are the OSM tags and values are the counts of POIs for each tag.
    """

    pois = ox.features_from_point((latitude, longitude), tags)

    pois_df = pd.DataFrame(pois)
    pois_df['latitude'] = pois_df.apply(lambda row: row.geometry.centroid.y, axis=1)
    pois_df['longitude'] = pois_df.apply(lambda row: row.geometry.centroid.x, axis=1)
    poi_counts = {}

    poi_types = ["amenity", "historic", "leisure", "shop", "tourism", "religion", "memorial"]

    for tag in poi_types:
        if tag in pois_df.columns:
            poi_counts[tag] = pois_df[tag].notnull().sum()
        else:
            poi_counts[tag] = 0

    return poi_counts

# %% [markdown]
# Now that you have written reusable code, choose the tags you want to
# query. This should be different from the tags used in the example. You
# can also search for specific tags like this:
# `"amenity": ["university", ...`.

# %%
# Modify this dict
tags = {
    "amenity": ["university"],
    "historic": True,
    "leisure": True,
    "shop": True,
    "tourism": True,
    "religion": True,
    "building": True,
    "public_transport": True,
    "natural": True,
}

# %% [markdown]
# Here there are 13 UK locations.

# %%
locations_dict = {
    "Cambridge": (52.2054, 0.1132),
    "Oxford": (51.7570, -1.2545),
    "Euston Square": (51.5246, -0.1340),
    "Temple": (51.5115, -0.1160),
    "Kensington": (51.4988, -0.1749),
    "Barnsley": (53.5526, -1.4797),
    "Mansfield": (53.1472, -1.1987),
    "Wakefield": (53.6848, -1.5039),
    "Sunderland": (54.9069, -1.3838),
    "Rotherham": (53.4300, -1.3568),
    "Doncaster": (53.5228, -1.1288),
    "Chesterfield": (53.2350, -1.4210),
    "Huddersfield": (53.6450, -1.7794)
    }

# %% [markdown]
# ### Exercise 1
#
# Use your code to query the OSM feature counts for each of them, and
# combine them into one dataframe.

# %% [markdown]
# ### Exercise 1 Answer
#
# Write your answer to Exercise 1 here

# %%
location_poi_counts = []
for location_name, (latitude, longitude) in locations_dict.items():
    poi_counts = count_pois_near_coordinates(latitude, longitude, tags)
    poi_counts['Location'] = location_name
    location_poi_counts.append(poi_counts)

poi_counts_df = pd.DataFrame(location_poi_counts)
poi_counts_df = poi_counts_df.set_index('Location')
poi_counts_df
# Out:
#                amenity  historic  leisure  shop  tourism  religion  memorial
# Location
# Cambridge          260        36      303   350      131        61        21
# Oxford             286        77      307   388      139        74        42
# Euston Square      488       172      181   795      286        42       157
# Temple             548       204      156   953      306        42       152
# Kensington         114        88      166   515      179        29        82
# Barnsley           186         5       96   344       13        11         2
# Mansfield           96        13       65   341       14        30        10
# Wakefield          223         5       89   518       19        25         3
# Sunderland         139         7       49   270       34        31         5
# Rotherham           75         1       52   186        6        13         0
# Doncaster           93         3       21   250       22        18         1
# Chesterfield        92         5       49   317       17        18         3
# Huddersfield        82         9       48   299       12        19         2

# %% [markdown]
# ### Exercise 2
#
# Use k-means clustering or another clustering method to try to find
# clusters of similar areas, based on nearby OSM features.

# %% [markdown]
# ### Exercise 2 Answer
#
# Write your answer to Exercise 2 here

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Select features for clustering (exclude any non-numerical columns)
features = poi_counts_df.select_dtypes(include=['number'])

# Standardize the features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

kmeans = KMeans(n_clusters=3)
kmeans.fit(scaled_features)

# Add cluster labels to the dataframe
poi_counts_df['Cluster'] = kmeans.labels_
poi_counts_df
# Out:
#                amenity  historic  leisure  shop  tourism  religion  memorial  \
# Location
# Cambridge          260        36      303   350      131        61        21
# Oxford             286        77      307   388      139        74        42
# Euston Square      488       172      181   795      286        42       157
# Temple             548       204      156   953      306        42       152
# Kensington         114        88      166   515      179        29        82
# Barnsley           186         5       96   344       13        11         2
# Mansfield           96        13       65   341       14        30        10
# Wakefield          223         5       89   518       19        25         3
# Sunderland         139         7       49   270       34        31         5
# Rotherham           75         1       52   186        6        13         0
# Doncaster           93         3       21   250       22        18         1
# Chesterfield        92         5       49   317       17        18         3
# Huddersfield        82         9       48   299       12        19         2
#
#                Cluster
# Location
# Cambridge            2
# Oxford               2
# Euston Square        1
# Temple               1
# Kensington           0
# Barnsley             0
# Mansfield            0
# Wakefield            0
# Sunderland           0
# Rotherham            0
# Doncaster            0
# Chesterfield         0
# Huddersfield         0

# %% [markdown]
# ### Exercise 3
#
# Investigate the locations yourself, and assign them categories based on
# your interpretation. Visualise and compare your manual assignments
# against your clustering results.

# %% [markdown]
# ### Exercise 3 Answer
#
# Write your answer to Exercise 3 here

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assign manual categories
manual_categories = {
    "Cambridge": 2,
    "Oxford": 2,
    "Euston Square": 1,
    "Temple": 1,
    "Kensington": 1,
    "Barnsley": 0,
    "Mansfield": 0,
    "Wakefield": 0,
    "Sunderland": 0,
    "Rotherham": 0,
    "Doncaster": 0,
    "Chesterfield": 0,
    "Huddersfield": 0
}

# Add manual categories to the dataframe
poi_counts_df['Manual Category'] = poi_counts_df.index.map(manual_categories)

# Plot the clustering results
plt.figure(figsize=(12, 6))
plt.xlabel('Cluster')
plt.ylabel('Location')
sns.heatmap(poi_counts_df[['Cluster', 'Manual Category']], cmap='coolwarm', cbar=False, annot=True)
# Out:
# <Axes: ylabel='Location'>

# %% [markdown]
# ### Exercise 4
#
# Normalise your dataframe and compute a distance matrix for the
# locations. Visualise it, and compare the outcode with your previous
# clustering results.

# %% [markdown]
# ### Exercise 4 Answer
#
# Write your answer to Exercise 4 here

# %%
from sklearn.preprocessing import normalize
from sklearn.metrics.pairwise import euclidean_distances

normalised = normalize(features)

distances = euclidean_distances(normalised)
distances_df = pd.DataFrame(distances, index=poi_counts_df.index, columns=poi_counts_df.index)
distances_df

# hot -> different
sns.heatmap(distances_df, cmap="coolwarm", cbar=True, annot=True)
# Out:
# <Axes: xlabel='Location', ylabel='Location'>

# %%
# distance matrix dataframe, where distance = 0 if they're in the same cluster, and one otherwise
# rows and columns are both the locations

cluster_distances = pd.DataFrame(1.0, index=poi_counts_df.index, columns=poi_counts_df.index)

for i in range(len(poi_counts_df)):
    for j in range(len(poi_counts_df)):
        if poi_counts_df['Cluster'][i] == poi_counts_df['Cluster'][j]:
            cluster_distances.iloc[i, j] = 0.0

# plot a heatmap
plt.figure(figsize=(12, 6))
plt.xlabel('Location')
plt.ylabel('Location')
sns.heatmap(cluster_distances, cmap='coolwarm', cbar=False, annot=True)
# Out:
# C:\Users\varun\AppData\Local\Temp\ipykernel_103592\1699911434.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if poi_counts_df['Cluster'][i] == poi_counts_df['Cluster'][j]:
# <Axes: xlabel='Location', ylabel='Location'>

# %% [markdown]
# ### Exercise 5
#
# Which features you included were correlated among each other?
# Investigate and plot a feature correlation matrix. What do these results
# say about your feature selection?

# %% [markdown]
# ### Exercise 5 Answer
#
# Write your answer to Exercise 5 here

# %%
df_corr = features.corr()

plt.figure(figsize=(12, 6))
sns.heatmap(df_corr, cmap='coolwarm', cbar=True, annot=True)

# Historic, tourism and memorial are all highly correlated
# This suggests that these POI types are often found together
# This might have skewed the results of the clustering algorithm as it might have clustered locations based on these POI types
# Out:
# <Axes: >

# %% [markdown]
# ## Joining Spatial Data
#
# <span class="editsection-bracket"
# style="">\[</span><span class="editsection"
# style=""><a href="https://github.com/lawrennd/snippets/edit/main/_access/includes/spatial-join.md" target="_blank" onclick="ga('send', 'event', 'Edit Page', 'Edit', 'https://github.com/lawrennd/snippets/edit/main/_access/includes/spatial-join.md', 13);">edit</a></span><span class="editsection-bracket" style="">\]</span>

# %% [markdown]
# ### Matching OpenStreetMap and House Prices data
#
# In this exercise you will download the geographies of houses from
# OpenStreetMap and map them to visualise the records you see in the house
# price dataset. This is a data linking and validation exercise.
#
# The latitude and longitude of Cambridge are as follows:

# %%
place_name = "Cambridge"
latitude = 52.1951
longitude = 0.1313

# %% [markdown]
# We want to execute an SQL query on your database to select all houses in
# a 1km x 1km region around the centre of Cambridge that have been part of
# housing transactions since 2020.
#
# This operation can take a very long time. This is because the table is
# not indexed on coordinate data, and therefore the query has to check
# tens of millions of rows. This can be fixed by constructing an index on
# the `latitude` and `longitude` values, using `BTREE` to make a joint
# index. *Note that indexing can take a long time.* Consider also indexing
# your table by other variables you might find useful later.

# %% [markdown]
# ### Exercise 6
#
# Index the table on the coordinate data using a `BTREE` and index other
# columns you might find useful.

# %% [markdown]
# ### Exercise 6 Answer
#
# Write your answer to Exercise 6 here

# %%
import yaml

with open("credentials.yaml") as file:
  credentials = yaml.safe_load(file)
username = credentials["username"]
password = credentials["password"]
url = credentials["url"]
port = credentials["port"]

# %pip install pymysql
# %load_ext sql
# %sql mariadb+pymysql://$username:$password@$url?local_infile=1

# %%
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %sql use `ads_2024`;
# %sql SHOW tables
# Out:
#  * mariadb+pymysql://admin:***@database-ads-vl331.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
#    mariadb+pymysql://admin:***@database2-ads-vl331.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-vl331.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
#    mariadb+pymysql://admin:***@database2-ads-vl331.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 3 rows affected.
# [('postcode_data',), ('pp_data',), ('prices_coordinates_data',)]

# %%
# %sql CREATE INDEX idx_prices_coordinates_data_coordinates ON prices_coordinates_data (latitude, longitude);
# %sql CREATE INDEX idx_prices_coordinates_data_date_of_transfer ON prices_coordinates_data (date_of_transfer);
# Out:
#  * mariadb+pymysql://admin:***@database2-ads-vl331.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# (pymysql.err.OperationalError) (1061, "Duplicate key name 'idx_prices_coordinates_data_coordinates'")
# [SQL: CREATE INDEX idx_prices_coordinates_data_coordinates ON prices_coordinates_data (latitude, longitude);]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#  * mariadb+pymysql://admin:***@database2-ads-vl331.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# (pymysql.err.OperationalError) (1061, "Duplicate key name 'idx_prices_coordinates_data_date_of_transfer'")
# [SQL: CREATE INDEX idx_prices_coordinates_data_date_of_transfer ON prices_coordinates_data (date_of_transfer);]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# ### Exercise 7
#
# Write an SQL query on your database to select all houses in a 1km x 1km
# region around the centre of Cambridge that have been part of housing
# transactions since 2020.

# %% [markdown]
# ### Exercise 7 Answer
#
# Write your answer to Exercise 7 here

# %%
conn = fynesse.access.create_connection(username, password, url, "ads_2024")
# Out:
# Connection established!

# %%
cursor = conn.cursor()
cursor.execute("SELECT * FROM pp_data inner join postcode_data on pp_data.postcode = postcode_data.postcode WHERE latitude between %s and %s and longitude between %s and %s and date_of_transfer >= '2020-01-01'", (latitude - 0.5/111, latitude + 0.5/111, longitude - 0.5/111, longitude + 0.5/111))

# put into a dataframe
cam_transactions_since_2020 = pd.DataFrame(cursor.fetchall(), columns=[desc[0] for desc in cursor.description])
cam_transactions_since_2020

# %% [markdown]
# ### Exercise 8
#
# Get information about all the buildings in that area from OpenStreetMaps
# (`'building': True`). You will need their address information
# (`addr:housenumber`, `addr:street`, `addr:postcode`, …) and geometry
# polygon (`geometries_from_bbox`). Construct a dataframe that lists all
# OSM buildings in the area that have a full address, along with their
# area (in square meters). Plot a map of the area, using color to mark the
# buildings with addresses and the ones without.

# %% [markdown]
# ### Exercise 8 Answer
#
# Write your answer to Exercise 8 here

# %%
buildings = fynesse.assess.osm_buildings_data(latitude, longitude)
# Out:
# c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\fynesse\assess.py:111: FutureWarning: The `geometries` module and `geometries_from_X` functions have been renamed the `features` module and `features_from_X` functions. Use these instead. The `geometries` module and function names are deprecated and will be removed in the v2.0.0 release. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   buildings = ox.geometries_from_bbox(latitude + distance/222, latitude - distance/222, longitude + distance/222, longitude - distance/222, building_tags)
# c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\osmnx\geometries.py:48: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   return features.features_from_bbox(north, south, east, west, tags=tags)
# c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\osmnx\geometries.py:48: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   return features.features_from_bbox(north, south, east, west, tags=tags)
# c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\fynesse\assess.py:112: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(latitude + distance/222, latitude - distance/222, longitude + distance/222, longitude - distance/222)
# c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\fynesse\assess.py:112: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(latitude + distance/222, latitude - distance/222, longitude + distance/222, longitude - distance/222)
# c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyproj\crs\crs.py:143: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\fynesse\assess.py:137: UserWarning: Legend does not support handles for PatchCollection instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   plt.legend()
# c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\fynesse\assess.py:137: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ### Exercise 9
#
# Match the houses you found in the price paid dataset with the buildings
# on OpenStreetMaps based on their addresses. Can this be applied to all
# building types? Are there any PP transactions which you couldn’t match
# to an OSM building, or any OSM buildings you coulnd’t match to a PP
# transaction? If so, what could be the reason for this? Do you employ any
# techniques to find non-exact matches? If yes, what matches would you
# have missed without it? Are you encountering false positive matches? Use
# this address matching to merge the two dataframes.

# %% [markdown]
# ### Exercise 9 Answer
#
# Write your answer to Exercise 9 here

# %%
pp_cambridge = fynesse.select_pp_data(conn, latitude, longitude)

# %%
merged = fynesse.assess.join_pp_osm(pp_cambridge, buildings)

# %% [markdown]
# This may not apply to some building types in which there are multiple properties in one address, like a Flat A and Flat B at house number 1.
# Non-matches could be explained by:
# - Demolition
# - Recent Construction
# - Lack of transfer of ownership
#
# I'm looking for non-exact matches by doing it case-insensitive, and using both primary and secondary addressable_object_name.

# %% [markdown]
# ### Exercise 10
#
# Examine the relationship between the price and area of a property. -
# What other variables do you need to account for? - Is the correlation as
# strong as you would expect? - What factors could be impacting this?
#
# Visualise the relationships you found.

# %% [markdown]
# ### Exercise 10 Answer
#
# Write your answer to Exercise 10 here

# %%
# plot price vs area_sqm
plt.figure(figsize=(12, 6))
plt.scatter(merged["area_sqm"], merged["price"])
plt.xlabel("Area (sqm)")
plt.ylabel("Price (£)")
plt.title("Price vs Area in Cambridge")
plt.show()

print(merged[["price", "area_sqm"]].corr()["price"]["area_sqm"])

# There is almost no correlation between price and area_sqm
# This could be due to the following other factors:
# - Location
# - Condition of the property
# - Date of transfer
# - Type of property
# Out:
# -0.09569368740310108
# -0.13885172685180489

# %% [markdown]
# Demonstrate the reusability of your code by executing the same analysis
# for Oxford.

# %%
place_name = "Oxford"

latitude = 51.7520
longitude = -1.2577

# %% [markdown]
# ### Exercise 11
#
# Replicating the same analysis for Oxford. You do not need to answer all
# the questions again, but you should show that your code works for this
# new input without the need to modify it. You should use the Fynesse
# library for this. Finish by plotting a map of the area and the
# correlation you find.

# %% [markdown]
# ### Exercise 11 Answer
#
# Write your answer to Exercise 11 here

# %%
# Use this box for any code you need
pp_ox = fynesse.assess.select_pp_data(conn, latitude, longitude)
buildings_ox = fynesse.assess.osm_buildings_data(latitude, longitude, 1)
merged_ox = fynesse.assess.join_pp_osm(pp_ox, buildings_ox)
merged_ox[["price", "area_sqm"]].corr()
# Out:
# c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\fynesse\assess.py:111: FutureWarning: The `geometries` module and `geometries_from_X` functions have been renamed the `features` module and `features_from_X` functions. Use these instead. The `geometries` module and function names are deprecated and will be removed in the v2.0.0 release. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   buildings = ox.geometries_from_bbox(latitude + distance/222, latitude - distance/222, longitude + distance/222, longitude - distance/222, building_tags)
# c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\osmnx\geometries.py:48: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   return features.features_from_bbox(north, south, east, west, tags=tags)
# c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\osmnx\geometries.py:48: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   return features.features_from_bbox(north, south, east, west, tags=tags)
# c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\fynesse\assess.py:112: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(latitude + distance/222, latitude - distance/222, longitude + distance/222, longitude - distance/222)
# c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\fynesse\assess.py:112: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(latitude + distance/222, latitude - distance/222, longitude + distance/222, longitude - distance/222)
# c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyproj\crs\crs.py:143: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\fynesse\assess.py:137: UserWarning: Legend does not support handles for PatchCollection instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   plt.legend()
#             price  area_sqm
# price     1.00000  -0.07543
# area_sqm -0.07543   1.00000

# %% [markdown]
# ## Conclusions
#
# You should find some of the code you wrote above useful in your final
# assessment. Make sure you wrote the code to be reusable and efficient,
# and do include it in your Fynesse library. The functions you are
# particularly likely to reuse are the OSM feature search, and map
# visualisation functions.

# %% [markdown]
# ### Exercise 12
#
# Add relevant code to your Fynesse library. Demonstrate this was
# successful by installing your library below and calling at least two
# example functions.

# %% [markdown]
# ### Exercise 12 Answer
#
# Write your answer to Exercise 12 here

# %%
fynesse.assess.count_pois_near_coordinates(latitude, longitude, tags)
# Out:
# {'amenity': 258,
#  'historic': 80,
#  'leisure': 316,
#  'shop': 345,
#  'tourism': 142,
#  'religion': 70,
#  'memorial': 44}

# %%
fynesse.assess.cluster_locations(locations_dict, tags)
# Out:
#                amenity  historic  leisure  shop  tourism  religion  memorial  \
# Location
# Cambridge          260        36      303   350      131        61        21
# Oxford             286        77      307   388      139        74        42
# Euston Square      488       172      181   795      286        42       157
# Temple             548       204      156   953      306        42       152
# Kensington         114        88      166   515      179        29        82
# Barnsley           186         5       96   344       13        11         2
# Mansfield           96        13       65   341       14        30        10
# Wakefield          223         5       89   518       19        25         3
# Sunderland         139         7       49   270       34        31         5
# Rotherham           75         1       52   186        6        13         0
# Doncaster           93         3       21   250       22        18         1
# Chesterfield        92         5       49   317       17        18         3
# Huddersfield        82         9       48   299       12        19         2
#
#                Cluster
# Location
# Cambridge            2
# Oxford               2
# Euston Square        0
# Temple               0
# Kensington           1
# Barnsley             1
# Mansfield            1
# Wakefield            1
# Sunderland           1
# Rotherham            1
# Doncaster            1
# Chesterfield         1
# Huddersfield         1

# %% [markdown]
# ## Thanks!
#
# For more information on these subjects and more you might want to check
# the following resources.
#
# -   book: [The Atomic
#     Human](https://www.penguin.co.uk/books/455130/the-atomic-human-by-lawrence-neil-d/9780241625248)
# -   twitter: [@lawrennd](https://twitter.com/lawrennd)
# -   podcast: [The Talking Machines](http://thetalkingmachines.com)
# -   newspaper: [Guardian Profile
#     Page](http://www.theguardian.com/profile/neil-lawrence)
# -   blog:
#     [http://inverseprobability.com](http://inverseprobability.com/blog.html)

# %% [markdown]
# ## References
