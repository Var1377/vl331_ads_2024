# %%
import pandas as pd
import osmnx as ox
import shapely as shp
import numpy as np
import os
import requests
import fynesse
import geopandas as gpd
import yaml
import matplotlib.pyplot as plt
import seaborn as sns
from zipfile import ZipFile
import sklearn

# %load_ext sql

with open("./credentials1.yaml") as file:
  credentials = yaml.safe_load(file)
username = credentials["username"]
password = credentials["password"]
url = credentials["url"]
port = credentials["port"]

# %config SqlMagic.style = '_DEPRECATED_DEFAULT'
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# Traceback (most recent call last):
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py", line 146, in __init__
#     self._dbapi_connection = engine.raw_connection()
#                              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py", line 3302, in raw_connection
#     return self.pool.connect()
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\pool\base.py", line 449, in connect
#     return _ConnectionFairy._checkout(self)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\pool\base.py", line 1263, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\pool\base.py", line 712, in checkout
#     rec = pool._do_get()
#           ^^^^^^^^^^^^^^
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\pool\impl.py", line 179, in _do_get
#     with util.safe_reraise():
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\pool\impl.py", line 177, in _do_get
#     return self._create_connection()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\pool\base.py", line 390, in _create_connection
#     return _ConnectionRecord(self)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\pool\base.py", line 674, in __init__
#     self.__connect()
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\pool\base.py", line 900, in __connect
#     with util.safe_reraise():
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\pool\base.py", line 896, in __connect
#     self.dbapi_connection = connection = pool._invoke_creator(self)
#                                          ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\create.py", line 643, in connect
#     return dialect.connect(*cargs, **cparams)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\default.py", line 621, in connect
#     return self.loaded_dbapi.connect(*cargs, **cparams)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\connections.py", line 361, in __init__
#     self.connect()
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\connections.py", line 669, in connect
#     self._request_authentication()
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\connections.py", line 979, in _request_authentication
#     auth_packet = _auth.caching_sha2_password_auth(self, auth_packet)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\_auth.py", line 241, in caching_sha2_password_auth
#     pkt = conn._read_packet()
#           ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\connections.py", line 775, in _read_packet
#     packet.raise_for_error()
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\protocol.py", line 219, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\err.py", line 150, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.OperationalError: (1049, "Unknown database 'ads_2024'")
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sql\magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sql\connection.py", line 70, in set
#     cls.current = existing or Connection(descriptor, connect_args, creator)
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sql\connection.py", line 55, in __init__
#     self.internal_connection = engine.connect()
#                                ^^^^^^^^^^^^^^^^
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py", line 3278, in connect
#     return self._connection_cls(self)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py", line 148, in __init__
#     Connection._handle_dbapi_exception_noconnection(
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py", line 2442, in _handle_dbapi_exception_noconnection
#     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py", line 146, in __init__
#     self._dbapi_connection = engine.raw_connection()
#                              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py", line 3302, in raw_connection
#     return self.pool.connect()
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\pool\base.py", line 449, in connect
#     return _ConnectionFairy._checkout(self)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\pool\base.py", line 1263, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\pool\base.py", line 712, in checkout
#     rec = pool._do_get()
#           ^^^^^^^^^^^^^^
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\pool\impl.py", line 179, in _do_get
#     with util.safe_reraise():
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\pool\impl.py", line 177, in _do_get
#     return self._create_connection()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\pool\base.py", line 390, in _create_connection
#     return _ConnectionRecord(self)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\pool\base.py", line 674, in __init__
#     self.__connect()
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\pool\base.py", line 900, in __connect
#     with util.safe_reraise():
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\pool\base.py", line 896, in __connect
#     self.dbapi_connection = connection = pool._invoke_creator(self)
#                                          ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\create.py", line 643, in connect
#     return dialect.connect(*cargs, **cparams)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\default.py", line 621, in connect
#     return self.loaded_dbapi.connect(*cargs, **cparams)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\connections.py", line 361, in __init__
#     self.connect()
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\connections.py", line 669, in connect
#     self._request_authentication()
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\connections.py", line 979, in _request_authentication
#     auth_packet = _auth.caching_sha2_password_auth(self, auth_packet)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\_auth.py", line 241, in caching_sha2_password_auth
#     pkt = conn._read_packet()
#           ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\connections.py", line 775, in _read_packet
#     packet.raise_for_error()
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\protocol.py", line 219, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "c:\Users\varun\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\err.py", line 150, in raise_mysql_exception
#     raise errorclass(errno, errval)
# sqlalchemy.exc.OperationalError: (pymysql.err.OperationalError) (1049, "Unknown database 'ads_2024'")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 0 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/ads_2024?local_infile=1
# 0 rows affected.
# []
